# %% [markdown]
# ### 1D Heat equation

# %%
# setup time-space geometry
import numpy as np

num_points = 51
x_start = 0
x_stop = 1
t_start = 0
t_stop = 1

# thermal diffusivity
alpha = 1.22e-3

# x points
x = np.linspace(start=x_start, stop=x_stop, num=num_points)
dx = x[1] - x[0]
print(dx)

# time step for numerical stability
num_timesteps = 1000
t = np.linspace(start=t_start, stop=t_stop, num=num_timesteps)
sigma = 0.5
dt = sigma * dx **2 / alpha

# initial condition and boundary condition
u = np.sin(np.pi * x)

# plot factor
plot_factor = int(np.floor(num_timesteps / 5))

# initial plot
import matplotlib.pyplot as plt
plt.plot(x, u)
plt.show()
# Out:
# 0.02

# %%
def delta_heat(u,x,dt):
    dx = x[1] - x[0]
    sigma = alpha * dt / dx**2
    return (sigma * (u[2:] - 2*u[1:-1] + u[:-2]))

# %%
# evolve the heat over all timesteps
for tstep in range(len(t)):
    u_next = u
    u_next[1:-1] = u[1:-1] + delta_heat(u,x,dt)
    if tstep % plot_factor == 0:
        plt.plot(x, u_next)
    u = u_next

plt.show()
