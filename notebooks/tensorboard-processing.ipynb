# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
lr_tst0p2.columns
# Out:
# Index(['Wall time', 'Step', 'Value'], dtype='object')

# %%
lr_tst0p2 = pd.read_csv("/home/harry/Downloads/run-cavity_nu0.01_U1_20x20_epochs5000_lrannealing_testpcnt0.2-tag-test_data_loss.csv")
lr_tst0p5 = pd.read_csv("/home/harry/Downloads/run-cavity_nu0.01_U1_20x20_epochs5000_lrannealing_testpcnt0.5-tag-test_data_loss.csv")
lr_tst0p8 = pd.read_csv("/home/harry/Downloads/run-cavity_nu0.01_U1_20x20_epochs5000_lrannealing_testpcnt0.8-tag-test_data_loss.csv")

fig, ax = plt.subplots(1,2, figsize=(12, 4))
ax[0].plot(lr_tst0p2.Step, lr_tst0p2.Value, label="Testing Percent: 20%")
ax[0].plot(lr_tst0p5.Step, lr_tst0p5.Value, label="Testing Percent: 50%")
ax[0].plot(lr_tst0p8.Step, lr_tst0p8.Value, label="Testing Percent: 80%")
ax[0].set_yscale('linear')
ax[0].set_title("Testing data residual (MSE)")
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("MSE")
ax[0].legend(loc="upper right")

ax[1].plot(lr_tst0p2.Step, lr_tst0p2.Value, label="Testing Percent: 20%")
ax[1].plot(lr_tst0p5.Step, lr_tst0p5.Value, label="Testing Percent: 50%")
ax[1].plot(lr_tst0p8.Step, lr_tst0p8.Value, label="Testing Percent: 80%")
ax[1].set_yscale('log')
ax[1].set_title("Testing data residual (MSE) LogScale")
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("MSE")
ax[1].legend(loc="upper right")

# %%
lr = pd.read_csv("/home/harry/Downloads/run-cavity_nu0.01_U1_20x20_epochs5000_lrannealing_testpcnt0.8-tag-test_data_loss.csv")
softadapt = pd.read_csv("/home/harry/Downloads/run-cavity_nu0.01_U1_20x20_epochs5000_softadapt_testpcnt0.8-tag-test_data_loss.csv")
noadaption = pd.read_csv("/home/harry/Downloads/run-cavity_nu0.01_U1_20x20_epochs5000_noadaption_testpcnt0.8-tag-test_data_loss.csv")

fig, ax = plt.subplots(1,2, figsize=(12, 4))
ax[0].plot(lr.Step, lr.Value, label="Linear rate annealing")
ax[0].plot(softadapt.Step, softadapt.Value, label="SoftAdapt")
ax[0].plot(noadaption.Step, noadaption.Value, label="No adaption")
ax[0].set_yscale('linear')
ax[0].set_title("Testing data residual (MSE)")
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("MSE")
ax[0].legend(loc="upper right")

ax[1].plot(lr.Step, lr.Value, label="Linear rate annealing")
ax[1].plot(softadapt.Step, softadapt.Value, label="SoftAdapt")
ax[1].plot(noadaption.Step, noadaption.Value, label="No adaption")
ax[1].set_yscale('log')
ax[1].set_title("Testing data residual (MSE) LogScale")
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("MSE")
ax[1].legend(loc="upper right")

# %%
lr = pd.read_csv("/home/harry/Downloads/run-cavity_nu0.01_U1_20x20_epochs5000_lrannealing_testpcnt0.8-tag-test_data_loss.csv")

fig, ax = plt.subplots(1,2, figsize=(12, 4))
ax[0].plot(lr.Value)
ax[0].set_yscale('linear')
ax[0].set_title("Testing data residual (MSE)")
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("MSE")
ax[0].legend(loc="upper right")

ax[1].plot(lr.Value, label="Linear rate annealing")
ax[1].plot(softadapt.Value, label="SoftAdapt")
ax[1].plot(noadaption.Value, label="No adaption")
ax[1].set_yscale('log')
ax[1].set_title("Testing data residual (MSE) LogScale")
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("MSE")
ax[1].legend(loc="upper right")
