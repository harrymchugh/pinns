# %% [markdown]
# # 1D Heat equation; PINN

# %%
# initial plot
import matplotlib.pyplot as plt
import numpy as np
import torch
import os
import pandas as pd
from torch.utils.tensorboard import SummaryWriter
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import datetime

# %% [markdown]
# We will store the temperature u, at a given x,t in a 2D tensor called U(t,x)

# %%
# setup time-space geometry
num_points = 51
x_start = 0
x_stop = 1
num_timesteps = 1000
t_start = 0
t_stop = 1 
x = np.linspace(start=x_start, stop=x_stop, num=num_points)
t = np.linspace(start=t_start, stop=t_stop, num=num_timesteps)

# %% [markdown]
# ## PINN to learn the 1D-heat diffusion equation

# %% [markdown]
# The goal of the following section is to show a PINN using:
#
# - Initial condition loss
# - Boundary condition loss
# - PDE loss
# - Data driven loss

# %%
#Use GPU if available
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cpu'

# %%
# When using Google Colab
# from google.colab import drive
# drive.mount('/gdrive')
# %cd /gdrive/My Drive

# %%
U_load = np.load("./1d-heat.npy")
print(f"U shape: {U_load.shape}")
# Out:
# U shape: (1000, 51)

# %%
#Store x,t in a feature array of 2 columns
features = np.ones((U_load.shape[0]*U_load.shape[1],2))
features[:,1] = np.tile(x,U_load.shape[0])
features[:,0] = np.repeat(t,U_load.shape[1])
print(f"First 5 features {features[0:5]}\n")
print(f"Last 5 features  {features[-5:]}")
# Out:
# First 5 features [[0.   0.  ]
#  [0.   0.02]
#  [0.   0.04]
#  [0.   0.06]
#  [0.   0.08]]
#
# Last 5 features  [[1.   0.92]
#  [1.   0.94]
#  [1.   0.96]
#  [1.   0.98]
#  [1.   1.  ]]

# %%
labels = np.ones((U_load.shape[0]*U_load.shape[1],1))
labels = U_load.ravel()
print(f"First 5 temperature label data: {labels[0:5]}")
# Out:
# First 5 temperature label data: [0.         0.06279052 0.12533323 0.18738131 0.24868989]

# %%
#Set datatype expected by PyTorch
labels = labels.astype(np.float32)
features = features.astype(np.float32)

# %% [markdown]
# Data now needs pre-processing ready for PyTorch training including:
#
# - Feature scaling
# - Train-test splitting for model validation

# %%
### Pre-processing stage
std_scaler = StandardScaler()
scaler_features = std_scaler.fit(features)
scaled_features = scaler_features.transform(features)

print(f"\nPre-scaling:\n {features[0:5]}")
print(f"Mean: {features.mean()} Std: {features.std()}")
print(f"\nPost-scaling:\n {scaled_features[0:5]}")
print(f"Mean: {scaled_features.mean()} Std: {scaled_features.std()}")
# Out:
# Pre-scaling:
#  [[0.   0.  ]
#  [0.   0.02]
#  [0.   0.04]
#  [0.   0.06]
#  [0.   0.08]]
# Mean: 0.5000000596046448 Std: 0.2916906177997589
#
# Post-scaling:
#  [[-1.7303196 -1.6984155]
#  [-1.7303196 -1.6304789]
#  [-1.7303196 -1.5625423]
#  [-1.7303196 -1.4946057]
#  [-1.7303196 -1.426669 ]]
# Mean: 2.1541818995274298e-08 Std: 1.0

# %%
scaled_features = features

# %%
# Get feature data for initial condition, boundary condition and interior points
features_init = scaled_features[0:51]

features_x0 = scaled_features[0::51]
features_xstop = scaled_features[50::51]
features_bound = np.append(features_x0, features_xstop, axis=0)

features_interior = np.empty((0,1))
start=1
block_size=49
skip=2
while start < features.shape[0]:
    features_interior = np.append(features_interior, scaled_features[start:start+block_size])
    start = start + block_size + skip

length = features_interior.ravel().shape[0]
features_interior = features_interior.reshape((int(length/2),2))

#Now split them into x and t as this is more generic for future multi-dimensional 
t_init = features_init[:, 0]
t_bound = features_bound[:, 0]
t_interior = features_interior[:, 0]
x_init = features_init[:, 1]
x_bound = features_bound[:, 1]
x_interior = features_interior[:, 1]

print(f"Time vals init condition shape: {t_init.shape}")
print(f"Time vals boundary condition shape: {t_bound.shape}")
print(f"Time vals interior condition shape: {t_interior.shape}")
print(f"Space vals init condition shape: {x_init.shape}")
print(f"Space vals boundary condition shape: {x_bound.shape}")
print(f"Space vals interior shape: {x_interior.shape}")
# Out:
# Time vals init condition shape: (51,)
# Time vals boundary condition shape: (2000,)
# Time vals interior condition shape: (49000,)
# Space vals init condition shape: (51,)
# Space vals boundary condition shape: (2000,)
# Space vals interior shape: (49000,)

# %%
# Get label data for initial condition, boundary condition and interior points
labels_init = labels[0:51]

labels_x0 = labels[0::51]
labels_xstop = labels[50::51]
labels_bound = np.append(labels_x0, labels_xstop, axis=0)

labels_interior = np.empty((0,1))
start=1
block_size=49
skip=2
while start < labels.shape[0]:
    labels_interior = np.append(labels_interior, labels[start:start+block_size])
    start = start + block_size + skip

print(f"Labels for init condition shape: {labels_init.shape}")
print(f"Labels for left boundary condition shape: {labels_x0.shape}")
print(f"Labels for right boundary condition shape: {labels_xstop.shape}")
print(f"\tLabels for both boundary condition shape: {labels_bound.shape}")
print(f"Labels for interior shape: {labels_interior.shape}")
# Out:
# Labels for init condition shape: (51,)
# Labels for left boundary condition shape: (1000,)
# Labels for right boundary condition shape: (1000,)
# 	Labels for both boundary condition shape: (2000,)
# Labels for interior shape: (49000,)

# %%
#Train test splitting
test_size = 0.2

#Interior data
(
    x_interior_train,
    x_interior_test,
    t_interior_train,
    t_interior_test,
    labels_interior_train,
    labels_interior_test,
) = train_test_split(x_interior, t_interior, labels_interior, test_size=test_size)

#Initial condition data
(
    x_init_train,
    x_init_test,
    t_init_train,
    t_init_test,
    labels_init_train,
    labels_init_test,
) = train_test_split(x_init, t_init, labels_init, test_size=test_size)

#Boundary condition data
(
    x_bound_train,
    x_bound_test,
    t_bound_train,
    t_bound_test,
    labels_bound_train,
    labels_bound_test,
) = train_test_split(x_bound, t_bound, labels_bound, test_size=test_size)

print(f"x_interior_train shape({x_interior_train.shape}) type({type(x_interior_train)})")
print(f"x_interior_test shape({x_interior_test.shape}) type({type(x_interior_test)})")
print(f"t_interior_train shape({t_interior_train.shape}) type({type(t_interior_train)})")
print(f"t_interior_test shape({t_interior_test.shape}) type({type(t_interior_test)})")
print(f"labels_interior_train shape({labels_interior_train.shape}) type({type(labels_interior_train)})")
print(f"labels_interior_test shape({labels_interior_test.shape}) type({type(labels_interior_test)})")

print()
print(f"x_bound_train shape({x_bound_train.shape}) type({type(x_bound_train)})")
print(f"x_bound_test shape({x_bound_test.shape}) type({type(x_bound_test)})")
print(f"t_bound_train shape({t_bound_train.shape}) type({type(t_bound_train)})")
print(f"t_bound_test shape({t_bound_test.shape}) type({type(t_bound_test)})")
print(f"labels_bound_train shape({labels_bound_train.shape}) type({type(labels_bound_train)})")
print(f"labels_bound_test shape({labels_bound_test.shape}) type({type(labels_bound_test)})")

print()
print(f"x_init_train shape({x_init_train.shape}) type({type(x_init_train)})")
print(f"x_init_test shape({x_init_test.shape}) type({type(x_init_test)})")
print(f"t_init_train shape({t_init_train.shape}) type({type(t_init_train)})")
print(f"t_init_test shape({t_init_test.shape}) type({type(t_init_test)})")
print(f"labels_init_train shape({labels_init_train.shape}) type({type(labels_init_train)})")
print(f"labels_init_test shape({labels_init_test.shape}) type({type(labels_init_test)})")
# Out:
# x_interior_train shape((39200,)) type(<class 'numpy.ndarray'>)
# x_interior_test shape((9800,)) type(<class 'numpy.ndarray'>)
# t_interior_train shape((39200,)) type(<class 'numpy.ndarray'>)
# t_interior_test shape((9800,)) type(<class 'numpy.ndarray'>)
# labels_interior_train shape((39200,)) type(<class 'numpy.ndarray'>)
# labels_interior_test shape((9800,)) type(<class 'numpy.ndarray'>)
#
# x_bound_train shape((1600,)) type(<class 'numpy.ndarray'>)
# x_bound_test shape((400,)) type(<class 'numpy.ndarray'>)
# t_bound_train shape((1600,)) type(<class 'numpy.ndarray'>)
# t_bound_test shape((400,)) type(<class 'numpy.ndarray'>)
# labels_bound_train shape((1600,)) type(<class 'numpy.ndarray'>)
# labels_bound_test shape((400,)) type(<class 'numpy.ndarray'>)
#
# x_init_train shape((40,)) type(<class 'numpy.ndarray'>)
# x_init_test shape((11,)) type(<class 'numpy.ndarray'>)
# t_init_train shape((40,)) type(<class 'numpy.ndarray'>)
# t_init_test shape((11,)) type(<class 'numpy.ndarray'>)
# labels_init_train shape((40,)) type(<class 'numpy.ndarray'>)
# labels_init_test shape((11,)) type(<class 'numpy.ndarray'>)

# %%
features_interior[:, 0]
# Out:
# array([0., 0., 0., ..., 1., 1., 1.])

# %%
U_load.shape
# Out:
# (1000, 51)

# %%
#Lets QC these training and testing locations
f,ax = plt.subplots()
ax.pcolormesh(features[:,0].reshape((1000,51)), features[:,1].reshape((1000,51)), labels.reshape((1000,51)), shading='gouraud',alpha=0.1)
ax.scatter(x_interior_train,t_interior_train,alpha=0.2,c="Red")
ax.scatter(x_interior_test,t_interior_test,alpha=0.01,c="Black")
ax.scatter(x_interior_test,t_interior_test,alpha=0.01,c="Black")
plt.show()

# %%
# Define MLP model architecture class
class NeuralNetwork(torch.nn.Module):
    def __init__(self):
        """_summary_
        """
        super().__init__()
        self.linear_stack = torch.nn.Sequential(
            torch.nn.Linear(2, 64),
            torch.nn.ReLU(),
            torch.nn.Linear(64, 64),
            torch.nn.ReLU(),
            torch.nn.Linear(64, 64),
            torch.nn.ReLU(),
            torch.nn.Linear(64, 64),
            torch.nn.ReLU(),
            torch.nn.Linear(64, 1)
        )

    def forward(self, x, t):
        """_summary_

        Args:
            x (_type_): _description_
            t (_type_): _description_

        Returns:
            _type_: _description_
        """
        inputs = torch.cat([x,t], axis=1).to(device)
        return self.linear_stack(inputs)

# %%
def train_loop(x_bound, x_init, x_interior, t_bound, t_init, t_interior,labels_bound, labels_init, labels_interior, model, loss_fn, optimizer, writer=None):
    """_summary_

    Args:
        x_bound (_type_): _description_
        x_init (_type_): _description_
        x_interior (_type_): _description_
        t_bound (_type_): _description_
        t_init (_type_): _description_
        t_interior (_type_): _description_
        labels_bound (_type_): _description_
        labels_init (_type_): _description_
        labels_interior (_type_): _description_
        model (_type_): _description_
        loss_fn (_type_): _description_
        optimizer (_type_): _description_
    """
    optimizer.zero_grad()

    interior_pred = model(x_interior, t_interior)
    bound_pred = model(x_bound, t_bound)
    init_pred = model(x_init, t_init)
    
    boundary_loss, initial_loss, pde_loss, data_loss = \
        loss_fn(
            interior_pred, bound_pred, init_pred, 
            labels_interior, labels_bound, labels_init, 
            x_interior, t_interior)
    
    print(f"\tBefore adaption: Initial condition loss: {initial_loss}")
    print(f"\tBefore adaption: Boundary condition loss: {boundary_loss}")
    print(f"\tBefore adaption: PDE loss: {pde_loss}")
    print(f"\tBefore adaption: Data loss: {data_loss}")

    #Calculate dBoundaryLoss/dTheta
    boundary_loss.backward(retain_graph=True)
    bound_grads = []
    for name, param in model.named_parameters():
        if "weight" in name:
            bound_grads.append(param.grad.view(-1))
    
    bound_grads = torch.cat(bound_grads)
    optimizer.zero_grad()
    
    #Calculate dInitialLoss/dTheta
    initial_loss.backward(retain_graph=True)
    init_grads = []
    for name, param in model.named_parameters():
        if "weight" in name:
            init_grads.append(param.grad.view(-1))
    
    init_grads = torch.cat(init_grads)
    optimizer.zero_grad()

    #Calculate dInitialLoss/dTheta
    pde_loss.backward(retain_graph=True)
    pde_grads = []
    for name, param in model.named_parameters():
        if "weight" in name:
            pde_grads.append(param.grad.view(-1))
    
    pde_grads = torch.cat(pde_grads)
    optimizer.zero_grad()

    #Calculate dDataLoss/dTheta
    data_loss.backward(retain_graph=True)
    data_grads = []
    for name, param in model.named_parameters():
        if "weight" in name:
            data_grads.append(param.grad.view(-1))    
    
    data_grads = torch.cat(data_grads)
    optimizer.zero_grad()

    #Compute adaptive weight for each component of total loss
    #relative to the mean gradient of data_loss w.r.t layer weights
    boundary_loss_weight = torch.max(torch.abs(data_grads)) / torch.mean(torch.abs(bound_grads))
    init_loss_weight = torch.max(torch.abs(data_grads)) / torch.mean(torch.abs(init_grads))
    pde_loss_weight = torch.max(torch.abs(data_grads)) / torch.mean(torch.abs(pde_grads))
    data_loss_weight = torch.max(torch.abs(data_grads)) / torch.mean(torch.abs(data_grads))

    #Create total loss to update all network parameters
    total_loss = \
        (data_loss * data_loss_weight) + \
        (init_loss_weight * initial_loss) + \
        (pde_loss_weight * pde_loss) + \
        (boundary_loss_weight * boundary_loss)
    
    print(f"\t\tAfter adaption: Initial condition loss: {initial_loss * init_loss_weight}")
    print(f"\t\tAfter adaption: Boundary condition loss: {boundary_loss * boundary_loss_weight}")
    print(f"\t\tAfter adaption: PDE loss: {pde_loss * pde_loss_weight}")
    print(f"\t\tAfter adaption: Data loss: {data_loss * data_loss_weight}")

    if writer:
        writer.add_scalar('training_boundary_loss',boundary_loss,epoch)
        writer.add_scalar('training_init_loss',initial_loss,epoch)
        writer.add_scalar('training_pde_loss',pde_loss,epoch)
        writer.add_scalar('training_data_loss',data_loss,epoch)
        writer.add_scalar('training_weighted_boundary_loss',boundary_loss * boundary_loss_weight,epoch)
        writer.add_scalar('training_weighted_init_loss',initial_loss * init_loss_weight,epoch)
        writer.add_scalar('training_weighted_pde_loss',pde_loss * pde_loss_weight,epoch)
        writer.add_scalar('training_weighted_data_loss',data_loss * data_loss_weight,epoch)
        writer.add_scalar('training_boundary_loss_weight',boundary_loss_weight,epoch)
        writer.add_scalar('training_init_loss_weight',init_loss_weight,epoch)
        writer.add_scalar('training_pde_loss_weight',pde_loss_weight,epoch)
        writer.add_scalar('training_data_loss_weight',data_loss_weight,epoch)
        writer.add_scalar('training_data_mean_grad', torch.mean(torch.abs(data_grads)))
        writer.add_scalar('training_pde_mean_grad', torch.mean(torch.abs(pde_grads)))
        writer.add_scalar('training_init_mean_grad', torch.mean(torch.abs(init_grads)))
        writer.add_scalar('training_bound_mean_grad', torch.mean(torch.abs(bound_grads)))
        
    
    total_loss.backward()
    optimizer.step()

# %%
def combined_physics_data_loss(interior_pred, bound_pred, init_pred, interior_labels, bound_labels, init_labels, x_interior, t_interior):
    """_summary_

    Args:
        interior_pred (_type_): _description_
        bound_pred (_type_): _description_
        init_pred (_type_): _description_
        interior_labels (_type_): _description_
        bound_labels (_type_): _description_
        init_labels (_type_): _description_
        x_interior (_type_): _description_
        t_interior (_type_): _description_

    Returns:
        _type_: _description_
    """
    dudx = torch.autograd.grad(interior_pred.sum(), x_interior, retain_graph=True, create_graph=True)[0]
    dudt = torch.autograd.grad(interior_pred.sum(), t_interior, retain_graph=True, create_graph=True)[0]
    d2udt2 = torch.autograd.grad(dudt.sum(), t_interior, retain_graph=True, create_graph=True)[0]
    pde_values = (dudx * d2udt2) - dudt

    mse = torch.nn.MSELoss()
    pde_zeros = torch.zeros_like(pde_values)
    pde_loss = mse(pde_zeros,pde_values)

    initial_loss = mse(init_labels, init_pred)
    boundary_loss = mse(bound_labels, bound_pred)
    data_loss = mse(interior_pred, interior_labels)
    
    return boundary_loss, initial_loss, pde_loss, data_loss

# %%
def test_loop(x_bound, x_init, x_interior, t_bound, t_init, t_interior,labels_bound, labels_init, labels_interior, model, loss_fn, writer=None):
    
    interior_pred = model(x_interior, t_interior)
    bound_pred = model(x_bound, t_bound)
    init_pred = model(x_init, t_init)

    boundary_loss, initial_loss, pde_loss, data_loss = \
        loss_fn(
            interior_pred, bound_pred, init_pred, 
            labels_interior, labels_bound, labels_init, 
            x_interior, t_interior)
    
    if writer:
        writer.add_scalar('testing_boundary_loss',boundary_loss,epoch)
        writer.add_scalar('testing_init_loss',initial_loss,epoch)
        writer.add_scalar('testing_pde_loss',pde_loss,epoch)
        writer.add_scalar('testing_data_loss',data_loss,epoch)
    
    print(f"\n\tTesting: Initial condition loss: {initial_loss}")
    print(f"\tTesting: Boundary condition loss: {boundary_loss}")
    print(f"\tTesting: PDE loss: {pde_loss}")
    print(f"\tTesting: Data loss: {data_loss}")

# %%
x_interior_train.shape
# Out:
# (39200,)

# %%
#PINN Model setup
model = NeuralNetwork()
model.to(device)
loss_fn = combined_physics_data_loss
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

#Place reshaped input tensors with correct data-type and with calculation of derivatives enabled on available device
x_interior_train=torch.from_numpy(x_interior_train.reshape(x_interior_train.shape[0],1)).float().requires_grad_().to(device)
t_interior_train=torch.from_numpy(t_interior_train.reshape(t_interior_train.shape[0],1)).float().requires_grad_().to(device)
x_init_train=torch.from_numpy(x_init_train.reshape(x_init_train.shape[0],1)).float().requires_grad_().to(device)
t_init_train=torch.from_numpy(t_init_train.reshape(t_init_train.shape[0],1)).float().requires_grad_().to(device)
x_bound_train=torch.from_numpy(x_bound_train.reshape(x_bound_train.shape[0],1)).float().requires_grad_().to(device)
t_bound_train=torch.from_numpy(t_bound_train.reshape(t_bound_train.shape[0],1)).float().requires_grad_().to(device)
labels_bound_train=torch.from_numpy(labels_bound_train.reshape(labels_bound_train.shape[0],1)).float().requires_grad_().to(device)
labels_init_train=torch.from_numpy(labels_init_train.reshape(labels_init_train.shape[0],1)).float().requires_grad_().to(device)
labels_interior_train=torch.from_numpy(labels_interior_train.reshape(labels_interior_train.shape[0],1)).float().requires_grad_().to(device)

x_interior_test=torch.from_numpy(x_interior_test.reshape(x_interior_test.shape[0],1)).float().requires_grad_().to(device)
t_interior_test=torch.from_numpy(t_interior_test.reshape(t_interior_test.shape[0],1)).float().requires_grad_().to(device)
x_init_test=torch.from_numpy(x_init_test.reshape(x_init_test.shape[0],1)).float().requires_grad_().to(device)
t_init_test=torch.from_numpy(t_init_test.reshape(t_init_test.shape[0],1)).float().requires_grad_().to(device)
x_bound_test=torch.from_numpy(x_bound_test.reshape(x_bound_test.shape[0],1)).float().requires_grad_().to(device)
t_bound_test=torch.from_numpy(t_bound_test.reshape(t_bound_test.shape[0],1)).float().requires_grad_().to(device)
labels_bound_test=torch.from_numpy(labels_bound_test.reshape(labels_bound_test.shape[0],1)).float().requires_grad_().to(device)
labels_init_test=torch.from_numpy(labels_init_test.reshape(labels_init_test.shape[0],1)).float().requires_grad_().to(device)
labels_interior_test=torch.from_numpy(labels_interior_test.reshape(labels_interior_test.shape[0],1)).float().requires_grad_().to(device)

#Setup Tensorboard for QCs
tensorboard_dir_name = "weighting"
writer = SummaryWriter("runs/" + tensorboard_dir_name)

epochs = 300

for epoch in range(epochs):
    print(f"\nEpoch {epoch+1}\n-------------------------------")

    train_loop(
        x_bound_train, x_init_train, x_interior_train,
        t_bound_train, t_init_train, t_interior_train,
        labels_bound_train, labels_init_train, labels_interior_train,
        model, loss_fn, optimizer, writer)
    
    test_loop(
        x_bound_test, x_init_test, x_interior_test,\
        t_bound_test, t_init_test, t_interior_test,\
        labels_bound_test, labels_init_test, labels_interior_test,\
        model, loss_fn, writer)

print("\nTraining complete!\n")
# Out:
# Epoch 1
# -------------------------------
# 	Before adaption: Initial condition loss: 0.33418306708335876
# 	Before adaption: Boundary condition loss: 0.012285685166716576
# 	Before adaption: PDE loss: 2.7774618502007797e-05
# 	Before adaption: Data loss: 0.0767790675163269
# 		After adaption: Initial condition loss: 18.70688247680664
# 		After adaption: Boundary condition loss: 2.813751697540283
# 		After adaption: PDE loss: 0.4198339581489563
# 		After adaption: Data loss: 11.536905288696289
#
# 	Testing: Initial condition loss: 0.4554629325866699
# 	Testing: Boundary condition loss: 0.015380685217678547
# 	Testing: PDE loss: 2.5407707653357647e-05
# 	Testing: Data loss: 0.07284419983625412
#
# Epoch 2
# -------------------------------
# 	Before adaption: Initial condition loss: 0.3211636543273926
# 	Before adaption: Boundary condition loss: 0.015333497896790504
# 	Before adaption: PDE loss: 2.5425923013244756e-05
# 	Before adaption: Data loss: 0.07199454307556152
# 		After adaption: Initial condition loss: 17.730083465576172
# 		After adaption: Boundary condition loss: 3.0664103031158447
# 		After adaption: PDE loss: 0.31900930404663086
# 		After adaption: Data loss: 11.269180297851562
#
# 	Testing: Initial condition loss: 0.4381912350654602
# 	Testing: Boundary condition loss: 0.019002821296453476
# 	Testing: PDE loss: 1.5388706742669456e-05
# 	Testing: Data loss: 0.06852608919143677
#
# Epoch 3
# -------------------------------
# 	Before adaption: Initial condition loss: 0.30900004506111145
# 	Before adaption: Boundary condition loss: 0.018940724432468414
# 	Before adaption: PDE loss: 1.583869379828684e-05
# 	Before adaption: Data loss: 0.067684605717659
# 		After adaption: Initial condition loss: 17.01937484741211
# 		After adaption: Boundary condition loss: 3.16048264503479
# 		After adaption: PDE loss: 0.2852780520915985
# 		After adaption: Data loss: 11.490055084228516
#
# 	Testing: Initial condition loss: 0.421891987323761
# 	Testing: Boundary condition loss: 0.023173876106739044
# 	Testing: PDE loss: 9.874356692307629e-06
# 	Testing: Data loss: 0.06470762193202972
#
# Epoch 4
# -------------------------------
# 	Before adaption: Initial condition loss: 0.29760950803756714
# 	Before adaption: Boundary condition loss: 0.02310873195528984
# 	Before adaption: PDE loss: 1.0204839782090858e-05
# 	Before adaption: Data loss: 0.0638715848326683
# 		After adaption: Initial condition loss: 16.276065826416016
# 		After adaption: Boundary condition loss: 3.2516415119171143
# 		After adaption: PDE loss: 0.5969521999359131
# 		After adaption: Data loss: 11.356441497802734
#
# 	Testing: Initial condition loss: 0.40513771772384644
# 	Testing: Boundary condition loss: 0.027742326259613037
# 	Testing: PDE loss: 1.1732437087630387e-05
# 	Testing: Data loss: 0.06122332066297531
#
# Epoch 5
# -------------------------------
# 	Before adaption: Initial condition loss: 0.2859530448913574
# 	Before adaption: Boundary condition loss: 0.02768128365278244
# 	Before adaption: PDE loss: 1.203683677886147e-05
# 	Before adaption: Data loss: 0.06039322912693024
# 		After adaption: Initial condition loss: 14.469096183776855
# 		After adaption: Boundary condition loss: 3.227935552597046
# 		After adaption: PDE loss: 0.3307289779186249
# 		After adaption: Data loss: 10.893163681030273
#
# 	Testing: Initial condition loss: 0.3885279595851898
# 	Testing: Boundary condition loss: 0.03250093385577202
# 	Testing: PDE loss: 1.1448018994997256e-05
# 	Testing: Data loss: 0.058151837438344955
#
# Epoch 6
# -------------------------------
# 	Before adaption: Initial condition loss: 0.2745037078857422
# 	Before adaption: Boundary condition loss: 0.03243859112262726
# 	Before adaption: PDE loss: 1.1473769518488552e-05
# 	Before adaption: Data loss: 0.057329874485731125
# 		After adaption: Initial condition loss: 12.755608558654785
# 		After adaption: Boundary condition loss: 3.0885117053985596
# 		After adaption: PDE loss: 0.28521889448165894
# 		After adaption: Data loss: 10.443016052246094
#
# 	Testing: Initial condition loss: 0.3723343014717102
# 	Testing: Boundary condition loss: 0.03747360780835152
# 	Testing: PDE loss: 9.950082130671944e-06
# 	Testing: Data loss: 0.05545338988304138
#
# Epoch 7
# -------------------------------
# 	Before adaption: Initial condition loss: 0.26340678334236145
# 	Before adaption: Boundary condition loss: 0.037405017763376236
# 	Before adaption: PDE loss: 9.797309758141637e-06
# 	Before adaption: Data loss: 0.054640572518110275
# 		After adaption: Initial condition loss: 11.050627708435059
# 		After adaption: Boundary condition loss: 2.8855183124542236
# 		After adaption: PDE loss: 0.4688988924026489
# 		After adaption: Data loss: 9.93852710723877
#
# 	Testing: Initial condition loss: 0.3564816415309906
# 	Testing: Boundary condition loss: 0.042681984603405
# 	Testing: PDE loss: 1.104410785046639e-05
# 	Testing: Data loss: 0.05310894921422005
#
# Epoch 8
# -------------------------------
# 	Before adaption: Initial condition loss: 0.2527194023132324
# 	Before adaption: Boundary condition loss: 0.04259961470961571
# 	Before adaption: PDE loss: 1.1078574971179478e-05
# 	Before adaption: Data loss: 0.052304551005363464
# 		After adaption: Initial condition loss: 9.448359489440918
# 		After adaption: Boundary condition loss: 2.6363372802734375
# 		After adaption: PDE loss: 0.2772471010684967
# 		After adaption: Data loss: 9.506065368652344
#
# 	Testing: Initial condition loss: 0.3408552408218384
# 	Testing: Boundary condition loss: 0.04834027215838432
# 	Testing: PDE loss: 1.392600461258553e-05
# 	Testing: Data loss: 0.05108935385942459
#
# Epoch 9
# -------------------------------
# 	Before adaption: Initial condition loss: 0.2423110008239746
# 	Before adaption: Boundary condition loss: 0.04824503883719444
# 	Before adaption: PDE loss: 1.4132002434052993e-05
# 	Before adaption: Data loss: 0.05029292404651642
# 		After adaption: Initial condition loss: 7.777647495269775
# 		After adaption: Boundary condition loss: 2.400092124938965
# 		After adaption: PDE loss: 0.16852737963199615
# 		After adaption: Data loss: 8.920166969299316
#
# 	Testing: Initial condition loss: 0.3255579173564911
# 	Testing: Boundary condition loss: 0.054424773901700974
# 	Testing: PDE loss: 1.542968129797373e-05
# 	Testing: Data loss: 0.04942290484905243
#
# Epoch 10
# -------------------------------
# 	Before adaption: Initial condition loss: 0.23229873180389404
# 	Before adaption: Boundary condition loss: 0.054317545145750046
# 	Before adaption: PDE loss: 1.5539329979219474e-05
# 	Before adaption: Data loss: 0.04863610863685608
# 		After adaption: Initial condition loss: 6.302002906799316
# 		After adaption: Boundary condition loss: 2.007133960723877
# 		After adaption: PDE loss: 0.12419064342975616
# 		After adaption: Data loss: 8.72543716430664
#
# 	Testing: Initial condition loss: 0.31099358201026917
# 	Testing: Boundary condition loss: 0.06071030721068382
# 	Testing: PDE loss: 1.6091473298729397e-05
# 	Testing: Data loss: 0.04816511645913124
#
# Epoch 11
# -------------------------------
# 	Before adaption: Initial condition loss: 0.22281022369861603
# 	Before adaption: Boundary condition loss: 0.06059464067220688
# 	Before adaption: PDE loss: 1.612875894352328e-05
# 	Before adaption: Data loss: 0.04739109054207802
# 		After adaption: Initial condition loss: 4.70615816116333
# 		After adaption: Boundary condition loss: 1.6742647886276245
# 		After adaption: PDE loss: 0.09137427061796188
# 		After adaption: Data loss: 7.8502397537231445
#
# 	Testing: Initial condition loss: 0.2971555292606354
# 	Testing: Boundary condition loss: 0.06706613302230835
# 	Testing: PDE loss: 1.8552485926193185e-05
# 	Testing: Data loss: 0.04729299247264862
#
# Epoch 12
# -------------------------------
# 	Before adaption: Initial condition loss: 0.2141234576702118
# 	Before adaption: Boundary condition loss: 0.0669461041688919
# 	Before adaption: PDE loss: 1.8626793462317437e-05
# 	Before adaption: Data loss: 0.04652915894985199
# 		After adaption: Initial condition loss: 3.206894874572754
# 		After adaption: Boundary condition loss: 1.1825027465820312
# 		After adaption: PDE loss: 0.0631229355931282
# 		After adaption: Data loss: 6.833939552307129
#
# 	Testing: Initial condition loss: 0.28466615080833435
# 	Testing: Boundary condition loss: 0.07363580912351608
# 	Testing: PDE loss: 2.0039491573697887e-05
# 	Testing: Data loss: 0.046840135008096695
#
# Epoch 13
# -------------------------------
# 	Before adaption: Initial condition loss: 0.20632393658161163
# 	Before adaption: Boundary condition loss: 0.07350694388151169
# 	Before adaption: PDE loss: 2.001837310672272e-05
# 	Before adaption: Data loss: 0.046085767447948456
# 		After adaption: Initial condition loss: 1.7806808948516846
# 		After adaption: Boundary condition loss: 0.6616740822792053
# 		After adaption: PDE loss: 0.03424118831753731
# 		After adaption: Data loss: 4.930145740509033
#
# 	Testing: Initial condition loss: 0.27333977818489075
# 	Testing: Boundary condition loss: 0.08013344556093216
# 	Testing: PDE loss: 2.0194478565827012e-05
# 	Testing: Data loss: 0.04674649238586426
#
# Epoch 14
# -------------------------------
# 	Before adaption: Initial condition loss: 0.19950421154499054
# 	Before adaption: Boundary condition loss: 0.0799885094165802
# 	Before adaption: PDE loss: 2.0365039745229296e-05
# 	Before adaption: Data loss: 0.04600020870566368
# 		After adaption: Initial condition loss: 0.6622796058654785
# 		After adaption: Boundary condition loss: 0.2526583969593048
# 		After adaption: PDE loss: 0.012662830762565136
# 		After adaption: Data loss: 1.9481995105743408
#
# 	Testing: Initial condition loss: 0.2635000944137573
# 	Testing: Boundary condition loss: 0.08639015257358551
# 	Testing: PDE loss: 1.903462725749705e-05
# 	Testing: Data loss: 0.046923715621232986
#
# Epoch 15
# -------------------------------
# 	Before adaption: Initial condition loss: 0.19353315234184265
# 	Before adaption: Boundary condition loss: 0.08623020350933075
# 	Before adaption: PDE loss: 1.9115133909508586e-05
# 	Before adaption: Data loss: 0.04618365317583084
# 		After adaption: Initial condition loss: 1.357672929763794
# 		After adaption: Boundary condition loss: 0.5245774388313293
# 		After adaption: PDE loss: 0.025480326265096664
# 		After adaption: Data loss: 3.2117128372192383
#
# 	Testing: Initial condition loss: 0.25473377108573914
# 	Testing: Boundary condition loss: 0.0922260656952858
# 	Testing: PDE loss: 1.7487287550466135e-05
# 	Testing: Data loss: 0.04726431518793106
#
# Epoch 16
# -------------------------------
# 	Before adaption: Initial condition loss: 0.18834276497364044
# 	Before adaption: Boundary condition loss: 0.09205437451601028
# 	Before adaption: PDE loss: 1.7505668438388966e-05
# 	Before adaption: Data loss: 0.04652942344546318
# 		After adaption: Initial condition loss: 2.4799060821533203
# 		After adaption: Boundary condition loss: 0.9857538938522339
# 		After adaption: PDE loss: 0.04576072469353676
# 		After adaption: Data loss: 4.71824312210083
#
# 	Testing: Initial condition loss: 0.2471894770860672
# 	Testing: Boundary condition loss: 0.09733447432518005
# 	Testing: PDE loss: 1.5199917470454238e-05
# 	Testing: Data loss: 0.047685157507658005
#
# Epoch 17
# -------------------------------
# 	Before adaption: Initial condition loss: 0.18394644558429718
# 	Before adaption: Boundary condition loss: 0.09714553505182266
# 	Before adaption: PDE loss: 1.5231273209792562e-05
# 	Before adaption: Data loss: 0.04695338383316994
# 		After adaption: Initial condition loss: 3.4506139755249023
# 		After adaption: Boundary condition loss: 1.4342488050460815
# 		After adaption: PDE loss: 0.062449291348457336
# 		After adaption: Data loss: 5.570415019989014
#
# 	Testing: Initial condition loss: 0.2411753237247467
# 	Testing: Boundary condition loss: 0.10143930464982986
# 	Testing: PDE loss: 1.3397684597293846e-05
# 	Testing: Data loss: 0.04810985177755356
#
# Epoch 18
# -------------------------------
# 	Before adaption: Initial condition loss: 0.18043485283851624
# 	Before adaption: Boundary condition loss: 0.10124636441469193
# 	Before adaption: PDE loss: 1.3473883882397786e-05
# 	Before adaption: Data loss: 0.04738214239478111
# 		After adaption: Initial condition loss: 4.243453502655029
# 		After adaption: Boundary condition loss: 1.8284112215042114
# 		After adaption: PDE loss: 0.08037868142127991
# 		After adaption: Data loss: 6.152098655700684
#
# 	Testing: Initial condition loss: 0.23685862123966217
# 	Testing: Boundary condition loss: 0.10439744591712952
# 	Testing: PDE loss: 1.1843140782730188e-05
# 	Testing: Data loss: 0.04846677556633949
#
# Epoch 19
# -------------------------------
# 	Before adaption: Initial condition loss: 0.1778869926929474
# 	Before adaption: Boundary condition loss: 0.10420353710651398
# 	Before adaption: PDE loss: 1.1711265869962517e-05
# 	Before adaption: Data loss: 0.04774307459592819
# 		After adaption: Initial condition loss: 4.869799613952637
# 		After adaption: Boundary condition loss: 2.144958019256592
# 		After adaption: PDE loss: 0.09992150217294693
# 		After adaption: Data loss: 6.6611247062683105
#
# 	Testing: Initial condition loss: 0.23419064283370972
# 	Testing: Boundary condition loss: 0.10620665550231934
# 	Testing: PDE loss: 1.005914145935094e-05
# 	Testing: Data loss: 0.048715926706790924
#
# Epoch 20
# -------------------------------
# 	Before adaption: Initial condition loss: 0.1763489842414856
# 	Before adaption: Boundary condition loss: 0.10602016746997833
# 	Before adaption: PDE loss: 9.838970072451048e-06
# 	Before adaption: Data loss: 0.047995779663324356
# 		After adaption: Initial condition loss: 5.318998336791992
# 		After adaption: Boundary condition loss: 2.356106758117676
# 		After adaption: PDE loss: 0.12379106879234314
# 		After adaption: Data loss: 7.059218406677246
#
# 	Testing: Initial condition loss: 0.23313836753368378
# 	Testing: Boundary condition loss: 0.10686241835355759
# 	Testing: PDE loss: 7.874332368373871e-06
# 	Testing: Data loss: 0.0488455705344677
#
# Epoch 21
# -------------------------------
# 	Before adaption: Initial condition loss: 0.1757848709821701
# 	Before adaption: Boundary condition loss: 0.10669057816267014
# 	Before adaption: PDE loss: 7.660723895241972e-06
# 	Before adaption: Data loss: 0.04812755808234215
# 		After adaption: Initial condition loss: 5.506361484527588
# 		After adaption: Boundary condition loss: 2.4459776878356934
# 		After adaption: PDE loss: 0.1771637350320816
# 		After adaption: Data loss: 7.14127254486084
#
# 	Testing: Initial condition loss: 0.23363904654979706
# 	Testing: Boundary condition loss: 0.10642699897289276
# 	Testing: PDE loss: 6.397786364686908e-06
# 	Testing: Data loss: 0.048839908093214035
#
# Epoch 22
# -------------------------------
# 	Before adaption: Initial condition loss: 0.17607852816581726
# 	Before adaption: Boundary condition loss: 0.1062755361199379
# 	Before adaption: PDE loss: 6.246378688956611e-06
# 	Before adaption: Data loss: 0.048122696578502655
# 		After adaption: Initial condition loss: 5.477788925170898
# 		After adaption: Boundary condition loss: 2.4204347133636475
# 		After adaption: PDE loss: 0.35353830456733704
# 		After adaption: Data loss: 7.08369255065918
#
# 	Testing: Initial condition loss: 0.23550228774547577
# 	Testing: Boundary condition loss: 0.10480407625436783
# 	Testing: PDE loss: 5.375994533096673e-06
# 	Testing: Data loss: 0.04861341789364815
#
# Epoch 23
# -------------------------------
# 	Before adaption: Initial condition loss: 0.1771223396062851
# 	Before adaption: Boundary condition loss: 0.1046711727976799
# 	Before adaption: PDE loss: 5.2851155487587675e-06
# 	Before adaption: Data loss: 0.04789672791957855
# 		After adaption: Initial condition loss: 5.288088798522949
# 		After adaption: Boundary condition loss: 2.308696746826172
# 		After adaption: PDE loss: 0.37446853518486023
# 		After adaption: Data loss: 7.0377326011657715
#
# 	Testing: Initial condition loss: 0.23845306038856506
# 	Testing: Boundary condition loss: 0.1022351086139679
# 	Testing: PDE loss: 5.265346771921031e-06
# 	Testing: Data loss: 0.04822702333331108
#
# Epoch 24
# -------------------------------
# 	Before adaption: Initial condition loss: 0.17879614233970642
# 	Before adaption: Boundary condition loss: 0.10211528837680817
# 	Before adaption: PDE loss: 5.2540867727657314e-06
# 	Before adaption: Data loss: 0.04751018434762955
# 		After adaption: Initial condition loss: 4.831824779510498
# 		After adaption: Boundary condition loss: 2.1113760471343994
# 		After adaption: PDE loss: 0.14585253596305847
# 		After adaption: Data loss: 6.910769462585449
#
# 	Testing: Initial condition loss: 0.2422132045030594
# 	Testing: Boundary condition loss: 0.09925998002290726
# 	Testing: PDE loss: 5.463346951728454e-06
# 	Testing: Data loss: 0.04784318804740906
#
# Epoch 25
# -------------------------------
# 	Before adaption: Initial condition loss: 0.1809547394514084
# 	Before adaption: Boundary condition loss: 0.09915013611316681
# 	Before adaption: PDE loss: 5.488671831699321e-06
# 	Before adaption: Data loss: 0.047125671058893204
# 		After adaption: Initial condition loss: 4.29979133605957
# 		After adaption: Boundary condition loss: 1.8773027658462524
# 		After adaption: PDE loss: 0.08416689932346344
# 		After adaption: Data loss: 6.869970321655273
#
# 	Testing: Initial condition loss: 0.24654053151607513
# 	Testing: Boundary condition loss: 0.09606671333312988
# 	Testing: PDE loss: 5.510494247573661e-06
# 	Testing: Data loss: 0.047501809895038605
#
# Epoch 26
# -------------------------------
# 	Before adaption: Initial condition loss: 0.18346582353115082
# 	Before adaption: Boundary condition loss: 0.09596854448318481
# 	Before adaption: PDE loss: 5.5804880503274035e-06
# 	Before adaption: Data loss: 0.046782877296209335
# 		After adaption: Initial condition loss: 3.776780366897583
# 		After adaption: Boundary condition loss: 1.612969994544983
# 		After adaption: PDE loss: 0.0648074522614479
# 		After adaption: Data loss: 6.670623779296875
#
# 	Testing: Initial condition loss: 0.2511914074420929
# 	Testing: Boundary condition loss: 0.09278970956802368
# 	Testing: PDE loss: 5.38921267434489e-06
# 	Testing: Data loss: 0.04720667377114296
#
# Epoch 27
# -------------------------------
# 	Before adaption: Initial condition loss: 0.18617090582847595
# 	Before adaption: Boundary condition loss: 0.09270361810922623
# 	Before adaption: PDE loss: 5.470976702781627e-06
# 	Before adaption: Data loss: 0.04648629203438759
# 		After adaption: Initial condition loss: 3.1702466011047363
# 		After adaption: Boundary condition loss: 1.3304636478424072
# 		After adaption: PDE loss: 0.0518970713019371
# 		After adaption: Data loss: 6.347399711608887
#
# 	Testing: Initial condition loss: 0.2559499442577362
# 	Testing: Boundary condition loss: 0.08955206722021103
# 	Testing: PDE loss: 5.325434813130414e-06
# 	Testing: Data loss: 0.04696548730134964
#
# Epoch 28
# -------------------------------
# 	Before adaption: Initial condition loss: 0.18894729018211365
# 	Before adaption: Boundary condition loss: 0.08947202563285828
# 	Before adaption: PDE loss: 5.361177500162739e-06
# 	Before adaption: Data loss: 0.046243131160736084
# 		After adaption: Initial condition loss: 2.5684821605682373
# 		After adaption: Boundary condition loss: 1.0565073490142822
# 		After adaption: PDE loss: 0.04201239347457886
# 		After adaption: Data loss: 5.849186897277832
#
# 	Testing: Initial condition loss: 0.2606360912322998
# 	Testing: Boundary condition loss: 0.08644842356443405
# 	Testing: PDE loss: 5.257003977021668e-06
# 	Testing: Data loss: 0.04678170382976532
#
# Epoch 29
# -------------------------------
# 	Before adaption: Initial condition loss: 0.19171404838562012
# 	Before adaption: Boundary condition loss: 0.08637385070323944
# 	Before adaption: PDE loss: 5.334703018888831e-06
# 	Before adaption: Data loss: 0.046057529747486115
# 		After adaption: Initial condition loss: 1.9743318557739258
# 		After adaption: Boundary condition loss: 0.7992063164710999
# 		After adaption: PDE loss: 0.0334896482527256
# 		After adaption: Data loss: 5.193927764892578
#
# 	Testing: Initial condition loss: 0.26513588428497314
# 	Testing: Boundary condition loss: 0.08354347944259644
# 	Testing: PDE loss: 5.147894171386724e-06
# 	Testing: Data loss: 0.04665570333600044
#
# Epoch 30
# -------------------------------
# 	Before adaption: Initial condition loss: 0.19439855217933655
# 	Before adaption: Boundary condition loss: 0.08347403258085251
# 	Before adaption: PDE loss: 5.16699583386071e-06
# 	Before adaption: Data loss: 0.04592948779463768
# 		After adaption: Initial condition loss: 1.4004603624343872
# 		After adaption: Boundary condition loss: 0.5581173300743103
# 		After adaption: PDE loss: 0.02438894659280777
# 		After adaption: Data loss: 4.2267279624938965
#
# 	Testing: Initial condition loss: 0.2693592309951782
# 	Testing: Boundary condition loss: 0.08089213073253632
# 	Testing: PDE loss: 4.930836894345703e-06
# 	Testing: Data loss: 0.046582385897636414
#
# Epoch 31
# -------------------------------
# 	Before adaption: Initial condition loss: 0.1969362050294876
# 	Before adaption: Boundary condition loss: 0.08082602173089981
# 	Before adaption: PDE loss: 4.881959284830373e-06
# 	Before adaption: Data loss: 0.04585389420390129
# 		After adaption: Initial condition loss: 0.8533194661140442
# 		After adaption: Boundary condition loss: 0.3377039134502411
# 		After adaption: PDE loss: 0.015244981274008751
# 		After adaption: Data loss: 2.9606637954711914
#
# 	Testing: Initial condition loss: 0.27323228120803833
# 	Testing: Boundary condition loss: 0.07852577418088913
# 	Testing: PDE loss: 4.581006123771658e-06
# 	Testing: Data loss: 0.04655379801988602
#
# Epoch 32
# -------------------------------
# 	Before adaption: Initial condition loss: 0.19929108023643494
# 	Before adaption: Boundary condition loss: 0.07846146821975708
# 	Before adaption: PDE loss: 4.55377221442177e-06
# 	Before adaption: Data loss: 0.04582268372178078
# 		After adaption: Initial condition loss: 0.5942147374153137
# 		After adaption: Boundary condition loss: 0.23337672650814056
# 		After adaption: PDE loss: 0.010750144720077515
# 		After adaption: Data loss: 2.226978302001953
#
# 	Testing: Initial condition loss: 0.27675172686576843
# 	Testing: Boundary condition loss: 0.07642718404531479
# 	Testing: PDE loss: 4.2961987674061675e-06
# 	Testing: Data loss: 0.046558380126953125
#
# Epoch 33
# -------------------------------
# 	Before adaption: Initial condition loss: 0.20144768059253693
# 	Before adaption: Boundary condition loss: 0.0763644203543663
# 	Before adaption: PDE loss: 4.2445658436918166e-06
# 	Before adaption: Data loss: 0.045824673026800156
# 		After adaption: Initial condition loss: 0.7879366874694824
# 		After adaption: Boundary condition loss: 0.30959200859069824
# 		After adaption: PDE loss: 0.014588325284421444
# 		After adaption: Data loss: 3.052253484725952
#
# 	Testing: Initial condition loss: 0.27989813685417175
# 	Testing: Boundary condition loss: 0.07457968592643738
# 	Testing: PDE loss: 4.091557002539048e-06
# 	Testing: Data loss: 0.046584196388721466
#
# Epoch 34
# -------------------------------
# 	Before adaption: Initial condition loss: 0.20339247584342957
# 	Before adaption: Boundary condition loss: 0.07452023029327393
# 	Before adaption: PDE loss: 4.033526693092426e-06
# 	Before adaption: Data loss: 0.045848120003938675
# 		After adaption: Initial condition loss: 1.1798263788223267
# 		After adaption: Boundary condition loss: 0.4624517261981964
# 		After adaption: PDE loss: 0.02270377054810524
# 		After adaption: Data loss: 4.493592739105225
#
# 	Testing: Initial condition loss: 0.2826102674007416
# 	Testing: Boundary condition loss: 0.07299313694238663
# 	Testing: PDE loss: 3.873945388477296e-06
# 	Testing: Data loss: 0.04661925509572029
#
# Epoch 35
# -------------------------------
# 	Before adaption: Initial condition loss: 0.2050791233778
# 	Before adaption: Boundary condition loss: 0.07293590903282166
# 	Before adaption: PDE loss: 3.835644292848883e-06
# 	Before adaption: Data loss: 0.045881304889917374
# 		After adaption: Initial condition loss: 1.5139434337615967
# 		After adaption: Boundary condition loss: 0.5897316932678223
# 		After adaption: PDE loss: 0.02979438193142414
# 		After adaption: Data loss: 5.483346462249756
#
# 	Testing: Initial condition loss: 0.28483662009239197
# 	Testing: Boundary condition loss: 0.07168741524219513
# 	Testing: PDE loss: 3.6777039440494264e-06
# 	Testing: Data loss: 0.046652261167764664
#
# Epoch 36
# -------------------------------
# 	Before adaption: Initial condition loss: 0.20645014941692352
# 	Before adaption: Boundary condition loss: 0.0716313049197197
# 	Before adaption: PDE loss: 3.616496314862161e-06
# 	Before adaption: Data loss: 0.04591326415538788
# 		After adaption: Initial condition loss: 1.7857681512832642
# 		After adaption: Boundary condition loss: 0.6902841925621033
# 		After adaption: PDE loss: 0.035746268928050995
# 		After adaption: Data loss: 6.115929126739502
#
# 	Testing: Initial condition loss: 0.28650492429733276
# 	Testing: Boundary condition loss: 0.07068058848381042
# 	Testing: PDE loss: 3.431510094742407e-06
# 	Testing: Data loss: 0.046673957258462906
#
# Epoch 37
# -------------------------------
# 	Before adaption: Initial condition loss: 0.20746326446533203
# 	Before adaption: Boundary condition loss: 0.07062408328056335
# 	Before adaption: PDE loss: 3.3282519780186703e-06
# 	Before adaption: Data loss: 0.04593459144234657
# 		After adaption: Initial condition loss: 1.984434723854065
# 		After adaption: Boundary condition loss: 0.7641088962554932
# 		After adaption: PDE loss: 0.040200844407081604
# 		After adaption: Data loss: 6.5508198738098145
#
# 	Testing: Initial condition loss: 0.2875719666481018
# 	Testing: Boundary condition loss: 0.06998151540756226
# 	Testing: PDE loss: 3.126998535663006e-06
# 	Testing: Data loss: 0.046678535640239716
#
# Epoch 38
# -------------------------------
# 	Before adaption: Initial condition loss: 0.20809385180473328
# 	Before adaption: Boundary condition loss: 0.0699242502450943
# 	Before adaption: PDE loss: 3.012819888681406e-06
# 	Before adaption: Data loss: 0.045939669013023376
# 		After adaption: Initial condition loss: 2.1151044368743896
# 		After adaption: Boundary condition loss: 0.8120091557502747
# 		After adaption: PDE loss: 0.043165504932403564
# 		After adaption: Data loss: 6.909615516662598
#
# 	Testing: Initial condition loss: 0.28803756833076477
# 	Testing: Boundary condition loss: 0.06959184259176254
# 	Testing: PDE loss: 2.8147453576821135e-06
# 	Testing: Data loss: 0.04666472598910332
#
# Epoch 39
# -------------------------------
# 	Before adaption: Initial condition loss: 0.20834004878997803
# 	Before adaption: Boundary condition loss: 0.06953320652246475
# 	Before adaption: PDE loss: 2.7519897685124306e-06
# 	Before adaption: Data loss: 0.04592714086174965
# 		After adaption: Initial condition loss: 2.1958229541778564
# 		After adaption: Boundary condition loss: 0.833543598651886
# 		After adaption: PDE loss: 0.0460364930331707
# 		After adaption: Data loss: 7.216629981994629
#
# 	Testing: Initial condition loss: 0.28791096806526184
# 	Testing: Boundary condition loss: 0.06950543075799942
# 	Testing: PDE loss: 2.6206191705568926e-06
# 	Testing: Data loss: 0.04663551226258278
#
# Epoch 40
# -------------------------------
# 	Before adaption: Initial condition loss: 0.20822235941886902
# 	Before adaption: Boundary condition loss: 0.06944403052330017
# 	Before adaption: PDE loss: 2.618448434077436e-06
# 	Before adaption: Data loss: 0.04589947685599327
# 		After adaption: Initial condition loss: 2.191330671310425
# 		After adaption: Boundary condition loss: 0.8305028080940247
# 		After adaption: PDE loss: 0.051713742315769196
# 		After adaption: Data loss: 7.417200088500977
#
# 	Testing: Initial condition loss: 0.2872875928878784
# 	Testing: Boundary condition loss: 0.06970010697841644
# 	Testing: PDE loss: 2.4931368898251094e-06
# 	Testing: Data loss: 0.04659462347626686
#
# Epoch 41
# -------------------------------
# 	Before adaption: Initial condition loss: 0.20776978135108948
# 	Before adaption: Boundary condition loss: 0.0696367546916008
# 	Before adaption: PDE loss: 2.4976466193038505e-06
# 	Before adaption: Data loss: 0.04586047679185867
# 		After adaption: Initial condition loss: 2.1379330158233643
# 		After adaption: Boundary condition loss: 0.8035973906517029
# 		After adaption: PDE loss: 0.06159519404172897
# 		After adaption: Data loss: 7.417060375213623
#
# 	Testing: Initial condition loss: 0.2862168252468109
# 	Testing: Boundary condition loss: 0.0701446533203125
# 	Testing: PDE loss: 2.396493528067367e-06
# 	Testing: Data loss: 0.04654448479413986
#
# Epoch 42
# -------------------------------
# 	Before adaption: Initial condition loss: 0.20704145729541779
# 	Before adaption: Boundary condition loss: 0.07008027285337448
# 	Before adaption: PDE loss: 2.391589760009083e-06
# 	Before adaption: Data loss: 0.045812323689460754
# 		After adaption: Initial condition loss: 2.026937961578369
# 		After adaption: Boundary condition loss: 0.7564660310745239
# 		After adaption: PDE loss: 0.07777165621519089
# 		After adaption: Data loss: 7.1521806716918945
#
# 	Testing: Initial condition loss: 0.28477370738983154
# 	Testing: Boundary condition loss: 0.0707872211933136
# 	Testing: PDE loss: 2.272084202559199e-06
# 	Testing: Data loss: 0.04648539796471596
#
# Epoch 43
# -------------------------------
# 	Before adaption: Initial condition loss: 0.2060844451189041
# 	Before adaption: Boundary condition loss: 0.07072153687477112
# 	Before adaption: PDE loss: 2.2670953967462992e-06
# 	Before adaption: Data loss: 0.045755255967378616
# 		After adaption: Initial condition loss: 1.868118405342102
# 		After adaption: Boundary condition loss: 0.6941323280334473
# 		After adaption: PDE loss: 0.08848043531179428
# 		After adaption: Data loss: 6.7225661277771
#
# 	Testing: Initial condition loss: 0.2830796539783478
# 	Testing: Boundary condition loss: 0.07154916971921921
# 	Testing: PDE loss: 2.175302370233112e-06
# 	Testing: Data loss: 0.046417899429798126
#
# Epoch 44
# -------------------------------
# 	Before adaption: Initial condition loss: 0.2049737423658371
# 	Before adaption: Boundary condition loss: 0.0714779645204544
# 	Before adaption: PDE loss: 2.188607368225348e-06
# 	Before adaption: Data loss: 0.04568949341773987
# 		After adaption: Initial condition loss: 1.676863193511963
# 		After adaption: Boundary condition loss: 0.6228810548782349
# 		After adaption: PDE loss: 0.09013280272483826
# 		After adaption: Data loss: 6.194993495941162
#
# 	Testing: Initial condition loss: 0.28130748867988586
# 	Testing: Boundary condition loss: 0.0723576694726944
# 	Testing: PDE loss: 2.1014052435930353e-06
# 	Testing: Data loss: 0.0463448241353035
#
# Epoch 45
# -------------------------------
# 	Before adaption: Initial condition loss: 0.20379438996315002
# 	Before adaption: Boundary condition loss: 0.07227783650159836
# 	Before adaption: PDE loss: 2.121869783877628e-06
# 	Before adaption: Data loss: 0.045618411153554916
# 		After adaption: Initial condition loss: 1.472170352935791
# 		After adaption: Boundary condition loss: 0.5467418432235718
# 		After adaption: PDE loss: 0.06752784550189972
# 		After adaption: Data loss: 5.614620685577393
#
# 	Testing: Initial condition loss: 0.2795293927192688
# 	Testing: Boundary condition loss: 0.07316864281892776
# 	Testing: PDE loss: 2.009774334510439e-06
# 	Testing: Data loss: 0.04627539962530136
#
# Epoch 46
# -------------------------------
# 	Before adaption: Initial condition loss: 0.20263031125068665
# 	Before adaption: Boundary condition loss: 0.07308000326156616
# 	Before adaption: PDE loss: 2.041521156570525e-06
# 	Before adaption: Data loss: 0.04555000364780426
# 		After adaption: Initial condition loss: 1.2656068801879883
# 		After adaption: Boundary condition loss: 0.4701816737651825
# 		After adaption: PDE loss: 0.03708408400416374
# 		After adaption: Data loss: 4.9291205406188965
#
# 	Testing: Initial condition loss: 0.27780380845069885
# 	Testing: Boundary condition loss: 0.07395307719707489
# 	Testing: PDE loss: 2.0090794805582846e-06
# 	Testing: Data loss: 0.04621302708983421
#
# Epoch 47
# -------------------------------
# 	Before adaption: Initial condition loss: 0.2015203982591629
# 	Before adaption: Boundary condition loss: 0.07385562360286713
# 	Before adaption: PDE loss: 2.0301285985624418e-06
# 	Before adaption: Data loss: 0.0454878993332386
# 		After adaption: Initial condition loss: 1.060380220413208
# 		After adaption: Boundary condition loss: 0.3949587345123291
# 		After adaption: PDE loss: 0.021419022232294083
# 		After adaption: Data loss: 4.147114276885986
#
# 	Testing: Initial condition loss: 0.27617356181144714
# 	Testing: Boundary condition loss: 0.07468851655721664
# 	Testing: PDE loss: 2.11144947570574e-06
# 	Testing: Data loss: 0.04615839198231697
#
# Epoch 48
# -------------------------------
# 	Before adaption: Initial condition loss: 0.20048871636390686
# 	Before adaption: Boundary condition loss: 0.07458258420228958
# 	Before adaption: PDE loss: 2.1161270069569582e-06
# 	Before adaption: Data loss: 0.04543357715010643
# 		After adaption: Initial condition loss: 0.8673192858695984
# 		After adaption: Boundary condition loss: 0.32293814420700073
# 		After adaption: PDE loss: 0.013575103133916855
# 		After adaption: Data loss: 3.3763484954833984
#
# 	Testing: Initial condition loss: 0.274675190448761
# 	Testing: Boundary condition loss: 0.07536105066537857
# 	Testing: PDE loss: 2.3700915789959254e-06
# 	Testing: Data loss: 0.046111129224300385
#
# Epoch 49
# -------------------------------
# 	Before adaption: Initial condition loss: 0.19954389333724976
# 	Before adaption: Boundary condition loss: 0.07524720579385757
# 	Before adaption: PDE loss: 2.3541499558632495e-06
# 	Before adaption: Data loss: 0.04538615047931671
# 		After adaption: Initial condition loss: 0.6937713623046875
# 		After adaption: Boundary condition loss: 0.25868502259254456
# 		After adaption: PDE loss: 0.009460316970944405
# 		After adaption: Data loss: 2.659240961074829
#
# 	Testing: Initial condition loss: 0.27332624793052673
# 	Testing: Boundary condition loss: 0.07596403360366821
# 	Testing: PDE loss: 2.692876023502322e-06
# 	Testing: Data loss: 0.0460696704685688
#
# Epoch 50
# -------------------------------
# 	Before adaption: Initial condition loss: 0.19868670403957367
# 	Before adaption: Boundary condition loss: 0.07584282755851746
# 	Before adaption: PDE loss: 2.6944655928673455e-06
# 	Before adaption: Data loss: 0.0453445129096508
# 		After adaption: Initial condition loss: 0.6032274961471558
# 		After adaption: Boundary condition loss: 0.22513514757156372
# 		After adaption: PDE loss: 0.007719101384282112
# 		After adaption: Data loss: 2.2637887001037598
#
# 	Testing: Initial condition loss: 0.2721191942691803
# 	Testing: Boundary condition loss: 0.07648483663797379
# 	Testing: PDE loss: 3.085156095039565e-06
# 	Testing: Data loss: 0.04603209346532822
#
# Epoch 51
# -------------------------------
# 	Before adaption: Initial condition loss: 0.1979120969772339
# 	Before adaption: Boundary condition loss: 0.0763566642999649
# 	Before adaption: PDE loss: 3.114870423814864e-06
# 	Before adaption: Data loss: 0.045307014137506485
# 		After adaption: Initial condition loss: 0.5519171357154846
# 		After adaption: Boundary condition loss: 0.20619644224643707
# 		After adaption: PDE loss: 0.006965089123696089
# 		After adaption: Data loss: 2.0255420207977295
#
# 	Testing: Initial condition loss: 0.27105942368507385
# 	Testing: Boundary condition loss: 0.07692057639360428
# 	Testing: PDE loss: 3.5499883779266383e-06
# 	Testing: Data loss: 0.04599614441394806
#
# Epoch 52
# -------------------------------
# 	Before adaption: Initial condition loss: 0.1972118318080902
# 	Before adaption: Boundary condition loss: 0.07678668200969696
# 	Before adaption: PDE loss: 3.5754105738305952e-06
# 	Before adaption: Data loss: 0.04527120664715767
# 		After adaption: Initial condition loss: 0.5886545181274414
# 		After adaption: Boundary condition loss: 0.22105829417705536
# 		After adaption: PDE loss: 0.007545663043856621
# 		After adaption: Data loss: 2.118443489074707
#
# 	Testing: Initial condition loss: 0.27013587951660156
# 	Testing: Boundary condition loss: 0.07726168632507324
# 	Testing: PDE loss: 4.015831109427381e-06
# 	Testing: Data loss: 0.04595859348773956
#
# Epoch 53
# -------------------------------
# 	Before adaption: Initial condition loss: 0.19658586382865906
# 	Before adaption: Boundary condition loss: 0.07712263613939285
# 	Before adaption: PDE loss: 4.047748006996699e-06
# 	Before adaption: Data loss: 0.04523409530520439
# 		After adaption: Initial condition loss: 0.6262978911399841
# 		After adaption: Boundary condition loss: 0.2349974513053894
# 		After adaption: PDE loss: 0.00823549646884203
# 		After adaption: Data loss: 2.207496404647827
#
# 	Testing: Initial condition loss: 0.269335001707077
# 	Testing: Boundary condition loss: 0.07749836891889572
# 	Testing: PDE loss: 4.459676802071044e-06
# 	Testing: Data loss: 0.04591712728142738
#
# Epoch 54
# -------------------------------
# 	Before adaption: Initial condition loss: 0.19603851437568665
# 	Before adaption: Boundary condition loss: 0.07735535502433777
# 	Before adaption: PDE loss: 4.499992883211235e-06
# 	Before adaption: Data loss: 0.045193079859018326
# 		After adaption: Initial condition loss: 0.6619787216186523
# 		After adaption: Boundary condition loss: 0.2491397261619568
# 		After adaption: PDE loss: 0.009019505232572556
# 		After adaption: Data loss: 2.2954282760620117
#
# 	Testing: Initial condition loss: 0.2686588168144226
# 	Testing: Boundary condition loss: 0.07763756066560745
# 	Testing: PDE loss: 4.88151681565796e-06
# 	Testing: Data loss: 0.045869313180446625
#
# Epoch 55
# -------------------------------
# 	Before adaption: Initial condition loss: 0.19557441771030426
# 	Before adaption: Boundary condition loss: 0.07749245315790176
# 	Before adaption: PDE loss: 4.922193056700053e-06
# 	Before adaption: Data loss: 0.04514605924487114
# 		After adaption: Initial condition loss: 0.7009320855140686
# 		After adaption: Boundary condition loss: 0.26413393020629883
# 		After adaption: PDE loss: 0.009862197563052177
# 		After adaption: Data loss: 2.387603521347046
#
# 	Testing: Initial condition loss: 0.2681044638156891
# 	Testing: Boundary condition loss: 0.0776815190911293
# 	Testing: PDE loss: 5.2584041441150475e-06
# 	Testing: Data loss: 0.04581555724143982
#
# Epoch 56
# -------------------------------
# 	Before adaption: Initial condition loss: 0.19520263373851776
# 	Before adaption: Boundary condition loss: 0.07753553986549377
# 	Before adaption: PDE loss: 5.2748423513548914e-06
# 	Before adaption: Data loss: 0.04509354755282402
# 		After adaption: Initial condition loss: 0.7399125695228577
# 		After adaption: Boundary condition loss: 0.2788277566432953
# 		After adaption: PDE loss: 0.010655264370143414
# 		After adaption: Data loss: 2.4921746253967285
#
# 	Testing: Initial condition loss: 0.2676800489425659
# 	Testing: Boundary condition loss: 0.07762892544269562
# 	Testing: PDE loss: 5.577589490712853e-06
# 	Testing: Data loss: 0.04575730860233307
#
# Epoch 57
# -------------------------------
# 	Before adaption: Initial condition loss: 0.19493122398853302
# 	Before adaption: Boundary condition loss: 0.07748338580131531
# 	Before adaption: PDE loss: 5.586577117355773e-06
# 	Before adaption: Data loss: 0.04503699392080307
# 		After adaption: Initial condition loss: 0.7728155255317688
# 		After adaption: Boundary condition loss: 0.2921123802661896
# 		After adaption: PDE loss: 0.011388683691620827
# 		After adaption: Data loss: 2.604252815246582
#
# 	Testing: Initial condition loss: 0.2674708664417267
# 	Testing: Boundary condition loss: 0.07748055458068848
# 	Testing: PDE loss: 5.889696694794111e-06
# 	Testing: Data loss: 0.045697107911109924
#
# Epoch 58
# -------------------------------
# 	Before adaption: Initial condition loss: 0.1947481781244278
# 	Before adaption: Boundary condition loss: 0.07733675092458725
# 	Before adaption: PDE loss: 5.851926289324183e-06
# 	Before adaption: Data loss: 0.044978756457567215
# 		After adaption: Initial condition loss: 0.7942292094230652
# 		After adaption: Boundary condition loss: 0.3029190003871918
# 		After adaption: PDE loss: 0.012048443779349327
# 		After adaption: Data loss: 2.720409870147705
#
# 	Testing: Initial condition loss: 0.2674272656440735
# 	Testing: Boundary condition loss: 0.0772431492805481
# 	Testing: PDE loss: 6.057627615518868e-06
# 	Testing: Data loss: 0.04563682898879051
#
# Epoch 59
# -------------------------------
# 	Before adaption: Initial condition loss: 0.19466157257556915
# 	Before adaption: Boundary condition loss: 0.07710235565900803
# 	Before adaption: PDE loss: 6.020286491548177e-06
# 	Before adaption: Data loss: 0.04492112994194031
# 		After adaption: Initial condition loss: 0.8139355182647705
# 		After adaption: Boundary condition loss: 0.310517281293869
# 		After adaption: PDE loss: 0.012433269061148167
# 		After adaption: Data loss: 2.825267791748047
#
# 	Testing: Initial condition loss: 0.2675178349018097
# 	Testing: Boundary condition loss: 0.07692644000053406
# 	Testing: PDE loss: 6.079626018618001e-06
# 	Testing: Data loss: 0.0455784797668457
#
# Epoch 60
# -------------------------------
# 	Before adaption: Initial condition loss: 0.19466808438301086
# 	Before adaption: Boundary condition loss: 0.07678975909948349
# 	Before adaption: PDE loss: 6.0520824263221584e-06
# 	Before adaption: Data loss: 0.044865209609270096
# 		After adaption: Initial condition loss: 0.8240442872047424
# 		After adaption: Boundary condition loss: 0.3147793412208557
# 		After adaption: PDE loss: 0.012441231869161129
# 		After adaption: Data loss: 2.905069589614868
#
# 	Testing: Initial condition loss: 0.2676914930343628
# 	Testing: Boundary condition loss: 0.07655047625303268
# 	Testing: PDE loss: 6.106836281105643e-06
# 	Testing: Data loss: 0.04552066698670387
#
# Epoch 61
# -------------------------------
# 	Before adaption: Initial condition loss: 0.19473901391029358
# 	Before adaption: Boundary condition loss: 0.07641860842704773
# 	Before adaption: PDE loss: 6.08748450758867e-06
# 	Before adaption: Data loss: 0.04480978101491928
# 		After adaption: Initial condition loss: 0.8280784487724304
# 		After adaption: Boundary condition loss: 0.31650879979133606
# 		After adaption: PDE loss: 0.01230921782553196
# 		After adaption: Data loss: 2.9581189155578613
#
# 	Testing: Initial condition loss: 0.2679302990436554
# 	Testing: Boundary condition loss: 0.07613276690244675
# 	Testing: PDE loss: 6.1923005887365434e-06
# 	Testing: Data loss: 0.045461270958185196
#
# Epoch 62
# -------------------------------
# 	Before adaption: Initial condition loss: 0.19484150409698486
# 	Before adaption: Boundary condition loss: 0.07600609213113785
# 	Before adaption: PDE loss: 6.192081855260767e-06
# 	Before adaption: Data loss: 0.044752806425094604
# 		After adaption: Initial condition loss: 0.828462541103363
# 		After adaption: Boundary condition loss: 0.3168772757053375
# 		After adaption: PDE loss: 0.012178396806120872
# 		After adaption: Data loss: 2.9984796047210693
#
# 	Testing: Initial condition loss: 0.2682048976421356
# 	Testing: Boundary condition loss: 0.07568728923797607
# 	Testing: PDE loss: 6.3374850469699595e-06
# 	Testing: Data loss: 0.04539982229471207
#
# Epoch 63
# -------------------------------
# 	Before adaption: Initial condition loss: 0.19495928287506104
# 	Before adaption: Boundary condition loss: 0.07556594908237457
# 	Before adaption: PDE loss: 6.358826340147061e-06
# 	Before adaption: Data loss: 0.04469385743141174
# 		After adaption: Initial condition loss: 0.8255248665809631
# 		After adaption: Boundary condition loss: 0.31657931208610535
# 		After adaption: PDE loss: 0.012095578946173191
# 		After adaption: Data loss: 3.0248360633850098
#
# 	Testing: Initial condition loss: 0.26848772168159485
# 	Testing: Boundary condition loss: 0.07522425800561905
# 	Testing: PDE loss: 6.629590643569827e-06
# 	Testing: Data loss: 0.04533616825938225
#
# Epoch 64
# -------------------------------
# 	Before adaption: Initial condition loss: 0.19508306682109833
# 	Before adaption: Boundary condition loss: 0.0751081183552742
# 	Before adaption: PDE loss: 6.638334980380023e-06
# 	Before adaption: Data loss: 0.044632717967033386
# 		After adaption: Initial condition loss: 0.8226783275604248
# 		After adaption: Boundary condition loss: 0.3159129023551941
# 		After adaption: PDE loss: 0.01213220413774252
# 		After adaption: Data loss: 3.0514376163482666
#
# 	Testing: Initial condition loss: 0.26877155900001526
# 	Testing: Boundary condition loss: 0.07475339621305466
# 	Testing: PDE loss: 7.064555575198028e-06
# 	Testing: Data loss: 0.0452703982591629
#
# Epoch 65
# -------------------------------
# 	Before adaption: Initial condition loss: 0.19519886374473572
# 	Before adaption: Boundary condition loss: 0.07464215904474258
# 	Before adaption: PDE loss: 7.014787570369663e-06
# 	Before adaption: Data loss: 0.04456934705376625
# 		After adaption: Initial condition loss: 0.8231133818626404
# 		After adaption: Boundary condition loss: 0.3151308298110962
# 		After adaption: PDE loss: 0.012259820476174355
# 		After adaption: Data loss: 3.0798964500427246
#
# 	Testing: Initial condition loss: 0.2690444886684418
# 	Testing: Boundary condition loss: 0.07428396493196487
# 	Testing: PDE loss: 7.521674433519365e-06
# 	Testing: Data loss: 0.04520270973443985
#
# Epoch 66
# -------------------------------
# 	Before adaption: Initial condition loss: 0.1952957808971405
# 	Before adaption: Boundary condition loss: 0.07417722791433334
# 	Before adaption: PDE loss: 7.530174116254784e-06
# 	Before adaption: Data loss: 0.044503774493932724
# 		After adaption: Initial condition loss: 0.8200458288192749
# 		After adaption: Boundary condition loss: 0.31446516513824463
# 		After adaption: PDE loss: 0.012519779615104198
# 		After adaption: Data loss: 3.0981438159942627
#
# 	Testing: Initial condition loss: 0.2692858874797821
# 	Testing: Boundary condition loss: 0.07382143288850784
# 	Testing: PDE loss: 8.137129952956457e-06
# 	Testing: Data loss: 0.045133285224437714
#
# Epoch 67
# -------------------------------
# 	Before adaption: Initial condition loss: 0.19537602365016937
# 	Before adaption: Boundary condition loss: 0.07371892035007477
# 	Before adaption: PDE loss: 8.141028047248255e-06
# 	Before adaption: Data loss: 0.04443632811307907
# 		After adaption: Initial condition loss: 0.8175889253616333
# 		After adaption: Boundary condition loss: 0.3139648735523224
# 		After adaption: PDE loss: 0.012862181290984154
# 		After adaption: Data loss: 3.1106369495391846
#
# 	Testing: Initial condition loss: 0.2694820463657379
# 	Testing: Boundary condition loss: 0.07336883246898651
# 	Testing: PDE loss: 8.88615886651678e-06
# 	Testing: Data loss: 0.045062121003866196
#
# Epoch 68
# -------------------------------
# 	Before adaption: Initial condition loss: 0.1954299956560135
# 	Before adaption: Boundary condition loss: 0.07326950877904892
# 	Before adaption: PDE loss: 8.865378731570672e-06
# 	Before adaption: Data loss: 0.04436691477894783
# 		After adaption: Initial condition loss: 0.8180886507034302
# 		After adaption: Boundary condition loss: 0.3137335181236267
# 		After adaption: PDE loss: 0.01330091618001461
# 		After adaption: Data loss: 3.1309609413146973
#
# 	Testing: Initial condition loss: 0.26962557435035706
# 	Testing: Boundary condition loss: 0.07293340563774109
# 	Testing: PDE loss: 9.719770787341986e-06
# 	Testing: Data loss: 0.04498948156833649
#
# Epoch 69
# -------------------------------
# 	Before adaption: Initial condition loss: 0.1954580545425415
# 	Before adaption: Boundary condition loss: 0.0728369653224945
# 	Before adaption: PDE loss: 9.649729690863751e-06
# 	Before adaption: Data loss: 0.0442957803606987
# 		After adaption: Initial condition loss: 0.817910373210907
# 		After adaption: Boundary condition loss: 0.3139004111289978
# 		After adaption: PDE loss: 0.013798071071505547
# 		After adaption: Data loss: 3.144881010055542
#
# 	Testing: Initial condition loss: 0.26971885561943054
# 	Testing: Boundary condition loss: 0.07251224666833878
# 	Testing: PDE loss: 1.0515786925680004e-05
# 	Testing: Data loss: 0.0449153408408165
#
# Epoch 70
# -------------------------------
# 	Before adaption: Initial condition loss: 0.19545836746692657
# 	Before adaption: Boundary condition loss: 0.07241827249526978
# 	Before adaption: PDE loss: 1.0501242286409251e-05
# 	Before adaption: Data loss: 0.04422306641936302
# 		After adaption: Initial condition loss: 0.823458731174469
# 		After adaption: Boundary condition loss: 0.3173002302646637
# 		After adaption: PDE loss: 0.014441541396081448
# 		After adaption: Data loss: 3.171766519546509
#
# 	Testing: Initial condition loss: 0.2697589099407196
# 	Testing: Boundary condition loss: 0.07210605591535568
# 	Testing: PDE loss: 1.1440009075158741e-05
# 	Testing: Data loss: 0.044839080423116684
#
# Epoch 71
# -------------------------------
# 	Before adaption: Initial condition loss: 0.19542823731899261
# 	Before adaption: Boundary condition loss: 0.07201419025659561
# 	Before adaption: PDE loss: 1.139757932833163e-05
# 	Before adaption: Data loss: 0.04414818435907364
# 		After adaption: Initial condition loss: 0.8640146255493164
# 		After adaption: Boundary condition loss: 0.3324507176876068
# 		After adaption: PDE loss: 0.015745315700769424
# 		After adaption: Data loss: 3.3160488605499268
#
# 	Testing: Initial condition loss: 0.2697523832321167
# 	Testing: Boundary condition loss: 0.07171223312616348
# ...
# 	Testing: Boundary condition loss: 2.6324481950723566e-05
# 	Testing: PDE loss: 1.863844954641536e-05
# 	Testing: Data loss: 0.030920855700969696
#
# Epoch 278
# -------------------------------
# 	Before adaption: Initial condition loss: 0.1218656674027443
# 	Before adaption: Boundary condition loss: 2.6322177291149274e-05
# 	Before adaption: PDE loss: 1.793595038179774e-05
# 	Before adaption: Data loss: 0.030596783384680748
# 		After adaption: Initial condition loss: 0.5831423401832581
# 		After adaption: Boundary condition loss: 0.006143954116851091
# 		After adaption: PDE loss: 0.04146832972764969
# 		After adaption: Data loss: 1.3929518461227417
#
# 	Testing: Initial condition loss: 0.17778021097183228
# 	Testing: Boundary condition loss: 2.143802157661412e-05
# 	Testing: PDE loss: 1.594607783772517e-05
# 	Testing: Data loss: 0.03079969435930252
#
# Epoch 279
# -------------------------------
# 	Before adaption: Initial condition loss: 0.12436379492282867
# 	Before adaption: Boundary condition loss: 2.1067316993139684e-05
# 	Before adaption: PDE loss: 1.531236557639204e-05
# 	Before adaption: Data loss: 0.030485888943076134
# 		After adaption: Initial condition loss: 0.4990784227848053
# 		After adaption: Boundary condition loss: 0.0050606015138328075
# 		After adaption: PDE loss: 0.06930654495954514
# 		After adaption: Data loss: 1.390411615371704
#
# 	Testing: Initial condition loss: 0.17577971518039703
# 	Testing: Boundary condition loss: 3.889125764544588e-06
# 	Testing: PDE loss: 2.142358607670758e-05
# 	Testing: Data loss: 0.03084717132151127
#
# Epoch 280
# -------------------------------
# 	Before adaption: Initial condition loss: 0.12277515977621078
# 	Before adaption: Boundary condition loss: 3.7975935356371338e-06
# 	Before adaption: PDE loss: 2.0913506887154654e-05
# 	Before adaption: Data loss: 0.030535290017724037
# 		After adaption: Initial condition loss: 0.539297878742218
# 		After adaption: Boundary condition loss: 0.007272294722497463
# 		After adaption: PDE loss: 0.029735207557678223
# 		After adaption: Data loss: 1.3772166967391968
#
# 	Testing: Initial condition loss: 0.1707371175289154
# 	Testing: Boundary condition loss: 0.00016462783969473094
# 	Testing: PDE loss: 2.138936542905867e-05
# 	Testing: Data loss: 0.031094562262296677
#
# Epoch 281
# -------------------------------
# 	Before adaption: Initial condition loss: 0.11828415095806122
# 	Before adaption: Boundary condition loss: 0.00016134943871293217
# 	Before adaption: PDE loss: 2.1284919057507068e-05
# 	Before adaption: Data loss: 0.030776875093579292
# 		After adaption: Initial condition loss: 0.6882522106170654
# 		After adaption: Boundary condition loss: 0.018275227397680283
# 		After adaption: PDE loss: 0.040947068482637405
# 		After adaption: Data loss: 1.3999935388565063
#
# 	Testing: Initial condition loss: 0.16928452253341675
# 	Testing: Boundary condition loss: 0.000149057392263785
# 	Testing: PDE loss: 2.5783692763070576e-05
# 	Testing: Data loss: 0.03102804347872734
#
# Epoch 282
# -------------------------------
# 	Before adaption: Initial condition loss: 0.1172112375497818
# 	Before adaption: Boundary condition loss: 0.00014646377530880272
# 	Before adaption: PDE loss: 2.59539665421471e-05
# 	Before adaption: Data loss: 0.030718691647052765
# 		After adaption: Initial condition loss: 0.6749561429023743
# 		After adaption: Boundary condition loss: 0.016372988000512123
# 		After adaption: PDE loss: 0.03635714575648308
# 		After adaption: Data loss: 1.3504778146743774
#
# 	Testing: Initial condition loss: 0.1715158075094223
# 	Testing: Boundary condition loss: 4.5328586566029117e-05
# 	Testing: PDE loss: 3.754445060621947e-05
# 	Testing: Data loss: 0.03078261762857437
#
# Epoch 283
# -------------------------------
# 	Before adaption: Initial condition loss: 0.11939358711242676
# 	Before adaption: Boundary condition loss: 4.504780372371897e-05
# 	Before adaption: PDE loss: 3.802997525781393e-05
# 	Before adaption: Data loss: 0.03048470988869667
# 		After adaption: Initial condition loss: 0.6084255576133728
# 		After adaption: Boundary condition loss: 0.011956498958170414
# 		After adaption: PDE loss: 0.03525503724813461
# 		After adaption: Data loss: 1.391520380973816
#
# 	Testing: Initial condition loss: 0.17698045074939728
# 	Testing: Boundary condition loss: 4.49502986157313e-05
# 	Testing: PDE loss: 2.8147411285317503e-05
# 	Testing: Data loss: 0.030482633039355278
#
# Epoch 284
# -------------------------------
# 	Before adaption: Initial condition loss: 0.1238846555352211
# 	Before adaption: Boundary condition loss: 4.365349013824016e-05
# 	Before adaption: PDE loss: 2.841579589585308e-05
# 	Before adaption: Data loss: 0.030178416520357132
# 		After adaption: Initial condition loss: 0.4868174195289612
# 		After adaption: Boundary condition loss: 0.00746179511770606
# 		After adaption: PDE loss: 0.026536379009485245
# 		After adaption: Data loss: 1.370367407798767
#
# 	Testing: Initial condition loss: 0.1779644638299942
# 	Testing: Boundary condition loss: 2.2826068743597716e-05
# 	Testing: PDE loss: 2.021017462539021e-05
# 	Testing: Data loss: 0.03052542544901371
#
# Epoch 285
# -------------------------------
# 	Before adaption: Initial condition loss: 0.1242750734090805
# 	Before adaption: Boundary condition loss: 2.5151961381197907e-05
# 	Before adaption: PDE loss: 2.0303999917814508e-05
# 	Before adaption: Data loss: 0.03020673431456089
# 		After adaption: Initial condition loss: 0.490550696849823
# 		After adaption: Boundary condition loss: 0.00687055429443717
# 		After adaption: PDE loss: 0.02977336011826992
# 		After adaption: Data loss: 1.367673635482788
#
# 	Testing: Initial condition loss: 0.17375554144382477
# 	Testing: Boundary condition loss: 7.07895087543875e-05
# 	Testing: PDE loss: 2.0285136997699738e-05
# 	Testing: Data loss: 0.030962705612182617
#
# Epoch 286
# -------------------------------
# 	Before adaption: Initial condition loss: 0.12074275314807892
# 	Before adaption: Boundary condition loss: 7.046962855383754e-05
# 	Before adaption: PDE loss: 1.999633423110936e-05
# 	Before adaption: Data loss: 0.03064514696598053
# 		After adaption: Initial condition loss: 0.6273826360702515
# 		After adaption: Boundary condition loss: 0.011410615406930447
# 		After adaption: PDE loss: 0.03374376893043518
# 		After adaption: Data loss: 1.4099910259246826
#
# 	Testing: Initial condition loss: 0.17136485874652863
# 	Testing: Boundary condition loss: 4.2883879359578714e-05
# 	Testing: PDE loss: 1.4125899724604096e-05
# 	Testing: Data loss: 0.031091855838894844
#
# Epoch 287
# -------------------------------
# 	Before adaption: Initial condition loss: 0.11922137439250946
# 	Before adaption: Boundary condition loss: 4.217069727019407e-05
# 	Before adaption: PDE loss: 1.3354201655602083e-05
# 	Before adaption: Data loss: 0.03079051710665226
# 		After adaption: Initial condition loss: 0.6384217739105225
# 		After adaption: Boundary condition loss: 0.00874220859259367
# 		After adaption: PDE loss: 0.12567660212516785
# 		After adaption: Data loss: 1.3853304386138916
#
# 	Testing: Initial condition loss: 0.17302900552749634
# 	Testing: Boundary condition loss: 4.297517079976387e-05
# 	Testing: PDE loss: 1.4745606677024625e-05
# 	Testing: Data loss: 0.03097568079829216
#
# Epoch 288
# -------------------------------
# 	Before adaption: Initial condition loss: 0.12106895446777344
# 	Before adaption: Boundary condition loss: 4.289665594114922e-05
# 	Before adaption: PDE loss: 1.4313169231172651e-05
# 	Before adaption: Data loss: 0.030684014782309532
# 		After adaption: Initial condition loss: 0.5890740156173706
# 		After adaption: Boundary condition loss: 0.009991546161472797
# 		After adaption: PDE loss: 0.040680065751075745
# 		After adaption: Data loss: 1.431645393371582
#
# 	Testing: Initial condition loss: 0.17451857030391693
# 	Testing: Boundary condition loss: 4.569991233438486e-06
# 	Testing: PDE loss: 1.3960165233584121e-05
# 	Testing: Data loss: 0.030832968652248383
#
# Epoch 289
# -------------------------------
# 	Before adaption: Initial condition loss: 0.1220007911324501
# 	Before adaption: Boundary condition loss: 4.356691533757839e-06
# 	Before adaption: PDE loss: 1.3440412658383138e-05
# 	Before adaption: Data loss: 0.0305278692394495
# 		After adaption: Initial condition loss: 0.5510980486869812
# 		After adaption: Boundary condition loss: 0.0034945933148264885
# 		After adaption: PDE loss: 0.03979797661304474
# 		After adaption: Data loss: 1.4029936790466309
#
# 	Testing: Initial condition loss: 0.17276233434677124
# 	Testing: Boundary condition loss: 0.0001189305039588362
# 	Testing: PDE loss: 1.4053601262276061e-05
# 	Testing: Data loss: 0.03105045296251774
#
# Epoch 290
# -------------------------------
# 	Before adaption: Initial condition loss: 0.11982224136590958
# 	Before adaption: Boundary condition loss: 0.00011919808457605541
# 	Before adaption: PDE loss: 1.3434727407002356e-05
# 	Before adaption: Data loss: 0.030724503099918365
# 		After adaption: Initial condition loss: 0.6572914123535156
# 		After adaption: Boundary condition loss: 0.015762241557240486
# 		After adaption: PDE loss: 0.04052143171429634
# 		After adaption: Data loss: 1.4300609827041626
#
# 	Testing: Initial condition loss: 0.1721174120903015
# 	Testing: Boundary condition loss: 0.00012127745867474005
# 	Testing: PDE loss: 1.5016809811640996e-05
# 	Testing: Data loss: 0.031153984367847443
#
# Epoch 291
# -------------------------------
# 	Before adaption: Initial condition loss: 0.11924350261688232
# 	Before adaption: Boundary condition loss: 0.00012037825945299119
# 	Before adaption: PDE loss: 1.4529313375533093e-05
# 	Before adaption: Data loss: 0.030827663838863373
# 		After adaption: Initial condition loss: 0.6739067435264587
# 		After adaption: Boundary condition loss: 0.01621708832681179
# 		After adaption: PDE loss: 0.0342756062746048
# 		After adaption: Data loss: 1.4278409481048584
#
# 	Testing: Initial condition loss: 0.17324799299240112
# 	Testing: Boundary condition loss: 5.4636270760966e-06
# 	Testing: PDE loss: 1.528714165033307e-05
# 	Testing: Data loss: 0.03102756477892399
#
# Epoch 292
# -------------------------------
# 	Before adaption: Initial condition loss: 0.12070465087890625
# 	Before adaption: Boundary condition loss: 5.468737072078511e-06
# 	Before adaption: PDE loss: 1.4791156900173519e-05
# 	Before adaption: Data loss: 0.03071490302681923
# 		After adaption: Initial condition loss: 0.5948479771614075
# 		After adaption: Boundary condition loss: 0.00361515861004591
# 		After adaption: PDE loss: 0.030056919902563095
# 		After adaption: Data loss: 1.4089255332946777
#
# 	Testing: Initial condition loss: 0.17709951102733612
# 	Testing: Boundary condition loss: 0.0001708147901808843
# 	Testing: PDE loss: 1.198009431391256e-05
# 	Testing: Data loss: 0.030830055475234985
#
# Epoch 293
# -------------------------------
# 	Before adaption: Initial condition loss: 0.12496040761470795
# 	Before adaption: Boundary condition loss: 0.00016703008441254497
# 	Before adaption: PDE loss: 1.1521360647748224e-05
# 	Before adaption: Data loss: 0.030537035316228867
# 		After adaption: Initial condition loss: 0.4994434118270874
# 		After adaption: Boundary condition loss: 0.01510058157145977
# 		After adaption: PDE loss: 0.04781001806259155
# 		After adaption: Data loss: 1.4537302255630493
#
# 	Testing: Initial condition loss: 0.1764315515756607
# 	Testing: Boundary condition loss: 0.00021767053112853318
# 	Testing: PDE loss: 1.4087488125369418e-05
# 	Testing: Data loss: 0.030928559601306915
#
# Epoch 294
# -------------------------------
# 	Before adaption: Initial condition loss: 0.12474093586206436
# 	Before adaption: Boundary condition loss: 0.00021290498261805624
# 	Before adaption: PDE loss: 1.3479465451382566e-05
# 	Before adaption: Data loss: 0.030642660334706306
# 		After adaption: Initial condition loss: 0.5095474123954773
# 		After adaption: Boundary condition loss: 0.017177969217300415
# 		After adaption: PDE loss: 0.027574053034186363
# 		After adaption: Data loss: 1.4490793943405151
#
# 	Testing: Initial condition loss: 0.17207935452461243
# 	Testing: Boundary condition loss: 4.751468077301979e-05
# 	Testing: PDE loss: 1.1568778063519858e-05
# 	Testing: Data loss: 0.031022388488054276
#
# Epoch 295
# -------------------------------
# 	Before adaption: Initial condition loss: 0.1205950379371643
# 	Before adaption: Boundary condition loss: 4.596156213665381e-05
# 	Before adaption: PDE loss: 1.087880718841916e-05
# 	Before adaption: Data loss: 0.030729258432984352
# 		After adaption: Initial condition loss: 0.5987071990966797
# 		After adaption: Boundary condition loss: 0.010081550106406212
# 		After adaption: PDE loss: 0.05086834728717804
# 		After adaption: Data loss: 1.4541032314300537
#
# 	Testing: Initial condition loss: 0.16710680723190308
# 	Testing: Boundary condition loss: 0.00021366094006225467
# 	Testing: PDE loss: 1.3199404747865628e-05
# 	Testing: Data loss: 0.03149919956922531
#
# Epoch 296
# -------------------------------
# 	Before adaption: Initial condition loss: 0.11552222818136215
# 	Before adaption: Boundary condition loss: 0.00020987240714021027
# 	Before adaption: PDE loss: 1.2495700502768159e-05
# 	Before adaption: Data loss: 0.031186312437057495
# 		After adaption: Initial condition loss: 0.743547260761261
# 		After adaption: Boundary condition loss: 0.022044479846954346
# 		After adaption: PDE loss: 0.035620857030153275
# 		After adaption: Data loss: 1.3826638460159302
#
# 	Testing: Initial condition loss: 0.16671377420425415
# 	Testing: Boundary condition loss: 0.00045865337597206235
# 	Testing: PDE loss: 1.0334902981412597e-05
# 	Testing: Data loss: 0.03165421262383461
#
# Epoch 297
# -------------------------------
# 	Before adaption: Initial condition loss: 0.11485272645950317
# 	Before adaption: Boundary condition loss: 0.0004506812256295234
# 	Before adaption: PDE loss: 9.730057172419038e-06
# 	Before adaption: Data loss: 0.03132924437522888
# 		After adaption: Initial condition loss: 0.8097543120384216
# 		After adaption: Boundary condition loss: 0.03616921603679657
# 		After adaption: PDE loss: 0.05637197941541672
# 		After adaption: Data loss: 1.4222747087478638
#
# 	Testing: Initial condition loss: 0.16973599791526794
# 	Testing: Boundary condition loss: 0.00023219981812871993
# 	Testing: PDE loss: 1.4512137568090111e-05
# 	Testing: Data loss: 0.0314326211810112
#
# Epoch 298
# -------------------------------
# 	Before adaption: Initial condition loss: 0.11743907630443573
# 	Before adaption: Boundary condition loss: 0.0002284788351971656
# 	Before adaption: PDE loss: 1.397942742187297e-05
# 	Before adaption: Data loss: 0.031110528856515884
# 		After adaption: Initial condition loss: 0.7240534424781799
# 		After adaption: Boundary condition loss: 0.024361852556467056
# 		After adaption: PDE loss: 0.031158726662397385
# 		After adaption: Data loss: 1.416124701499939
#
# 	Testing: Initial condition loss: 0.1750599443912506
# 	Testing: Boundary condition loss: 1.0515101166674867e-05
# 	Testing: PDE loss: 1.0586943972157314e-05
# 	Testing: Data loss: 0.03081453964114189
#
# Epoch 299
# -------------------------------
# 	Before adaption: Initial condition loss: 0.12258092314004898
# 	Before adaption: Boundary condition loss: 1.0374097655585501e-05
# 	Before adaption: PDE loss: 1.0194256901741028e-05
# 	Before adaption: Data loss: 0.030509846284985542
# 		After adaption: Initial condition loss: 0.5355209112167358
# 		After adaption: Boundary condition loss: 0.0044123101979494095
# 		After adaption: PDE loss: 0.039017725735902786
# 		After adaption: Data loss: 1.4095640182495117
#
# 	Testing: Initial condition loss: 0.17549067735671997
# 	Testing: Boundary condition loss: 7.591167377540842e-05
# 	Testing: PDE loss: 1.545940358482767e-05
# 	Testing: Data loss: 0.030808469280600548
#
# Epoch 300
# -------------------------------
# 	Before adaption: Initial condition loss: 0.12332415580749512
# 	Before adaption: Boundary condition loss: 7.431012636516243e-05
# 	Before adaption: PDE loss: 1.5109259038581513e-05
# 	Before adaption: Data loss: 0.03051578998565674
# 		After adaption: Initial condition loss: 0.5173799991607666
# 		After adaption: Boundary condition loss: 0.010154503397643566
# 		After adaption: PDE loss: 0.02281304821372032
# 		After adaption: Data loss: 1.4118331670761108
#
# 	Testing: Initial condition loss: 0.1728803962469101
# 	Testing: Boundary condition loss: 1.2338768101471942e-05
# 	Testing: PDE loss: 1.374173371004872e-05
# 	Testing: Data loss: 0.030913814902305603
#
# Training complete!

# %%
def result_plot(simulation, prediction, savefig=False):
    """_summary_

    Args:
        simulation (_type_): _description_
        prediction (_type_): _description_
    """
    f, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, sharey=True)
    f.tight_layout()

    # Min and max of real data so plots share limits
    sim_min = np.min(simulation)
    sim_max = np.max(simulation)
    
    sim_im = ax1.imshow(simulation, aspect=0.125, vmin=sim_min, vmax=sim_max)
    pred_im = ax2.imshow(prediction, aspect=0.125, vmin=sim_min, vmax=sim_max)
    res_im_fixed = ax3.imshow(simulation-np.asarray(prediction), aspect=0.125, vmin=sim_min, vmax=sim_max)
    res_im = ax4.imshow(simulation-np.asarray(prediction), aspect=0.125)

    # Colorbars
    f.colorbar(sim_im, orientation='vertical', shrink=0.45)
    f.colorbar(pred_im, orientation='vertical', shrink=0.45)
    f.colorbar(res_im_fixed, orientation='vertical', shrink=0.45)  
    f.colorbar(res_im, orientation='vertical', shrink=0.45)  
    
    #Titles and labels
    ax1.set_title("Simulated Data")
    ax1.set_ylabel("Time-step index")
    ax1.set_xlabel("Spatial index")
    ax2.set_title("Predicted Data")
    ax2.set_xlabel("Spatial index")
    ax3.set_title("Residual (fixed)")
    ax3.set_xlabel("Spatial index")
    ax4.set_title("Residual")
    ax4.set_xlabel("Spatial index")
    
    # Make spacing suitable
    plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.6, hspace=None)
    if savefig:
        f.savefig("output_img.png")

# Model inferencing and QC
x = torch.from_numpy(scaled_features[:, 1]).to(device)
t = torch.from_numpy(scaled_features[:, 0]).to(device)


with torch.inference_mode():
    prediction = model(torch.Tensor(x).reshape((x.shape[0],1)),
                       torch.Tensor(t).reshape((t.shape[0],1)))

prediction = prediction.reshape_as(torch.Tensor(U_load))
prediction = prediction.cpu().detach().numpy()
simulation = U_load

result_plot(simulation,prediction)

# %%
#Save the model for future use
output_model_path = os.getcwd() + "/model.pt"
torch.save(model.cpu(), output_model_path)
