# %% [markdown]
# # 1D Heat equation; PINN

# %%
# initial plot
import matplotlib.pyplot as plt
import numpy as np
import torch
import os
import pandas as pd
from torch.utils.tensorboard import SummaryWriter
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import datetime

# %% [markdown]
# We will store the temperature u, at a given x,t in a 2D tensor called U(t,x)

# %%
# setup time-space geometry
num_points = 51
x_start = 0
x_stop = 1
num_timesteps = 1000
t_start = 0
t_stop = 1 
x = np.linspace(start=x_start, stop=x_stop, num=num_points)
t = np.linspace(start=t_start, stop=t_stop, num=num_timesteps)

# %% [markdown]
# ## PINN to learn the 1D-heat diffusion equation

# %% [markdown]
# The goal of the following section is to show a PINN using:
#
# - Initial condition loss
# - Boundary condition loss
# - PDE loss
# - Data driven loss

# %%
#Use GPU if available
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cpu'

# %%
# When using Google Colab
# from google.colab import drive
# drive.mount('/gdrive')
# %cd /gdrive/My Drive

# %%
U_load = np.load("./1d-heat.npy")
print(f"U shape: {U_load.shape}")
# Out:
# U shape: (1000, 51)

# %%
#Store x,t in a feature array of 2 columns
features = np.ones((U_load.shape[0]*U_load.shape[1],2))
features[:,1] = np.tile(x,U_load.shape[0])
features[:,0] = np.repeat(t,U_load.shape[1])
print(f"First 5 features {features[0:5]}\n")
print(f"Last 5 features  {features[-5:]}")
# Out:
# First 5 features [[0.   0.  ]
#  [0.   0.02]
#  [0.   0.04]
#  [0.   0.06]
#  [0.   0.08]]
#
# Last 5 features  [[1.   0.92]
#  [1.   0.94]
#  [1.   0.96]
#  [1.   0.98]
#  [1.   1.  ]]

# %%
labels = np.ones((U_load.shape[0]*U_load.shape[1],1))
labels = U_load.ravel()
print(f"First 5 temperature label data: {labels[0:5]}")
# Out:
# First 5 temperature label data: [0.         0.06279052 0.12533323 0.18738131 0.24868989]

# %%
#Set datatype expected by PyTorch
labels = labels.astype(np.float32)
features = features.astype(np.float32)

# %% [markdown]
# Data now needs pre-processing ready for PyTorch training including:
#
# - Feature scaling
# - Train-test splitting for model validation

# %%
### Pre-processing stage
std_scaler = StandardScaler()
scaler_features = std_scaler.fit(features)
scaled_features = scaler_features.transform(features)

print(f"\nPre-scaling:\n {features[0:5]}")
print(f"Mean: {features.mean()} Std: {features.std()}")
print(f"\nPost-scaling:\n {scaled_features[0:5]}")
print(f"Mean: {scaled_features.mean()} Std: {scaled_features.std()}")
# Out:
# Pre-scaling:
#  [[0.   0.  ]
#  [0.   0.02]
#  [0.   0.04]
#  [0.   0.06]
#  [0.   0.08]]
# Mean: 0.5000000596046448 Std: 0.2916906177997589
#
# Post-scaling:
#  [[-1.7303196 -1.6984155]
#  [-1.7303196 -1.6304789]
#  [-1.7303196 -1.5625423]
#  [-1.7303196 -1.4946057]
#  [-1.7303196 -1.426669 ]]
# Mean: 2.1541818995274298e-08 Std: 1.0

# %%
# Get feature data for initial condition, boundary condition and interior points
features_init = scaled_features[0:51]

features_x0 = scaled_features[0::51]
features_xstop = scaled_features[50::51]
features_bound = np.append(features_x0, features_xstop, axis=0)

features_interior = np.empty((0,1))
start=1
block_size=49
skip=2
while start < features.shape[0]:
    features_interior = np.append(features_interior, scaled_features[start:start+block_size])
    start = start + block_size + skip

length = features_interior.ravel().shape[0]
features_interior = features_interior.reshape((int(length/2),2))

#Now split them into x and t as this is more generic for future multi-dimensional 
t_init = features_init[:, 0]
t_bound = features_bound[:, 0]
t_interior = features_interior[:, 0]
x_init = features_init[:, 1]
x_bound = features_bound[:, 1]
x_interior = features_interior[:, 1]

print(f"Time vals init condition shape: {t_init.shape}")
print(f"Time vals boundary condition shape: {t_bound.shape}")
print(f"Time vals interior condition shape: {t_interior.shape}")
print(f"Space vals init condition shape: {x_init.shape}")
print(f"Space vals boundary condition shape: {x_bound.shape}")
print(f"Space vals interior shape: {x_interior.shape}")
# Out:
# Time vals init condition shape: (51,)
# Time vals boundary condition shape: (2000,)
# Time vals interior condition shape: (49000,)
# Space vals init condition shape: (51,)
# Space vals boundary condition shape: (2000,)
# Space vals interior shape: (49000,)

# %%
# Get label data for initial condition, boundary condition and interior points
labels_init = labels[0:51]

labels_x0 = labels[0::51]
labels_xstop = labels[50::51]
labels_bound = np.append(labels_x0, labels_xstop, axis=0)

labels_interior = np.empty((0,1))
start=1
block_size=49
skip=2
while start < labels.shape[0]:
    labels_interior = np.append(labels_interior, labels[start:start+block_size])
    start = start + block_size + skip

print(f"Labels for init condition shape: {labels_init.shape}")
print(f"Labels for left boundary condition shape: {labels_x0.shape}")
print(f"Labels for right boundary condition shape: {labels_xstop.shape}")
print(f"\tLabels for both boundary condition shape: {labels_bound.shape}")
print(f"Labels for interior shape: {labels_interior.shape}")
# Out:
# Labels for init condition shape: (51,)
# Labels for left boundary condition shape: (1000,)
# Labels for right boundary condition shape: (1000,)
# 	Labels for both boundary condition shape: (2000,)
# Labels for interior shape: (49000,)

# %%
#Train test splitting
test_size = 0.8

#Interior data
(
    x_interior_train,
    x_interior_test,
    t_interior_train,
    t_interior_test,
    labels_interior_train,
    labels_interior_test,
) = train_test_split(x_interior, t_interior, labels_interior, test_size=test_size)

#Initial condition data
(
    x_init_train,
    x_init_test,
    t_init_train,
    t_init_test,
    labels_init_train,
    labels_init_test,
) = train_test_split(x_init, t_init, labels_init, test_size=test_size)

#Boundary condition data
(
    x_bound_train,
    x_bound_test,
    t_bound_train,
    t_bound_test,
    labels_bound_train,
    labels_bound_test,
) = train_test_split(x_bound, t_bound, labels_bound, test_size=test_size)

print(f"x_interior_train shape({x_interior_train.shape}) type({type(x_interior_train)})")
print(f"x_interior_test shape({x_interior_test.shape}) type({type(x_interior_test)})")
print(f"t_interior_train shape({t_interior_train.shape}) type({type(t_interior_train)})")
print(f"t_interior_test shape({t_interior_test.shape}) type({type(t_interior_test)})")
print(f"labels_interior_train shape({labels_interior_train.shape}) type({type(labels_interior_train)})")
print(f"labels_interior_test shape({labels_interior_test.shape}) type({type(labels_interior_test)})")

print()
print(f"x_bound_train shape({x_bound_train.shape}) type({type(x_bound_train)})")
print(f"x_bound_test shape({x_bound_test.shape}) type({type(x_bound_test)})")
print(f"t_bound_train shape({t_bound_train.shape}) type({type(t_bound_train)})")
print(f"t_bound_test shape({t_bound_test.shape}) type({type(t_bound_test)})")
print(f"labels_bound_train shape({labels_bound_train.shape}) type({type(labels_bound_train)})")
print(f"labels_bound_test shape({labels_bound_test.shape}) type({type(labels_bound_test)})")

print()
print(f"x_init_train shape({x_init_train.shape}) type({type(x_init_train)})")
print(f"x_init_test shape({x_init_test.shape}) type({type(x_init_test)})")
print(f"t_init_train shape({t_init_train.shape}) type({type(t_init_train)})")
print(f"t_init_test shape({t_init_test.shape}) type({type(t_init_test)})")
print(f"labels_init_train shape({labels_init_train.shape}) type({type(labels_init_train)})")
print(f"labels_init_test shape({labels_init_test.shape}) type({type(labels_init_test)})")
# Out:
# x_interior_train shape((9800,)) type(<class 'numpy.ndarray'>)
# x_interior_test shape((39200,)) type(<class 'numpy.ndarray'>)
# t_interior_train shape((9800,)) type(<class 'numpy.ndarray'>)
# t_interior_test shape((39200,)) type(<class 'numpy.ndarray'>)
# labels_interior_train shape((9800,)) type(<class 'numpy.ndarray'>)
# labels_interior_test shape((39200,)) type(<class 'numpy.ndarray'>)
#
# x_bound_train shape((400,)) type(<class 'numpy.ndarray'>)
# x_bound_test shape((1600,)) type(<class 'numpy.ndarray'>)
# t_bound_train shape((400,)) type(<class 'numpy.ndarray'>)
# t_bound_test shape((1600,)) type(<class 'numpy.ndarray'>)
# labels_bound_train shape((400,)) type(<class 'numpy.ndarray'>)
# labels_bound_test shape((1600,)) type(<class 'numpy.ndarray'>)
#
# x_init_train shape((10,)) type(<class 'numpy.ndarray'>)
# x_init_test shape((41,)) type(<class 'numpy.ndarray'>)
# t_init_train shape((10,)) type(<class 'numpy.ndarray'>)
# t_init_test shape((41,)) type(<class 'numpy.ndarray'>)
# labels_init_train shape((10,)) type(<class 'numpy.ndarray'>)
# labels_init_test shape((41,)) type(<class 'numpy.ndarray'>)

# %%
# Define MLP model architecture class
class NeuralNetwork(torch.nn.Module):
    def __init__(self):
        """_summary_
        """
        super().__init__()
        self.linear_stack = torch.nn.Sequential(
            torch.nn.Linear(2, 64),
            torch.nn.ReLU(),
            torch.nn.Linear(64, 64),
            torch.nn.ReLU(),
            torch.nn.Linear(64, 64),
            torch.nn.ReLU(),
            torch.nn.Linear(64, 64),
            torch.nn.ReLU(),
            torch.nn.Linear(64, 1)
        )

    def forward(self, x, t):
        """_summary_

        Args:
            x (_type_): _description_
            t (_type_): _description_

        Returns:
            _type_: _description_
        """
        inputs = torch.cat([x,t], axis=1).to(device)
        return self.linear_stack(inputs)

# %%
def train_loop(x_bound, x_init, x_interior, t_bound, t_init, t_interior,labels_bound, labels_init, labels_interior, model, loss_fn, optimizer, writer=None):
    """_summary_

    Args:
        x_bound (_type_): _description_
        x_init (_type_): _description_
        x_interior (_type_): _description_
        t_bound (_type_): _description_
        t_init (_type_): _description_
        t_interior (_type_): _description_
        labels_bound (_type_): _description_
        labels_init (_type_): _description_
        labels_interior (_type_): _description_
        model (_type_): _description_
        loss_fn (_type_): _description_
        optimizer (_type_): _description_
    """
    optimizer.zero_grad()

    interior_pred = model(x_interior, t_interior)
    bound_pred = model(x_bound, t_bound)
    init_pred = model(x_init, t_init)
    
    boundary_loss, initial_loss, pde_loss, data_loss = \
        loss_fn(
            interior_pred, bound_pred, init_pred, 
            labels_interior, labels_bound, labels_init, 
            x_interior, t_interior)
    
    print(f"\tBefore adaption: Initial condition loss: {initial_loss}")
    print(f"\tBefore adaption: Boundary condition loss: {boundary_loss}")
    print(f"\tBefore adaption: PDE loss: {pde_loss}")
    print(f"\tBefore adaption: Data loss: {data_loss}")

    #Calculate dBoundaryLoss/dTheta
    boundary_loss.backward(retain_graph=True)
    bound_grads = []
    for name, param in model.named_parameters():
        if "weight" in name:
            bound_grads.append(param.grad.view(-1))
    
    bound_grads = torch.cat(bound_grads)
    optimizer.zero_grad()
    
    #Calculate dInitialLoss/dTheta
    initial_loss.backward(retain_graph=True)
    init_grads = []
    for name, param in model.named_parameters():
        if "weight" in name:
            init_grads.append(param.grad.view(-1))
    
    init_grads = torch.cat(init_grads)
    optimizer.zero_grad()

    #Calculate dInitialLoss/dTheta
    pde_loss.backward(retain_graph=True)
    pde_grads = []
    for name, param in model.named_parameters():
        if "weight" in name:
            pde_grads.append(param.grad.view(-1))
    
    pde_grads = torch.cat(pde_grads)
    optimizer.zero_grad()

    #Calculate dDataLoss/dTheta
    data_loss.backward(retain_graph=True)
    data_grads = []
    for name, param in model.named_parameters():
        if "weight" in name:
            data_grads.append(param.grad.view(-1))    
    
    data_grads = torch.cat(data_grads)
    optimizer.zero_grad()

    #Compute adaptive weight for each component of total loss
    #relative to the mean gradient of data_loss w.r.t layer weights
    boundary_loss_weight = torch.max(torch.abs(data_grads)) / torch.mean(torch.abs(bound_grads))
    init_loss_weight = torch.max(torch.abs(data_grads)) / torch.mean(torch.abs(init_grads))
    pde_loss_weight = torch.max(torch.abs(data_grads)) / torch.mean(torch.abs(pde_grads))
    data_loss_weight = torch.max(torch.abs(data_grads)) / torch.mean(torch.abs(data_grads))

    #Create total loss to update all network parameters
    total_loss = \
        (data_loss * data_loss_weight) + \
        (init_loss_weight * initial_loss) + \
        (pde_loss_weight * pde_loss) + \
        (boundary_loss_weight * boundary_loss)
    
    print(f"\t\tAfter adaption: Initial condition loss: {initial_loss * init_loss_weight}")
    print(f"\t\tAfter adaption: Boundary condition loss: {boundary_loss * boundary_loss_weight}")
    print(f"\t\tAfter adaption: PDE loss: {pde_loss * pde_loss_weight}")
    print(f"\t\tAfter adaption: Data loss: {data_loss * data_loss_weight}")

    if writer:
        writer.add_scalar('training_boundary_loss',boundary_loss,epoch)
        writer.add_scalar('training_init_loss',initial_loss,epoch)
        writer.add_scalar('training_pde_loss',pde_loss,epoch)
        writer.add_scalar('training_data_loss',data_loss,epoch)
        writer.add_scalar('training_weighted_boundary_loss',boundary_loss * boundary_loss_weight,epoch)
        writer.add_scalar('training_weighted_init_loss',initial_loss * init_loss_weight,epoch)
        writer.add_scalar('training_weighted_pde_loss',pde_loss * pde_loss_weight,epoch)
        writer.add_scalar('training_weighted_data_loss',data_loss * data_loss_weight,epoch)
        writer.add_scalar('training_boundary_loss_weight',boundary_loss_weight,epoch)
        writer.add_scalar('training_init_loss_weight',init_loss_weight,epoch)
        writer.add_scalar('training_pde_loss_weight',pde_loss_weight,epoch)
        writer.add_scalar('training_data_loss_weight',data_loss_weight,epoch)
        
    
    total_loss.backward()
    optimizer.step()

# %%
def combined_physics_data_loss(interior_pred, bound_pred, init_pred, interior_labels, bound_labels, init_labels, x_interior, t_interior):
    """_summary_

    Args:
        interior_pred (_type_): _description_
        bound_pred (_type_): _description_
        init_pred (_type_): _description_
        interior_labels (_type_): _description_
        bound_labels (_type_): _description_
        init_labels (_type_): _description_
        x_interior (_type_): _description_
        t_interior (_type_): _description_

    Returns:
        _type_: _description_
    """
    dudx = torch.autograd.grad(interior_pred.sum(), x_interior, retain_graph=True, create_graph=True)[0]
    dudt = torch.autograd.grad(interior_pred.sum(), t_interior, retain_graph=True, create_graph=True)[0]
    d2udt2 = torch.autograd.grad(dudt.sum(), t_interior, retain_graph=True, create_graph=True)[0]
    pde_values = (dudx * d2udt2) - dudt

    mse = torch.nn.MSELoss()
    pde_zeros = torch.zeros_like(pde_values)
    pde_loss = mse(pde_values,pde_zeros)

    initial_loss = mse(init_labels, init_pred)
    boundary_loss = mse(bound_labels, bound_pred)
    data_loss = mse(interior_pred, interior_labels)
    
    return boundary_loss, initial_loss, pde_loss, data_loss

# %%
def test_loop(x_bound, x_init, x_interior, t_bound, t_init, t_interior,labels_bound, labels_init, labels_interior, model, loss_fn, writer=None):
    
    interior_pred = model(x_interior, t_interior)
    bound_pred = model(x_bound, t_bound)
    init_pred = model(x_init, t_init)

    boundary_loss, initial_loss, pde_loss, data_loss = \
        loss_fn(
            interior_pred, bound_pred, init_pred, 
            labels_interior, labels_bound, labels_init, 
            x_interior, t_interior)
    
    if writer:
        writer.add_scalar('testing_boundary_loss',boundary_loss,epoch)
        writer.add_scalar('testing_init_loss',initial_loss,epoch)
        writer.add_scalar('testing_pde_loss',pde_loss,epoch)
        writer.add_scalar('testing_data_loss',data_loss,epoch)
    
    print(f"\n\tTesting: Initial condition loss: {initial_loss}")
    print(f"\tTesting: Boundary condition loss: {boundary_loss}")
    print(f"\tTesting: PDE loss: {pde_loss}")
    print(f"\tTesting: Data loss: {data_loss}")

# %%
#PINN Model setup
model = NeuralNetwork()
model.to(device)
loss_fn = combined_physics_data_loss
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

#Place reshaped input tensors with correct data-type and with calculation of derivatives enabled on available device
x_interior_train=torch.from_numpy(x_interior_train.reshape(x_interior_train.shape[0],1)).float().requires_grad_().to(device)
t_interior_train=torch.from_numpy(t_interior_train.reshape(t_interior_train.shape[0],1)).float().requires_grad_().to(device)
x_init_train=torch.from_numpy(x_init_train.reshape(x_init_train.shape[0],1)).float().requires_grad_().to(device)
t_init_train=torch.from_numpy(t_init_train.reshape(t_init_train.shape[0],1)).float().requires_grad_().to(device)
x_bound_train=torch.from_numpy(x_bound_train.reshape(x_bound_train.shape[0],1)).float().requires_grad_().to(device)
t_bound_train=torch.from_numpy(t_bound_train.reshape(t_bound_train.shape[0],1)).float().requires_grad_().to(device)
labels_bound_train=torch.from_numpy(labels_bound_train.reshape(labels_bound_train.shape[0],1)).float().requires_grad_().to(device)
labels_init_train=torch.from_numpy(labels_init_train.reshape(labels_init_train.shape[0],1)).float().requires_grad_().to(device)
labels_interior_train=torch.from_numpy(labels_interior_train.reshape(labels_interior_train.shape[0],1)).float().requires_grad_().to(device)

x_interior_test=torch.from_numpy(x_interior_test.reshape(x_interior_test.shape[0],1)).float().requires_grad_().to(device)
t_interior_test=torch.from_numpy(t_interior_test.reshape(t_interior_test.shape[0],1)).float().requires_grad_().to(device)
x_init_test=torch.from_numpy(x_init_test.reshape(x_init_test.shape[0],1)).float().requires_grad_().to(device)
t_init_test=torch.from_numpy(t_init_test.reshape(t_init_test.shape[0],1)).float().requires_grad_().to(device)
x_bound_test=torch.from_numpy(x_bound_test.reshape(x_bound_test.shape[0],1)).float().requires_grad_().to(device)
t_bound_test=torch.from_numpy(t_bound_test.reshape(t_bound_test.shape[0],1)).float().requires_grad_().to(device)
labels_bound_test=torch.from_numpy(labels_bound_test.reshape(labels_bound_test.shape[0],1)).float().requires_grad_().to(device)
labels_init_test=torch.from_numpy(labels_init_test.reshape(labels_init_test.shape[0],1)).float().requires_grad_().to(device)
labels_interior_test=torch.from_numpy(labels_interior_test.reshape(labels_interior_test.shape[0],1)).float().requires_grad_().to(device)

#Setup Tensorboard for QCs
tensorboard_dir_name = "weighting"
writer = SummaryWriter("runs/" + tensorboard_dir_name)

epochs = 100

for epoch in range(epochs):
    print(f"\nEpoch {epoch+1}\n-------------------------------")

    train_loop(
        x_bound_train, x_init_train, x_interior_train,
        t_bound_train, t_init_train, t_interior_train,
        labels_bound_train, labels_init_train, labels_interior_train,
        model, loss_fn, optimizer, writer)
    
    test_loop(
        x_bound_test, x_init_test, x_interior_test,\
        t_bound_test, t_init_test, t_interior_test,\
        labels_bound_test, labels_init_test, labels_interior_test,\
        model, loss_fn, writer)

print("\nTraining complete!\n")
# Out:
# Epoch 1
# -------------------------------
# 	Before adaption: Initial condition loss: 0.2583417594432831
# 	Before adaption: Boundary condition loss: 0.011437378823757172
# 	Before adaption: PDE loss: 7.24938654457219e-05
# 	Before adaption: Data loss: 0.07734072208404541
# 		After adaption: Initial condition loss: 13.727411270141602
# 		After adaption: Boundary condition loss: 2.1899099349975586
# 		After adaption: PDE loss: 0.9346451163291931
# 		After adaption: Data loss: 12.904685020446777
#
# 	Testing: Initial condition loss: 0.3813842236995697
# 	Testing: Boundary condition loss: 0.013896746560931206
# 	Testing: PDE loss: 4.66460405732505e-05
# 	Testing: Data loss: 0.07380403578281403
#
# Epoch 2
# -------------------------------
# 	Before adaption: Initial condition loss: 0.24164800345897675
# 	Before adaption: Boundary condition loss: 0.01383997593075037
# 	Before adaption: PDE loss: 4.6076325816102326e-05
# 	Before adaption: Data loss: 0.07219398021697998
# 		After adaption: Initial condition loss: 13.358819007873535
# 		After adaption: Boundary condition loss: 2.311769485473633
# 		After adaption: PDE loss: 0.8761405944824219
# 		After adaption: Data loss: 12.484617233276367
#
# 	Testing: Initial condition loss: 0.36281225085258484
# 	Testing: Boundary condition loss: 0.01645101234316826
# 	Testing: PDE loss: 6.152077548904344e-05
# 	Testing: Data loss: 0.069229856133461
#
# Epoch 3
# -------------------------------
# 	Before adaption: Initial condition loss: 0.22756901383399963
# 		After adaption: Data loss: 5.390995025634766
#
# 	Testing: Initial condition loss: 0.23121261596679688
# 	Testing: Boundary condition loss: 0.04852830246090889
# 	Testing: PDE loss: 0.0006411348003894091
# 	Testing: Data loss: 0.03952867165207863
#
# Epoch 13
# -------------------------------
# 	Before adaption: Initial condition loss: 0.13268828392028809
# 	Before adaption: Boundary condition loss: 0.04857240244746208
# 	Before adaption: PDE loss: 0.000650923466309905
# 	Before adaption: Data loss: 0.03851814195513725
# 		After adaption: Initial condition loss: 3.7429680824279785
# 		After adaption: Boundary condition loss: 1.1934303045272827
# 		After adaption: PDE loss: 0.5248576998710632
# 		After adaption: Data loss: 4.364555358886719
#
# 	Testing: Initial condition loss: 0.2204490751028061
# 	Testing: Boundary condition loss: 0.051855217665433884
# 	Testing: PDE loss: 0.0007756476406939328
# 	Testing: Data loss: 0.03764558583498001
#
# Epoch 14
# -------------------------------
# 	Before adaption: Initial condition loss: 0.12560266256332397
# 	Before adaption: Boundary condition loss: 0.05190487951040268
# 	Before adaption: PDE loss: 0.0007892486755736172
# 	Before adaption: Data loss: 0.03669476509094238
# 		After adaption: Initial condition loss: 2.946734666824341
# 		After adaption: Boundary condition loss: 0.9755802154541016
# 		After adaption: PDE loss: 0.45713669061660767
# 		After adaption: Data loss: 3.4950039386749268
#
# 	Testing: Initial condition loss: 0.2105458825826645
# 	Testing: Boundary condition loss: 0.05470632389187813
# 	Testing: PDE loss: 0.0009188278345391154
# 	Testing: Data loss: 0.0360025055706501
#
# Epoch 15
# -------------------------------
# 	Before adaption: Initial condition loss: 0.119423508644104
# 	Before adaption: Boundary condition loss: 0.05477060005068779
# 	Before adaption: PDE loss: 0.0009363724384456873
# 	Before adaption: Data loss: 0.03510976955294609
# 		After adaption: Initial condition loss: 2.2549304962158203
# 		After adaption: Boundary condition loss: 0.7803774476051331
# 		After adaption: PDE loss: 0.3850501775741577
# 		After adaption: Data loss: 2.7325234413146973
#
# 	Testing: Initial condition loss: 0.2013493925333023
# 	Testing: Boundary condition loss: 0.05699263513088226
# 	Testing: PDE loss: 0.0010838673915714025
# 	Testing: Data loss: 0.0345374159514904
#
# Epoch 16
# -------------------------------
# 	Before adaption: Initial condition loss: 0.11370666325092316
# 	Before adaption: Boundary condition loss: 0.05710091441869736
# 	Before adaption: PDE loss: 0.001103451126255095
# 	Before adaption: Data loss: 0.03370106592774391
# 		After adaption: Initial condition loss: 1.7679145336151123
# 		After adaption: Boundary condition loss: 0.647314727306366
# 		After adaption: PDE loss: 0.3343227207660675
# 		After adaption: Data loss: 2.1767096519470215
#
# 	Testing: Initial condition loss: 0.19286088645458221
# 	Testing: Boundary condition loss: 0.058631788939237595
# 	Testing: PDE loss: 0.001276894472539425
# 	Testing: Data loss: 0.033184878528118134
#
# Epoch 17
# -------------------------------
# 	Before adaption: Initial condition loss: 0.10842432826757431
# 	Before adaption: Boundary condition loss: 0.058770373463630676
# 	Before adaption: PDE loss: 0.0013008668320253491
# 	Before adaption: Data loss: 0.03240368142724037
# 		After adaption: Initial condition loss: 1.4873789548873901
# 		After adaption: Boundary condition loss: 0.559941828250885
# 		After adaption: PDE loss: 0.30457228422164917
# 		After adaption: Data loss: 1.7987926006317139
#
# 	Testing: Initial condition loss: 0.18505607545375824
# 	Testing: Boundary condition loss: 0.05959150940179825
# 	Testing: PDE loss: 0.0015013115480542183
# 	Testing: Data loss: 0.03189075365662575
#
# Epoch 18
# -------------------------------
# 	Before adaption: Initial condition loss: 0.10346297919750214
# 	Before adaption: Boundary condition loss: 0.059754982590675354
# 	Before adaption: PDE loss: 0.0015312276082113385
# 	Before adaption: Data loss: 0.031158698722720146
# 		After adaption: Initial condition loss: 1.269484281539917
# 		After adaption: Boundary condition loss: 0.48608872294425964
# 		After adaption: PDE loss: 0.27939075231552124
# 		After adaption: Data loss: 1.4934529066085815
#
# 	Testing: Initial condition loss: 0.17787688970565796
# 	Testing: Boundary condition loss: 0.059860434383153915
# 	Testing: PDE loss: 0.0017612368101254106
# 	Testing: Data loss: 0.03062000498175621
#
# Epoch 19
# -------------------------------
# 	Before adaption: Initial condition loss: 0.09895431995391846
# 	Before adaption: Boundary condition loss: 0.06006866320967674
# 	Before adaption: PDE loss: 0.0017957666423171759
# 	Before adaption: Data loss: 0.029932089149951935
# 		After adaption: Initial condition loss: 1.2728092670440674
# 		After adaption: Boundary condition loss: 0.49496638774871826
# 		After adaption: PDE loss: 0.3007902503013611
# 		After adaption: Data loss: 1.4591312408447266
#
# 	Testing: Initial condition loss: 0.17127948999404907
# 	Testing: Boundary condition loss: 0.05936408415436745
# 	Testing: PDE loss: 0.0020606606267392635
# 	Testing: Data loss: 0.02932666428387165
#
# Epoch 20
# -------------------------------
# 	Before adaption: Initial condition loss: 0.0948697179555893
# 	Before adaption: Boundary condition loss: 0.05962973088026047
# 	Before adaption: PDE loss: 0.0020984041038900614
# 	Before adaption: Data loss: 0.028677595779299736
# 		After adaption: Initial condition loss: 1.2955479621887207
# 		After adaption: Boundary condition loss: 0.5096049904823303
# 		After adaption: PDE loss: 0.3275671601295471
# 		After adaption: Data loss: 1.4452086687088013
#
# 	Testing: Initial condition loss: 0.1651114672422409
# 	Testing: Boundary condition loss: 0.0581173412501812
# 	Testing: PDE loss: 0.002407138468697667
# 	Testing: Data loss: 0.02797507494688034
#
# Epoch 21
# -------------------------------
# 	Before adaption: Initial condition loss: 0.09110615402460098
# 	Before adaption: Boundary condition loss: 0.05844799056649208
# 	Before adaption: PDE loss: 0.002442128723487258
# 	Before adaption: Data loss: 0.027360428124666214
# 		After adaption: Initial condition loss: 1.2976751327514648
# 		After adaption: Boundary condition loss: 0.5104019045829773
# 		After adaption: PDE loss: 0.34953927993774414
# 		After adaption: Data loss: 1.4123904705047607
#
# 	Testing: Initial condition loss: 0.15936429798603058
# 	Testing: Boundary condition loss: 0.05608991160988808
# 	Testing: PDE loss: 0.0028032034169882536
# 	Testing: Data loss: 0.026552336290478706
#
# Epoch 22
# -------------------------------
# 	Before adaption: Initial condition loss: 0.08769279718399048
# 	Before adaption: Boundary condition loss: 0.05648253113031387
# 	Before adaption: PDE loss: 0.002839981112629175
# 	Before adaption: Data loss: 0.025967545807361603
# 		After adaption: Initial condition loss: 1.2821797132492065
# 		After adaption: Boundary condition loss: 0.4955420196056366
# 		After adaption: PDE loss: 0.36498236656188965
# 		After adaption: Data loss: 1.3595956563949585
#
# 	Testing: Initial condition loss: 0.15403996407985687
# 	Testing: Boundary condition loss: 0.05328860878944397
# 	Testing: PDE loss: 0.003252206603065133
# 	Testing: Data loss: 0.02506234496831894
#
# Epoch 23
# -------------------------------
# 	Before adaption: Initial condition loss: 0.08463019132614136
# 	Before adaption: Boundary condition loss: 0.0537382997572422
# 	Before adaption: PDE loss: 0.0032904406543821096
# 	Before adaption: Data loss: 0.024502165615558624
# 		After adaption: Initial condition loss: 1.227860689163208
# 		After adaption: Boundary condition loss: 0.46710440516471863
# 		After adaption: PDE loss: 0.37175220251083374
# 		After adaption: Data loss: 1.2848215103149414
#
# 	Testing: Initial condition loss: 0.149067223072052
# 	Testing: Boundary condition loss: 0.04980912059545517
# 	Testing: PDE loss: 0.0037588835693895817
# 	Testing: Data loss: 0.023520423099398613
#
# Epoch 24
# -------------------------------
# 	Before adaption: Initial condition loss: 0.08181705325841904
# 	Before adaption: Boundary condition loss: 0.05032198131084442
# 	Before adaption: PDE loss: 0.0037955292500555515
# 	Before adaption: Data loss: 0.022981872782111168
# 		After adaption: Initial condition loss: 1.1186492443084717
# 		After adaption: Boundary condition loss: 0.4271107614040375
# 		After adaption: PDE loss: 0.3675687909126282
# 		After adaption: Data loss: 1.1835243701934814
#
# 	Testing: Initial condition loss: 0.1443704068660736
# 	Testing: Boundary condition loss: 0.04583367332816124
# 	Testing: PDE loss: 0.0043212492018938065
# 	Testing: Data loss: 0.021964699029922485
#
# Epoch 25
# -------------------------------
# 	Before adaption: Initial condition loss: 0.07923490554094315
# 	Before adaption: Boundary condition loss: 0.04640492424368858
# 	Before adaption: PDE loss: 0.004362707491964102
# 	Before adaption: Data loss: 0.021445512771606445
# 		After adaption: Initial condition loss: 1.079724907875061
# 		After adaption: Boundary condition loss: 0.4092475175857544
# 		After adaption: PDE loss: 0.3823247253894806
# 		After adaption: Data loss: 1.1525479555130005
#
# 	Testing: Initial condition loss: 0.13985663652420044
# 	Testing: Boundary condition loss: 0.04154603183269501
# 	Testing: PDE loss: 0.0049410308711230755
# 	Testing: Data loss: 0.020434916019439697
#
# Epoch 26
# -------------------------------
# 	Before adaption: Initial condition loss: 0.07666225731372833
# 	Before adaption: Boundary condition loss: 0.042163342237472534
# 	Before adaption: PDE loss: 0.00498341815546155
# 	Before adaption: Data loss: 0.01993141882121563
# 		After adaption: Initial condition loss: 1.1393755674362183
# 		After adaption: Boundary condition loss: 0.4341127872467041
# 		After adaption: PDE loss: 0.43943846225738525
# 		After adaption: Data loss: 1.235058307647705
#
# 	Testing: Initial condition loss: 0.13545510172843933
# 	Testing: Boundary condition loss: 0.03714084252715111
# 	Testing: PDE loss: 0.005619470030069351
# 	Testing: Data loss: 0.018961356952786446
#
# Epoch 27
# -------------------------------
# 	Before adaption: Initial condition loss: 0.07413371652364731
# 	Before adaption: Boundary condition loss: 0.037801530212163925
# 	Before adaption: PDE loss: 0.0056662485003471375
# 	Before adaption: Data loss: 0.018471859395503998
# 		After adaption: Initial condition loss: 1.1521233320236206
# 		After adaption: Boundary condition loss: 0.45724254846572876
# 		After adaption: PDE loss: 0.5009349584579468
# 		After adaption: Data loss: 1.2837891578674316
#
# 	Testing: Initial condition loss: 0.13091516494750977
# 	Testing: Boundary condition loss: 0.03287345543503761
# 	Testing: PDE loss: 0.006362472660839558
# 	Testing: Data loss: 0.01754247024655342
#
# Epoch 28
# -------------------------------
# 	Before adaption: Initial condition loss: 0.071470245718956
# 	Before adaption: Boundary condition loss: 0.03357180953025818
# 	Before adaption: PDE loss: 0.00641264021396637
# 	Before adaption: Data loss: 0.01706739515066147
# 		After adaption: Initial condition loss: 1.1915521621704102
# 		After adaption: Boundary condition loss: 0.477022647857666
# 		After adaption: PDE loss: 0.5673509240150452
# 		After adaption: Data loss: 1.3167253732681274
#
# 	Testing: Initial condition loss: 0.1257837414741516
# 	Testing: Boundary condition loss: 0.029017280787229538
# 	Testing: PDE loss: 0.007165648974478245
# 	Testing: Data loss: 0.016168050467967987
#
# Epoch 29
# -------------------------------
# 	Before adaption: Initial condition loss: 0.06851163506507874
# 	Before adaption: Boundary condition loss: 0.029732463881373405
# 	Before adaption: PDE loss: 0.007223811931908131
# 	Before adaption: Data loss: 0.015710914507508278
# 		After adaption: Initial condition loss: 1.3013558387756348
# 		After adaption: Boundary condition loss: 0.5254401564598083
# 		After adaption: PDE loss: 0.6720876097679138
# 		After adaption: Data loss: 1.412895917892456
#
# 	Testing: Initial condition loss: 0.11966006457805634
# 	Testing: Boundary condition loss: 0.025738628581166267
# 	Testing: PDE loss: 0.00802766252309084
# 	Testing: Data loss: 0.014801126904785633
#
# Epoch 30
# -------------------------------
# 	Before adaption: Initial condition loss: 0.06497126817703247
# 	Before adaption: Boundary condition loss: 0.02646646462380886
# 	Before adaption: PDE loss: 0.008096067234873772
# 	Before adaption: Data loss: 0.014369083568453789
# 		After adaption: Initial condition loss: 1.3536732196807861
# 		After adaption: Boundary condition loss: 0.5489099025726318
# 		After adaption: PDE loss: 0.7487318515777588
# 		After adaption: Data loss: 1.418619155883789
#
# 	Testing: Initial condition loss: 0.11233797669410706
# 	Testing: Boundary condition loss: 0.023145828396081924
# 	Testing: PDE loss: 0.008929180912673473
# 	Testing: Data loss: 0.013414572924375534
#
# Epoch 31
# -------------------------------
# 	Before adaption: Initial condition loss: 0.06075987219810486
# 	Before adaption: Boundary condition loss: 0.023875854909420013
# 	Before adaption: PDE loss: 0.008998623117804527
# 	Before adaption: Data loss: 0.013016294687986374
# 		After adaption: Initial condition loss: 1.319560170173645
# 		After adaption: Boundary condition loss: 0.5355993509292603
# 	Before adaption: Data loss: 0.007262928411364555
# 		After adaption: Initial condition loss: 0.6306062936782837
# 		After adaption: Boundary condition loss: 0.2006925493478775
# 		After adaption: PDE loss: 0.39312681555747986
# 		After adaption: Data loss: 0.48500683903694153
#
# 	Testing: Initial condition loss: 0.059906959533691406
# 	Testing: Boundary condition loss: 0.01416591927409172
# 	Testing: PDE loss: 0.015335145406425
# 	Testing: Data loss: 0.006747507490217686
#
# Epoch 37
# -------------------------------
# 	Before adaption: Initial condition loss: 0.032492928206920624
# 	Before adaption: Boundary condition loss: 0.01476045697927475
# 	Before adaption: PDE loss: 0.015452385880053043
# 	Before adaption: Data loss: 0.006557503715157509
# 		After adaption: Initial condition loss: 0.5419530868530273
# 		After adaption: Boundary condition loss: 0.16343364119529724
# 		After adaption: PDE loss: 0.334125280380249
# 		After adaption: Data loss: 0.3818342387676239
#
# 	Testing: Initial condition loss: 0.05329455807805061
# 	Testing: Boundary condition loss: 0.012432562187314034
# 	Testing: PDE loss: 0.016534989699721336
# 	Testing: Data loss: 0.006140772253274918
#
# Epoch 38
# -------------------------------
# 	Before adaption: Initial condition loss: 0.02906867489218712
# 	Before adaption: Boundary condition loss: 0.013038036413490772
# 	Before adaption: PDE loss: 0.01666472665965557
# 	Before adaption: Data loss: 0.005967725068330765
# 		After adaption: Initial condition loss: 0.4577099680900574
# 		After adaption: Boundary condition loss: 0.14265714585781097
# 		After adaption: PDE loss: 0.2976837456226349
# 		After adaption: Data loss: 0.3181561529636383
#
# 	Testing: Initial condition loss: 0.04751459136605263
# 	Testing: Boundary condition loss: 0.010782016441226006
# 	Testing: PDE loss: 0.017684902995824814
# 	Testing: Data loss: 0.005645879544317722
#
# Epoch 39
# -------------------------------
# 	Before adaption: Initial condition loss: 0.025960609316825867
# 	Before adaption: Boundary condition loss: 0.011411353014409542
# 	Before adaption: PDE loss: 0.01782608963549137
# 	Before adaption: Data loss: 0.0054878490045666695
# 		After adaption: Initial condition loss: 0.385903000831604
# 		After adaption: Boundary condition loss: 0.13642658293247223
# 		After adaption: PDE loss: 0.2827169597148895
# 		After adaption: Data loss: 0.28631192445755005
#
# 	Testing: Initial condition loss: 0.04241226986050606
# 	Testing: Boundary condition loss: 0.009396654553711414
# 	Testing: PDE loss: 0.018736613914370537
# 	Testing: Data loss: 0.005270927678793669
#
# Epoch 40
# -------------------------------
# 	Before adaption: Initial condition loss: 0.023115891963243484
# 	Before adaption: Boundary condition loss: 0.01004333607852459
# 	Before adaption: PDE loss: 0.01885923184454441
# 	Before adaption: Data loss: 0.005126778036355972
# 		After adaption: Initial condition loss: 0.3667651116847992
# 		After adaption: Boundary condition loss: 0.15815050899982452
# 		After adaption: PDE loss: 0.31282347440719604
# 		After adaption: Data loss: 0.29583877325057983
#
# 	Testing: Initial condition loss: 0.03782755136489868
# 	Testing: Boundary condition loss: 0.008352252654731274
# 	Testing: PDE loss: 0.019624561071395874
# 	Testing: Data loss: 0.0050112358294427395
#
# Epoch 41
# -------------------------------
# 		After adaption: PDE loss: 0.31830283999443054
# 		After adaption: Data loss: 0.18454180657863617
#
# 	Testing: Initial condition loss: 0.017632246017456055
# 	Testing: Boundary condition loss: 0.0008499223622493446
# 	Testing: PDE loss: 0.01896941475570202
# 	Testing: Data loss: 0.004855816718190908
#
# Epoch 51
# -------------------------------
# 	Before adaption: Initial condition loss: 0.010814693756401539
# 	Before adaption: Boundary condition loss: 0.0009016895783133805
# 	Before adaption: PDE loss: 0.018992574885487556
# 	Before adaption: Data loss: 0.004869209136813879
# 		After adaption: Initial condition loss: 0.05632219463586807
# 		After adaption: Boundary condition loss: 0.06264545023441315
# 		After adaption: PDE loss: 0.22145286202430725
# 		After adaption: Data loss: 0.12883266806602478
#
# 	Testing: Initial condition loss: 0.019659297540783882
# 	Testing: Boundary condition loss: 0.000603787659201771
# 	Testing: PDE loss: 0.018225181847810745
# 	Testing: Data loss: 0.004907613154500723
#
# Epoch 52
# -------------------------------
# 	Before adaption: Initial condition loss: 0.01294802874326706
# 	Before adaption: Boundary condition loss: 0.0006159687181934714
# 	Before adaption: PDE loss: 0.01822071336209774
# 	Before adaption: Data loss: 0.004945587832480669
# 		After adaption: Initial condition loss: 0.04991336166858673
# 		After adaption: Boundary condition loss: 0.06022053211927414
# 		After adaption: PDE loss: 0.19594793021678925
# 		After adaption: Data loss: 0.11310739070177078
#
# 	Testing: Initial condition loss: 0.02196701616048813
# 	Testing: Boundary condition loss: 0.0004695845127571374
# 	Testing: PDE loss: 0.017536168918013573
# 	Testing: Data loss: 0.004972862079739571
#
# Epoch 53
# -------------------------------
# 	Before adaption: Initial condition loss: 0.015447172336280346
# 	Before adaption: Boundary condition loss: 0.000464108947198838
# 	Before adaption: PDE loss: 0.017535502091050148
# 	Before adaption: Data loss: 0.0050320010632276535
# 		After adaption: Initial condition loss: 0.056328851729631424
# 		After adaption: Boundary condition loss: 0.06497696787118912
# 		After adaption: PDE loss: 0.21379461884498596
# 		After adaption: Data loss: 0.12005934119224548
#
# 	Testing: Initial condition loss: 0.02418706566095352
# 	Testing: Boundary condition loss: 0.0003949443926103413
# 	Testing: PDE loss: 0.017006130889058113
# 	Testing: Data loss: 0.004959464073181152
#
# Epoch 54
# -------------------------------
# 	Before adaption: Initial condition loss: 0.017983291298151016
# 	Before adaption: Boundary condition loss: 0.0003857256378978491
# 	Before adaption: PDE loss: 0.01698312908411026
# 	Before adaption: Data loss: 0.0050337668508291245
# 		After adaption: Initial condition loss: 0.07630203664302826
# 		After adaption: Boundary condition loss: 0.07288477569818497
# 		After adaption: PDE loss: 0.2779507339000702
# 		After adaption: Data loss: 0.15067315101623535
#
# 	Testing: Initial condition loss: 0.025683386251330376
# 	Testing: Boundary condition loss: 0.0003398414410185069
# 	Testing: PDE loss: 0.016767103224992752
# 	Testing: Data loss: 0.004782091826200485
#
# Epoch 55
# -------------------------------
# 	Before adaption: Initial condition loss: 0.019852209836244583
# 	Before adaption: Boundary condition loss: 0.0003369792248122394
# 	Before adaption: PDE loss: 0.01668543368577957
#
# Epoch 60
# -------------------------------
# 	Before adaption: Initial condition loss: 0.014943132176995277
# 	Before adaption: Boundary condition loss: 0.00025407824432477355
# 	Before adaption: PDE loss: 0.01994221843779087
# 	Before adaption: Data loss: 0.002772533567622304
# 		After adaption: Initial condition loss: 0.06166854500770569
# 		After adaption: Boundary condition loss: 0.01715453900396824
# 		After adaption: PDE loss: 0.24742449820041656
# 		After adaption: Data loss: 0.10856691747903824
#
# 	Testing: Initial condition loss: 0.01721983030438423
# 	Testing: Boundary condition loss: 0.0003572415153030306
# 	Testing: PDE loss: 0.021197855472564697
# 	Testing: Data loss: 0.0024137033615261316
#
# Epoch 61
# -------------------------------
# 	Before adaption: Initial condition loss: 0.012710859067738056
# 	Before adaption: Boundary condition loss: 0.00037330889608711004
# 	Before adaption: PDE loss: 0.02113468013703823
# 	Before adaption: Data loss: 0.0024211069103330374
# 		After adaption: Initial condition loss: 0.036374032497406006
# 		After adaption: Boundary condition loss: 0.012315407395362854
# 		After adaption: PDE loss: 0.1529388129711151
# 		After adaption: Data loss: 0.07478032261133194
#
# 	Testing: Initial condition loss: 0.01520050410181284
# 	Testing: Boundary condition loss: 0.0005173953250050545
# 	Testing: PDE loss: 0.022346381098031998
# 	Testing: Data loss: 0.0021732982713729143
#
# Epoch 62
# -------------------------------
# 	Before adaption: Initial condition loss: 0.01078655757009983
# 	Before adaption: Boundary condition loss: 0.0005556591204367578
# 	Before adaption: PDE loss: 0.022272687405347824
# 	Before adaption: Data loss: 0.0021704642567783594
# 		After adaption: Initial condition loss: 0.021092399954795837
# 		After adaption: Boundary condition loss: 0.008587646298110485
# 		After adaption: PDE loss: 0.09096485376358032
# 		After adaption: Data loss: 0.05415664613246918
#
# 	Testing: Initial condition loss: 0.013589887879788876
# 	Testing: Boundary condition loss: 0.0007296297117136419
# 	Testing: PDE loss: 0.023457882925868034
# 	Testing: Data loss: 0.002022351138293743
#
# Epoch 63
# -------------------------------
# 	Before adaption: Initial condition loss: 0.00928531400859356
# 	Before adaption: Boundary condition loss: 0.0007983236573636532
# 	Before adaption: PDE loss: 0.023349452763795853
# 	Before adaption: Data loss: 0.002012532204389572
# 		After adaption: Initial condition loss: 0.02787528745830059
# 		After adaption: Boundary condition loss: 0.012786941602826118
# 		After adaption: PDE loss: 0.1190279945731163
# 		After adaption: Data loss: 0.08335519582033157
#
# 	Testing: Initial condition loss: 0.01239394024014473
# 	Testing: Boundary condition loss: 0.0009536659927107394
# 	Testing: PDE loss: 0.024485012516379356
# 	Testing: Data loss: 0.0019272816134616733
#
# Epoch 64
# -------------------------------
# 	Before adaption: Initial condition loss: 0.008161334320902824
# 	Before adaption: Boundary condition loss: 0.0010556313209235668
# 	Before adaption: PDE loss: 0.02437049150466919
# 	Before adaption: Data loss: 0.0019131303997710347
# 		After adaption: Initial condition loss: 0.05097280070185661
# 		After adaption: Boundary condition loss: 0.025792179629206657
# 		After adaption: PDE loss: 0.21222449839115143
# 		After adaption: Data loss: 0.14614522457122803
# 		After adaption: Initial condition loss: 0.02818291261792183
# 		After adaption: Boundary condition loss: 0.01919306442141533
# 		After adaption: PDE loss: 0.12208036333322525
# 		After adaption: Data loss: 0.0746263787150383
#
# 	Testing: Initial condition loss: 0.013374201953411102
# 	Testing: Boundary condition loss: 0.0008586989133618772
# 	Testing: PDE loss: 0.0255306214094162
# 	Testing: Data loss: 0.00146983633749187
#
# Epoch 70
# -------------------------------
# 	Before adaption: Initial condition loss: 0.007473992649465799
# 	Before adaption: Boundary condition loss: 0.0008749874541535974
# 	Before adaption: PDE loss: 0.025407951325178146
# 	Before adaption: Data loss: 0.0014581019058823586
# 		After adaption: Initial condition loss: 0.022904520854353905
# 		After adaption: Boundary condition loss: 0.013632398098707199
# 		After adaption: PDE loss: 0.09736555069684982
# 		After adaption: Data loss: 0.06082987040281296
#
# 	Testing: Initial condition loss: 0.013621464371681213
# 	Testing: Boundary condition loss: 0.00084533984772861
# 	Testing: PDE loss: 0.02522825077176094
# 	Testing: Data loss: 0.0014221323654055595
#
# Epoch 71
# -------------------------------
# 	Before adaption: Initial condition loss: 0.007551418151706457
# 	Before adaption: Boundary condition loss: 0.0008511386695317924
# 	Before adaption: PDE loss: 0.025119837373495102
# 	Before adaption: Data loss: 0.00140949129126966
# 		After adaption: Initial condition loss: 0.014425788074731827
# ...
# 	Testing: PDE loss: 0.02430366724729538
# 	Testing: Data loss: 0.00121639808639884
#
# Epoch 78
# -------------------------------
# 	Before adaption: Initial condition loss: 0.008201217278838158
# 	Before adaption: Boundary condition loss: 0.000846485432703048
# 	Before adaption: PDE loss: 0.024148698896169662
# 	Before adaption: Data loss: 0.0011966971214860678
# 		After adaption: Initial condition loss: 0.027357539162039757
# 		After adaption: Boundary condition loss: 0.00955558754503727
# 		After adaption: PDE loss: 0.10661294311285019
# 		After adaption: Data loss: 0.05806109309196472
#
# 	Testing: Initial condition loss: 0.014971746131777763
# 	Testing: Boundary condition loss: 0.000755314773414284
# 	Testing: PDE loss: 0.024437827989459038
# 	Testing: Data loss: 0.0011774986051023006
#
# Epoch 79
# -------------------------------
# 	Before adaption: Initial condition loss: 0.008154073730111122
# 	Before adaption: Boundary condition loss: 0.0007904695230536163
# 	Before adaption: PDE loss: 0.024305440485477448
# 	Before adaption: Data loss: 0.0011574294185265899
# 		After adaption: Initial condition loss: 0.029266512021422386
# 		After adaption: Boundary condition loss: 0.010005773045122623
# 		After adaption: PDE loss: 0.11472846567630768
# 		After adaption: Data loss: 0.056363604962825775
#
# 	Testing: Initial condition loss: 0.014684055000543594
# 	Testing: Boundary condition loss: 0.0006949438247829676
# 	Testing: PDE loss: 0.02463385835289955
# 	Testing: Data loss: 0.001131365424953401
#
# Epoch 80
# -------------------------------
# 	Before adaption: Initial condition loss: 0.007974537089467049
# 	Before adaption: Boundary condition loss: 0.0007348642684519291
# 	Before adaption: PDE loss: 0.02451198734343052
# 	Before adaption: Data loss: 0.0011112266220152378
# 		After adaption: Initial condition loss: 0.029306355863809586
# 	Testing: PDE loss: 0.028657786548137665
# 	Testing: Data loss: 0.0008084307773970068
#
# Epoch 90
# -------------------------------
# 	Before adaption: Initial condition loss: 0.004836295731365681
# 	Before adaption: Boundary condition loss: 0.0005006064893677831
# 	Before adaption: PDE loss: 0.02853025496006012
# 	Before adaption: Data loss: 0.0007965513505041599
# 		After adaption: Initial condition loss: 0.014573493041098118
# 		After adaption: Boundary condition loss: 0.004845647141337395
# 		After adaption: PDE loss: 0.05874774232506752
# 		After adaption: Data loss: 0.03456476703286171
#
# 	Testing: Initial condition loss: 0.008695756085216999
# 	Testing: Boundary condition loss: 0.00043846777407452464
# 	Testing: PDE loss: 0.028956519439816475
# 	Testing: Data loss: 0.0007891572313383222
#
# Epoch 91
# -------------------------------
# 	Before adaption: Initial condition loss: 0.004639966879040003
# 	Before adaption: Boundary condition loss: 0.0004916384932585061
# 	Before adaption: PDE loss: 0.028835121542215347
# 	Before adaption: Data loss: 0.0007784227491356432
# 		After adaption: Initial condition loss: 0.015514714643359184
# 		After adaption: Boundary condition loss: 0.005373884458094835
# 		After adaption: PDE loss: 0.06280352175235748
# 		After adaption: Data loss: 0.038077451288700104
#
# 	Testing: Initial condition loss: 0.008328677155077457
# 	Testing: Boundary condition loss: 0.0004293839738238603
# 	Testing: PDE loss: 0.029183559119701385
# 	Testing: Data loss: 0.0007677312823943794
#
# Epoch 92
# -------------------------------
# 	Before adaption: Initial condition loss: 0.004446192178875208
# 	Before adaption: Boundary condition loss: 0.0004835494328290224
# 	Before adaption: PDE loss: 0.02905622497200966
# 	Before adaption: Data loss: 0.0007580043748021126
# 		After adaption: Initial condition loss: 0.014092124067246914
# 		After adaption: Boundary condition loss: 0.004870285280048847
# 		After adaption: PDE loss: 0.057011816650629044
# 		After adaption: Data loss: 0.0381552018225193
#
# 	Testing: Initial condition loss: 0.007990799844264984
# 	Testing: Boundary condition loss: 0.000420851371018216
# 	Testing: PDE loss: 0.02933238446712494
# 	Testing: Data loss: 0.0007459984626621008
#
# Epoch 93
# -------------------------------
# 	Before adaption: Initial condition loss: 0.0042670415714383125
# 	Before adaption: Boundary condition loss: 0.0004746055346913636
# 	Before adaption: PDE loss: 0.029199760407209396
# 	Before adaption: Data loss: 0.0007371286046691239
# 		After adaption: Initial condition loss: 0.011077319271862507
# 		After adaption: Boundary condition loss: 0.0037160879001021385
# 		After adaption: PDE loss: 0.04486415535211563
# 		After adaption: Data loss: 0.032976459711790085
#
# 	Testing: Initial condition loss: 0.007712237536907196
# 	Testing: Boundary condition loss: 0.0004113434988539666
# 	Testing: PDE loss: 0.029414860531687737
# 	Testing: Data loss: 0.0007256584358401597
#
# Epoch 94
# -------------------------------
# 	Before adaption: Initial condition loss: 0.004118508659303188
# 	Before adaption: Boundary condition loss: 0.0004627177841030061
# 	Before adaption: PDE loss: 0.029288416728377342
# 	Before adaption: Data loss: 0.0007175329956226051
# 		After adaption: Initial condition loss: 0.012325979769229889
# 		After adaption: Boundary condition loss: 0.004005721770226955
# 	Before adaption: PDE loss: 0.02911248430609703
# 	Before adaption: Data loss: 0.0006319864769466221
# 		After adaption: Initial condition loss: 0.008505630306899548
# 		After adaption: Boundary condition loss: 0.0032143949065357447
# 		After adaption: PDE loss: 0.041985489428043365
# 		After adaption: Data loss: 0.01950695365667343
#
# 	Testing: Initial condition loss: 0.007420968730002642
# 	Testing: Boundary condition loss: 0.0003319377719890326
# 	Testing: PDE loss: 0.029252318665385246
# 	Testing: Data loss: 0.0006250609876587987
#
# Epoch 100
# -------------------------------
# 	Before adaption: Initial condition loss: 0.004021317698061466
# 	Before adaption: Boundary condition loss: 0.0003439915890339762
# 	Before adaption: PDE loss: 0.02908555045723915
# 	Before adaption: Data loss: 0.0006197019247338176
# 		After adaption: Initial condition loss: 0.008548353798687458
# 		After adaption: Boundary condition loss: 0.003292211564257741
# 		After adaption: PDE loss: 0.04314275458455086
# 		After adaption: Data loss: 0.0180189348757267
#
# 	Testing: Initial condition loss: 0.0073851970955729485
# 	Testing: Boundary condition loss: 0.00033577653812244534
# 	Testing: PDE loss: 0.02925708331167698
# 	Testing: Data loss: 0.0006126362713985145
#
# Training complete!

# %%
def result_plot(simulation, prediction, savefig=False):
    """_summary_

    Args:
        simulation (_type_): _description_
        prediction (_type_): _description_
    """
    f, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, sharey=True)
    f.tight_layout()

    # Min and max of real data so plots share limits
    sim_min = np.min(simulation)
    sim_max = np.max(simulation)
    
    sim_im = ax1.imshow(simulation, aspect=0.125, vmin=sim_min, vmax=sim_max)
    pred_im = ax2.imshow(prediction, aspect=0.125, vmin=sim_min, vmax=sim_max)
    res_im_fixed = ax3.imshow(simulation-np.asarray(prediction), aspect=0.125, vmin=sim_min, vmax=sim_max)
    res_im = ax4.imshow(simulation-np.asarray(prediction), aspect=0.125)

    # Colorbars
    f.colorbar(sim_im, orientation='vertical', shrink=0.45)
    f.colorbar(pred_im, orientation='vertical', shrink=0.45)
    f.colorbar(res_im_fixed, orientation='vertical', shrink=0.45)  
    f.colorbar(res_im, orientation='vertical', shrink=0.45)  
    
    #Titles and labels
    ax1.set_title("Simulated Data")
    ax1.set_ylabel("Time-step index")
    ax1.set_xlabel("Spatial index")
    ax2.set_title("Predicted Data")
    ax2.set_xlabel("Spatial index")
    ax3.set_title("Residual (fixed)")
    ax3.set_xlabel("Spatial index")
    ax4.set_title("Residual")
    ax4.set_xlabel("Spatial index")
    
    # Make spacing suitable
    plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.6, hspace=None)
    if savefig:
        f.savefig("output_img.png")

# Model inferencing and QC
x = torch.from_numpy(scaled_features[:, 1]).to(device)
t = torch.from_numpy(scaled_features[:, 0]).to(device)


with torch.inference_mode():
    prediction = model(torch.Tensor(x).reshape((x.shape[0],1)),
                       torch.Tensor(t).reshape((t.shape[0],1)))

prediction = prediction.reshape_as(torch.Tensor(U_load))
prediction = prediction.cpu().detach().numpy()
simulation = U_load

result_plot(simulation,prediction)

# %%
#Save the model for future use
output_model_path = os.getcwd() + "/model.pt"
torch.save(model.cpu(), output_model_path)
