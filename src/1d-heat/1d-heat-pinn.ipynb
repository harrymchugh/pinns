# %% [markdown]
# # 1D Heat equation; PINN

# %%
# initial plot
import matplotlib.pyplot as plt
import numpy as np
import torch
import os
import pandas as pd
from torch.utils.tensorboard import SummaryWriter
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import datetime

# %% [markdown]
# We will store the temperature u, at a given x,t in a 2D tensor called U(t,x)

# %%
# setup time-space geometry
num_points = 51
x_start = 0
x_stop = 1
num_timesteps = 1000
t_start = 0
t_stop = 1 
x = np.linspace(start=x_start, stop=x_stop, num=num_points)
t = np.linspace(start=t_start, stop=t_stop, num=num_timesteps)

# %% [markdown]
# ## PINN to learn the 1D-heat diffusion equation

# %% [markdown]
# The goal of the following section is to show a PINN using:
#
# - Initial condition loss
# - Boundary condition loss
# - PDE loss
# - Data driven loss

# %%
#Use GPU if available
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cpu'

# %%
# When using Google Colab
# from google.colab import drive
# drive.mount('/gdrive')
# %cd /gdrive/My Drive

# %%
U_load = np.load("./1d-heat.npy")
print(f"U shape: {U_load.shape}")
# Out:
# U shape: (1000, 51)

# %%
#Store x,t in a feature array of 2 columns
features = np.ones((U_load.shape[0]*U_load.shape[1],2))
features[:,1] = np.tile(x,U_load.shape[0])
features[:,0] = np.repeat(t,U_load.shape[1])
print(f"First 5 features {features[0:5]}\n")
print(f"Last 5 features  {features[-5:]}")
# Out:
# First 5 features [[0.   0.  ]
#  [0.   0.02]
#  [0.   0.04]
#  [0.   0.06]
#  [0.   0.08]]
#
# Last 5 features  [[1.   0.92]
#  [1.   0.94]
#  [1.   0.96]
#  [1.   0.98]
#  [1.   1.  ]]

# %%
labels = np.ones((U_load.shape[0]*U_load.shape[1],1))
labels = U_load.ravel()
print(f"First 5 temperature label data: {labels[0:5]}")
# Out:
# First 5 temperature label data: [0.         0.06279052 0.12533323 0.18738131 0.24868989]

# %%
#Set datatype expected by PyTorch
labels = labels.astype(np.float32)
features = features.astype(np.float32)

# %% [markdown]
# Data now needs pre-processing ready for PyTorch training including:
#
# - Feature scaling
# - Train-test splitting for model validation

# %%
### Pre-processing stage
std_scaler = StandardScaler()
scaler_features = std_scaler.fit(features)
scaled_features = scaler_features.transform(features)

print(f"\nPre-scaling:\n {features[0:5]}")
print(f"Mean: {features.mean()} Std: {features.std()}")
print(f"\nPost-scaling:\n {scaled_features[0:5]}")
print(f"Mean: {scaled_features.mean()} Std: {scaled_features.std()}")
# Out:
# Pre-scaling:
#  [[0.   0.  ]
#  [0.   0.02]
#  [0.   0.04]
#  [0.   0.06]
#  [0.   0.08]]
# Mean: 0.5000000596046448 Std: 0.2916906177997589
#
# Post-scaling:
#  [[-1.7303196 -1.6984155]
#  [-1.7303196 -1.6304789]
#  [-1.7303196 -1.5625423]
#  [-1.7303196 -1.4946057]
#  [-1.7303196 -1.426669 ]]
# Mean: 2.1541818995274298e-08 Std: 1.0

# %%
scaled_features = features

# %%
# Get feature data for initial condition, boundary condition and interior points
features_init = scaled_features[0:51]

features_x0 = scaled_features[0::51]
features_xstop = scaled_features[50::51]
features_bound = np.append(features_x0, features_xstop, axis=0)

features_interior = np.empty((0,1))
start=1
block_size=49
skip=2
while start < features.shape[0]:
    features_interior = np.append(features_interior, scaled_features[start:start+block_size])
    start = start + block_size + skip

length = features_interior.ravel().shape[0]
features_interior = features_interior.reshape((int(length/2),2))

#Now split them into x and t as this is more generic for future multi-dimensional 
t_init = features_init[:, 0]
t_bound = features_bound[:, 0]
t_interior = features_interior[:, 0]
x_init = features_init[:, 1]
x_bound = features_bound[:, 1]
x_interior = features_interior[:, 1]

print(f"Time vals init condition shape: {t_init.shape}")
print(f"Time vals boundary condition shape: {t_bound.shape}")
print(f"Time vals interior condition shape: {t_interior.shape}")
print(f"Space vals init condition shape: {x_init.shape}")
print(f"Space vals boundary condition shape: {x_bound.shape}")
print(f"Space vals interior shape: {x_interior.shape}")
# Out:
# Time vals init condition shape: (51,)
# Time vals boundary condition shape: (2000,)
# Time vals interior condition shape: (49000,)
# Space vals init condition shape: (51,)
# Space vals boundary condition shape: (2000,)
# Space vals interior shape: (49000,)

# %%
# Get label data for initial condition, boundary condition and interior points
labels_init = labels[0:51]

labels_x0 = labels[0::51]
labels_xstop = labels[50::51]
labels_bound = np.append(labels_x0, labels_xstop, axis=0)

labels_interior = np.empty((0,1))
start=1
block_size=49
skip=2
while start < labels.shape[0]:
    labels_interior = np.append(labels_interior, labels[start:start+block_size])
    start = start + block_size + skip

print(f"Labels for init condition shape: {labels_init.shape}")
print(f"Labels for left boundary condition shape: {labels_x0.shape}")
print(f"Labels for right boundary condition shape: {labels_xstop.shape}")
print(f"\tLabels for both boundary condition shape: {labels_bound.shape}")
print(f"Labels for interior shape: {labels_interior.shape}")
# Out:
# Labels for init condition shape: (51,)
# Labels for left boundary condition shape: (1000,)
# Labels for right boundary condition shape: (1000,)
# 	Labels for both boundary condition shape: (2000,)
# Labels for interior shape: (49000,)

# %%
#Train test splitting
test_size = 0.95

#Interior data
(
    x_interior_train,
    x_interior_test,
    t_interior_train,
    t_interior_test,
    labels_interior_train,
    labels_interior_test,
) = train_test_split(x_interior, t_interior, labels_interior, test_size=test_size)

#Initial condition data
(
    x_init_train,
    x_init_test,
    t_init_train,
    t_init_test,
    labels_init_train,
    labels_init_test,
) = train_test_split(x_init, t_init, labels_init, test_size=test_size)

#Boundary condition data
(
    x_bound_train,
    x_bound_test,
    t_bound_train,
    t_bound_test,
    labels_bound_train,
    labels_bound_test,
) = train_test_split(x_bound, t_bound, labels_bound, test_size=test_size)

print(f"x_interior_train shape({x_interior_train.shape}) type({type(x_interior_train)})")
print(f"x_interior_test shape({x_interior_test.shape}) type({type(x_interior_test)})")
print(f"t_interior_train shape({t_interior_train.shape}) type({type(t_interior_train)})")
print(f"t_interior_test shape({t_interior_test.shape}) type({type(t_interior_test)})")
print(f"labels_interior_train shape({labels_interior_train.shape}) type({type(labels_interior_train)})")
print(f"labels_interior_test shape({labels_interior_test.shape}) type({type(labels_interior_test)})")

print()
print(f"x_bound_train shape({x_bound_train.shape}) type({type(x_bound_train)})")
print(f"x_bound_test shape({x_bound_test.shape}) type({type(x_bound_test)})")
print(f"t_bound_train shape({t_bound_train.shape}) type({type(t_bound_train)})")
print(f"t_bound_test shape({t_bound_test.shape}) type({type(t_bound_test)})")
print(f"labels_bound_train shape({labels_bound_train.shape}) type({type(labels_bound_train)})")
print(f"labels_bound_test shape({labels_bound_test.shape}) type({type(labels_bound_test)})")

print()
print(f"x_init_train shape({x_init_train.shape}) type({type(x_init_train)})")
print(f"x_init_test shape({x_init_test.shape}) type({type(x_init_test)})")
print(f"t_init_train shape({t_init_train.shape}) type({type(t_init_train)})")
print(f"t_init_test shape({t_init_test.shape}) type({type(t_init_test)})")
print(f"labels_init_train shape({labels_init_train.shape}) type({type(labels_init_train)})")
print(f"labels_init_test shape({labels_init_test.shape}) type({type(labels_init_test)})")
# Out:
# x_interior_train shape((2450,)) type(<class 'numpy.ndarray'>)
# x_interior_test shape((46550,)) type(<class 'numpy.ndarray'>)
# t_interior_train shape((2450,)) type(<class 'numpy.ndarray'>)
# t_interior_test shape((46550,)) type(<class 'numpy.ndarray'>)
# labels_interior_train shape((2450,)) type(<class 'numpy.ndarray'>)
# labels_interior_test shape((46550,)) type(<class 'numpy.ndarray'>)
#
# x_bound_train shape((100,)) type(<class 'numpy.ndarray'>)
# x_bound_test shape((1900,)) type(<class 'numpy.ndarray'>)
# t_bound_train shape((100,)) type(<class 'numpy.ndarray'>)
# t_bound_test shape((1900,)) type(<class 'numpy.ndarray'>)
# labels_bound_train shape((100,)) type(<class 'numpy.ndarray'>)
# labels_bound_test shape((1900,)) type(<class 'numpy.ndarray'>)
#
# x_init_train shape((2,)) type(<class 'numpy.ndarray'>)
# x_init_test shape((49,)) type(<class 'numpy.ndarray'>)
# t_init_train shape((2,)) type(<class 'numpy.ndarray'>)
# t_init_test shape((49,)) type(<class 'numpy.ndarray'>)
# labels_init_train shape((2,)) type(<class 'numpy.ndarray'>)
# labels_init_test shape((49,)) type(<class 'numpy.ndarray'>)

# %%
features_interior[:, 0]
# Out:
# array([0., 0., 0., ..., 1., 1., 1.])

# %%
U_load.shape
# Out:
# (1000, 51)

# %%
#Lets QC these training and testing locations
f,ax = plt.subplots()
ax.pcolormesh(features[:,0].reshape((1000,51)), features[:,1].reshape((1000,51)), labels.reshape((1000,51)), shading='gouraud',alpha=0.1)
ax.scatter(x_interior_train,t_interior_train,alpha=0.2,c="Red")
ax.scatter(x_interior_test,t_interior_test,alpha=0.01,c="Black")
ax.scatter(x_interior_test,t_interior_test,alpha=0.01,c="Black")
plt.show()

# %%
# Define MLP model architecture class
class NeuralNetwork(torch.nn.Module):
    def __init__(self):
        """_summary_
        """
        super().__init__()
        self.linear_stack = torch.nn.Sequential(
            torch.nn.Linear(2, 64),
            torch.nn.ReLU(),
            torch.nn.Linear(64, 64),
            torch.nn.ReLU(),
            torch.nn.Linear(64, 64),
            torch.nn.ReLU(),
            torch.nn.Linear(64, 64),
            torch.nn.ReLU(),
            torch.nn.Linear(64, 1)
        )

    def forward(self, x, t):
        """_summary_

        Args:
            x (_type_): _description_
            t (_type_): _description_

        Returns:
            _type_: _description_
        """
        inputs = torch.cat([x,t], axis=1).to(device)
        return self.linear_stack(inputs)

# %%
def train_loop(x_bound, x_init, x_interior, t_bound, t_init, t_interior,labels_bound, labels_init, labels_interior, model, loss_fn, optimizer, writer=None):
    """_summary_

    Args:
        x_bound (_type_): _description_
        x_init (_type_): _description_
        x_interior (_type_): _description_
        t_bound (_type_): _description_
        t_init (_type_): _description_
        t_interior (_type_): _description_
        labels_bound (_type_): _description_
        labels_init (_type_): _description_
        labels_interior (_type_): _description_
        model (_type_): _description_
        loss_fn (_type_): _description_
        optimizer (_type_): _description_
    """
    optimizer.zero_grad()

    interior_pred = model(x_interior, t_interior)
    bound_pred = model(x_bound, t_bound)
    init_pred = model(x_init, t_init)
    
    boundary_loss, initial_loss, pde_loss, data_loss = \
        loss_fn(
            interior_pred, bound_pred, init_pred, 
            labels_interior, labels_bound, labels_init, 
            x_interior, t_interior)
    
    print(f"\tBefore adaption: Initial condition loss: {initial_loss}")
    print(f"\tBefore adaption: Boundary condition loss: {boundary_loss}")
    print(f"\tBefore adaption: PDE loss: {pde_loss}")
    print(f"\tBefore adaption: Data loss: {data_loss}")

    #Calculate dBoundaryLoss/dTheta
    boundary_loss.backward(retain_graph=True)
    bound_grads = []
    for name, param in model.named_parameters():
        if "weight" in name:
            bound_grads.append(param.grad.view(-1))
    
    bound_grads = torch.cat(bound_grads)
    optimizer.zero_grad()
    
    #Calculate dInitialLoss/dTheta
    initial_loss.backward(retain_graph=True)
    init_grads = []
    for name, param in model.named_parameters():
        if "weight" in name:
            init_grads.append(param.grad.view(-1))
    
    init_grads = torch.cat(init_grads)
    optimizer.zero_grad()

    #Calculate dInitialLoss/dTheta
    pde_loss.backward(retain_graph=True)
    pde_grads = []
    for name, param in model.named_parameters():
        if "weight" in name:
            pde_grads.append(param.grad.view(-1))
    
    pde_grads = torch.cat(pde_grads)
    optimizer.zero_grad()

    #Calculate dDataLoss/dTheta
    data_loss.backward(retain_graph=True)
    data_grads = []
    for name, param in model.named_parameters():
        if "weight" in name:
            data_grads.append(param.grad.view(-1))    
    
    data_grads = torch.cat(data_grads)
    optimizer.zero_grad()

    #Compute adaptive weight for each component of total loss
    #relative to the mean gradient of data_loss w.r.t layer weights
    boundary_loss_weight = torch.max(torch.abs(data_grads)) / torch.mean(torch.abs(bound_grads))
    init_loss_weight = torch.max(torch.abs(data_grads)) / torch.mean(torch.abs(init_grads))
    pde_loss_weight = torch.max(torch.abs(data_grads)) / torch.mean(torch.abs(pde_grads))
    data_loss_weight = torch.max(torch.abs(data_grads)) / torch.mean(torch.abs(data_grads))

    #Create total loss to update all network parameters
    total_loss = \
        (data_loss * data_loss_weight) + \
        (init_loss_weight * initial_loss) + \
        (pde_loss_weight * pde_loss) + \
        (boundary_loss_weight * boundary_loss)
    
    print(f"\t\tAfter adaption: Initial condition loss: {initial_loss * init_loss_weight}")
    print(f"\t\tAfter adaption: Boundary condition loss: {boundary_loss * boundary_loss_weight}")
    print(f"\t\tAfter adaption: PDE loss: {pde_loss * pde_loss_weight}")
    print(f"\t\tAfter adaption: Data loss: {data_loss * data_loss_weight}")

    if writer:
        writer.add_scalar('training_boundary_loss',boundary_loss,epoch)
        writer.add_scalar('training_init_loss',initial_loss,epoch)
        writer.add_scalar('training_pde_loss',pde_loss,epoch)
        writer.add_scalar('training_data_loss',data_loss,epoch)
        writer.add_scalar('training_weighted_boundary_loss',boundary_loss * boundary_loss_weight,epoch)
        writer.add_scalar('training_weighted_init_loss',initial_loss * init_loss_weight,epoch)
        writer.add_scalar('training_weighted_pde_loss',pde_loss * pde_loss_weight,epoch)
        writer.add_scalar('training_weighted_data_loss',data_loss * data_loss_weight,epoch)
        writer.add_scalar('training_boundary_loss_weight',boundary_loss_weight,epoch)
        writer.add_scalar('training_init_loss_weight',init_loss_weight,epoch)
        writer.add_scalar('training_pde_loss_weight',pde_loss_weight,epoch)
        writer.add_scalar('training_data_loss_weight',data_loss_weight,epoch)
        writer.add_scalar('training_data_mean_grad', torch.mean(torch.abs(data_grads)))
        writer.add_scalar('training_pde_mean_grad', torch.mean(torch.abs(pde_grads)))
        writer.add_scalar('training_init_mean_grad', torch.mean(torch.abs(init_grads)))
        writer.add_scalar('training_bound_mean_grad', torch.mean(torch.abs(bound_grads)))
        
    
    total_loss.backward()
    optimizer.step()

# %%
def combined_physics_data_loss(interior_pred, bound_pred, init_pred, interior_labels, bound_labels, init_labels, x_interior, t_interior):
    """_summary_

    Args:
        interior_pred (_type_): _description_
        bound_pred (_type_): _description_
        init_pred (_type_): _description_
        interior_labels (_type_): _description_
        bound_labels (_type_): _description_
        init_labels (_type_): _description_
        x_interior (_type_): _description_
        t_interior (_type_): _description_

    Returns:
        _type_: _description_
    """
    dudx = torch.autograd.grad(interior_pred.sum(), x_interior, retain_graph=True, create_graph=True)[0]
    dudt = torch.autograd.grad(interior_pred.sum(), t_interior, retain_graph=True, create_graph=True)[0]
    d2udt2 = torch.autograd.grad(dudt.sum(), t_interior, retain_graph=True, create_graph=True)[0]
    pde_values = (dudx * d2udt2) - dudt

    mse = torch.nn.MSELoss()
    pde_zeros = torch.zeros_like(pde_values)
    pde_loss = mse(pde_values,pde_zeros)

    initial_loss = mse(init_labels, init_pred)
    boundary_loss = mse(bound_labels, bound_pred)
    data_loss = mse(interior_pred, interior_labels)
    
    return boundary_loss, initial_loss, pde_loss, data_loss

# %%
def test_loop(x_bound, x_init, x_interior, t_bound, t_init, t_interior,labels_bound, labels_init, labels_interior, model, loss_fn, writer=None):
    
    interior_pred = model(x_interior, t_interior)
    bound_pred = model(x_bound, t_bound)
    init_pred = model(x_init, t_init)

    boundary_loss, initial_loss, pde_loss, data_loss = \
        loss_fn(
            interior_pred, bound_pred, init_pred, 
            labels_interior, labels_bound, labels_init, 
            x_interior, t_interior)
    
    if writer:
        writer.add_scalar('testing_boundary_loss',boundary_loss,epoch)
        writer.add_scalar('testing_init_loss',initial_loss,epoch)
        writer.add_scalar('testing_pde_loss',pde_loss,epoch)
        writer.add_scalar('testing_data_loss',data_loss,epoch)
    
    print(f"\n\tTesting: Initial condition loss: {initial_loss}")
    print(f"\tTesting: Boundary condition loss: {boundary_loss}")
    print(f"\tTesting: PDE loss: {pde_loss}")
    print(f"\tTesting: Data loss: {data_loss}")

# %%
#PINN Model setup
model = NeuralNetwork()
model.to(device)
loss_fn = combined_physics_data_loss
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

#Place reshaped input tensors with correct data-type and with calculation of derivatives enabled on available device
x_interior_train=torch.from_numpy(x_interior_train.reshape(x_interior_train.shape[0],1)).float().requires_grad_().to(device)
t_interior_train=torch.from_numpy(t_interior_train.reshape(t_interior_train.shape[0],1)).float().requires_grad_().to(device)
x_init_train=torch.from_numpy(x_init_train.reshape(x_init_train.shape[0],1)).float().requires_grad_().to(device)
t_init_train=torch.from_numpy(t_init_train.reshape(t_init_train.shape[0],1)).float().requires_grad_().to(device)
x_bound_train=torch.from_numpy(x_bound_train.reshape(x_bound_train.shape[0],1)).float().requires_grad_().to(device)
t_bound_train=torch.from_numpy(t_bound_train.reshape(t_bound_train.shape[0],1)).float().requires_grad_().to(device)
labels_bound_train=torch.from_numpy(labels_bound_train.reshape(labels_bound_train.shape[0],1)).float().requires_grad_().to(device)
labels_init_train=torch.from_numpy(labels_init_train.reshape(labels_init_train.shape[0],1)).float().requires_grad_().to(device)
labels_interior_train=torch.from_numpy(labels_interior_train.reshape(labels_interior_train.shape[0],1)).float().requires_grad_().to(device)

x_interior_test=torch.from_numpy(x_interior_test.reshape(x_interior_test.shape[0],1)).float().requires_grad_().to(device)
t_interior_test=torch.from_numpy(t_interior_test.reshape(t_interior_test.shape[0],1)).float().requires_grad_().to(device)
x_init_test=torch.from_numpy(x_init_test.reshape(x_init_test.shape[0],1)).float().requires_grad_().to(device)
t_init_test=torch.from_numpy(t_init_test.reshape(t_init_test.shape[0],1)).float().requires_grad_().to(device)
x_bound_test=torch.from_numpy(x_bound_test.reshape(x_bound_test.shape[0],1)).float().requires_grad_().to(device)
t_bound_test=torch.from_numpy(t_bound_test.reshape(t_bound_test.shape[0],1)).float().requires_grad_().to(device)
labels_bound_test=torch.from_numpy(labels_bound_test.reshape(labels_bound_test.shape[0],1)).float().requires_grad_().to(device)
labels_init_test=torch.from_numpy(labels_init_test.reshape(labels_init_test.shape[0],1)).float().requires_grad_().to(device)
labels_interior_test=torch.from_numpy(labels_interior_test.reshape(labels_interior_test.shape[0],1)).float().requires_grad_().to(device)

#Setup Tensorboard for QCs
tensorboard_dir_name = "weighting"
writer = SummaryWriter("runs/" + tensorboard_dir_name)

epochs = 100

for epoch in range(epochs):
    print(f"\nEpoch {epoch+1}\n-------------------------------")

    train_loop(
        x_bound_train, x_init_train, x_interior_train,
        t_bound_train, t_init_train, t_interior_train,
        labels_bound_train, labels_init_train, labels_interior_train,
        model, loss_fn, optimizer, writer)
    
    test_loop(
        x_bound_test, x_init_test, x_interior_test,\
        t_bound_test, t_init_test, t_interior_test,\
        labels_bound_test, labels_init_test, labels_interior_test,\
        model, loss_fn, writer)

print("\nTraining complete!\n")
# Out:
# Epoch 1
# -------------------------------
# 	Before adaption: Initial condition loss: 0.47598305344581604
# 	Before adaption: Boundary condition loss: 0.00410744734108448
# 	Before adaption: PDE loss: 5.128209522808902e-05
# 	Before adaption: Data loss: 0.16357183456420898
# 		After adaption: Initial condition loss: 20.05014991760254
# 		After adaption: Boundary condition loss: 1.3409074544906616
# 		After adaption: PDE loss: 1.095354676246643
# 		After adaption: Data loss: 13.647553443908691
#
# 	Testing: Initial condition loss: 0.5546140670776367
# 	Testing: Boundary condition loss: 0.001290924847126007
# 	Testing: PDE loss: 5.31568075530231e-05
# 	Testing: Data loss: 0.15103018283843994
#
# Epoch 2
# -------------------------------
# 	Before adaption: Initial condition loss: 0.4450340270996094
# 	Before adaption: Boundary condition loss: 0.0012597563909366727
# -------------------------------
# 	Before adaption: Initial condition loss: 0.1635146290063858
# 	Before adaption: Boundary condition loss: 0.07319463789463043
# 	Before adaption: PDE loss: 0.0006483442848548293
# 	Before adaption: Data loss: 0.04383047670125961
# 		After adaption: Initial condition loss: 2.350742816925049
# 		After adaption: Boundary condition loss: 0.8128098845481873
# 		After adaption: PDE loss: 0.35617706179618835
# 		After adaption: Data loss: 2.7570712566375732
#
# 	Testing: Initial condition loss: 0.20906217396259308
# 	Testing: Boundary condition loss: 0.08337318152189255
# 	Testing: PDE loss: 0.0007721130969002843
# 	Testing: Data loss: 0.043167904019355774
#
# Epoch 18
# -------------------------------
# 	Before adaption: Initial condition loss: 0.15226635336875916
# 	Before adaption: Boundary condition loss: 0.08210066705942154
# 	Before adaption: PDE loss: 0.0007674500229768455
# 	Before adaption: Data loss: 0.04213928058743477
# 		After adaption: Initial condition loss: 1.5314193964004517
# 		After adaption: Boundary condition loss: 0.5708299875259399
# 		After adaption: PDE loss: 0.24439339339733124
# 		After adaption: Data loss: 1.843634843826294
#
# 	Testing: Initial condition loss: 0.19603869318962097
# 	Testing: Boundary condition loss: 0.09163933992385864
# 	Testing: PDE loss: 0.0009191621793434024
# 	Testing: Data loss: 0.04182307794690132
#
# Epoch 19
# -------------------------------
# 	Before adaption: Initial condition loss: 0.14253029227256775
# 	Before adaption: Boundary condition loss: 0.09024665504693985
# 	Before adaption: PDE loss: 0.0009095792192965746
# 	Before adaption: Data loss: 0.04088732600212097
# 		After adaption: Initial condition loss: 0.8642686605453491
# 		After adaption: Boundary condition loss: 0.3313286602497101
# 		After adaption: PDE loss: 0.14077813923358917
# 		After adaption: Data loss: 0.9776833653450012
#
# 	Testing: Initial condition loss: 0.18465186655521393
# 	Testing: Boundary condition loss: 0.09911695122718811
# 	Testing: PDE loss: 0.0010914946906268597
# 	Testing: Data loss: 0.040844086557626724
#
# Epoch 20
# -------------------------------
# 	Before adaption: Initial condition loss: 0.13418300449848175
# 	Before adaption: Boundary condition loss: 0.09758687019348145
# 	Before adaption: PDE loss: 0.0010795478010550141
# 	Before adaption: Data loss: 0.039995938539505005
# 		After adaption: Initial condition loss: 1.2581336498260498
# 		After adaption: Boundary condition loss: 0.4832434356212616
# 		After adaption: PDE loss: 0.2061193734407425
# 		After adaption: Data loss: 1.241813063621521
#
# 	Testing: Initial condition loss: 0.17474304139614105
# 	Testing: Boundary condition loss: 0.10534217208623886
# 	Testing: PDE loss: 0.0013013358693569899
# 	Testing: Data loss: 0.04003211483359337
#
# Epoch 21
# -------------------------------
# 	Before adaption: Initial condition loss: 0.1270911544561386
# 	Before adaption: Boundary condition loss: 0.10368206351995468
# 	Before adaption: PDE loss: 0.001281783333979547
# 	Before adaption: Data loss: 0.039264727383852005
# 		After adaption: Initial condition loss: 1.7970201969146729
# 		After adaption: Boundary condition loss: 0.6981322765350342
# 		After adaption: PDE loss: 0.3037794530391693
# 		After adaption: Data loss: 1.5855262279510498
#
# 	Testing: Initial condition loss: 0.16631372272968292
# 	Testing: Boundary condition loss: 0.1096682995557785
# 	Testing: PDE loss: 0.0015508733922615647
# 	Testing: Data loss: 0.03917373716831207
#
# Epoch 22
# -------------------------------
# 	Before adaption: Initial condition loss: 0.12110016494989395
# 	Before adaption: Boundary condition loss: 0.10787862539291382
# 	Before adaption: PDE loss: 0.0015330994501709938
# 	Before adaption: Data loss: 0.03847436234354973
# 		After adaption: Initial condition loss: 2.270167827606201
# 		After adaption: Boundary condition loss: 0.8953890204429626
# 		After adaption: PDE loss: 0.4029511511325836
# 		After adaption: Data loss: 1.830866813659668
#
# 	Testing: Initial condition loss: 0.15940377116203308
# 	Testing: Boundary condition loss: 0.11147717386484146
# 	Testing: PDE loss: 0.001852119225077331
# 	Testing: Data loss: 0.038073550909757614
#
# Epoch 23
# -------------------------------
# 	Before adaption: Initial condition loss: 0.11621208488941193
# 	Before adaption: Boundary condition loss: 0.10955968499183655
# 	Before adaption: PDE loss: 0.0018262182129547
# 	Before adaption: Data loss: 0.037426382303237915
# 		After adaption: Initial condition loss: 2.5729379653930664
# 		After adaption: Boundary condition loss: 1.01175057888031
# 		After adaption: PDE loss: 0.4748840034008026
# 		After adaption: Data loss: 1.9240527153015137
#
# 	Testing: Initial condition loss: 0.15398889780044556
# 	Testing: Boundary condition loss: 0.11053737998008728
# 	Testing: PDE loss: 0.0022020572796463966
# 	Testing: Data loss: 0.036634769290685654
#
# Epoch 24
# -------------------------------
# 	Before adaption: Initial condition loss: 0.11226340383291245
# 	Before adaption: Boundary condition loss: 0.10850677639245987
# 	Before adaption: PDE loss: 0.0021717448253184557
# 	Before adaption: Data loss: 0.03602225333452225
# 		After adaption: Initial condition loss: 2.594038248062134
# 		After adaption: Boundary condition loss: 1.0216327905654907
# 		After adaption: PDE loss: 0.5071266293525696
# 		After adaption: Data loss: 1.8750306367874146
#
# 	Testing: Initial condition loss: 0.14982165396213531
# 	Testing: Boundary condition loss: 0.10700594633817673
# 	Testing: PDE loss: 0.0026060836389660835
# 	Testing: Data loss: 0.03484618663787842
#
# Epoch 25
# -------------------------------
# 	Before adaption: Initial condition loss: 0.10904113203287125
# 	Before adaption: Boundary condition loss: 0.10489221662282944
# 	Before adaption: PDE loss: 0.002571114804595709
# 	Before adaption: Data loss: 0.034254081547260284
# 		After adaption: Initial condition loss: 2.3557841777801514
# 		After adaption: Boundary condition loss: 0.9339319467544556
# 		After adaption: PDE loss: 0.49533483386039734
# 		After adaption: Data loss: 1.7114659547805786
#
# 	Testing: Initial condition loss: 0.1466301530599594
# 	Testing: Boundary condition loss: 0.10131604969501495
# 	Testing: PDE loss: 0.0030695642344653606
# 	Testing: Data loss: 0.03279108181595802
#
# Epoch 26
# -------------------------------
# 	Before adaption: Initial condition loss: 0.10634948313236237
# 	Before adaption: Boundary condition loss: 0.09915374964475632
# 	Before adaption: PDE loss: 0.0030404794961214066
# 	Before adaption: Data loss: 0.03220939636230469
# 		After adaption: Initial condition loss: 1.9936083555221558
# 		After adaption: Boundary condition loss: 0.7773059606552124
# 	Before adaption: Boundary condition loss: 0.03550039231777191
# 	Before adaption: PDE loss: 0.010509299114346504
# 	Before adaption: Data loss: 0.01599971204996109
# 		After adaption: Initial condition loss: 1.814139485359192
# 		After adaption: Boundary condition loss: 0.6124141812324524
# 		After adaption: PDE loss: 0.8372479677200317
# 		After adaption: Data loss: 1.612749695777893
#
# 	Testing: Initial condition loss: 0.10652822256088257
# 	Testing: Boundary condition loss: 0.03614446148276329
# 	Testing: PDE loss: 0.01146991178393364
# 	Testing: Data loss: 0.014783743768930435
#
# Epoch 37
# -------------------------------
# 	Before adaption: Initial condition loss: 0.07715091854333878
# 	Before adaption: Boundary condition loss: 0.03434402495622635
# 	Before adaption: PDE loss: 0.011430329643189907
# 	Before adaption: Data loss: 0.014402644708752632
# 		After adaption: Initial condition loss: 1.6404658555984497
# 		After adaption: Boundary condition loss: 0.5393562316894531
# 		After adaption: PDE loss: 0.7745012640953064
# 		After adaption: Data loss: 1.4375345706939697
#
# 	Testing: Initial condition loss: 0.09715273976325989
# 	Testing: Boundary condition loss: 0.03551533445715904
# 	Testing: PDE loss: 0.012398741208016872
# 	Testing: Data loss: 0.013075452297925949
#
# Epoch 38
# -------------------------------
# 	Before adaption: Initial condition loss: 0.07075069844722748
# 	Before adaption: Boundary condition loss: 0.033735617995262146
# 	Before adaption: PDE loss: 0.012345272116363049
# 	Before adaption: Data loss: 0.012759683653712273
# 		After adaption: Initial condition loss: 1.393537998199463
# 		After adaption: Boundary condition loss: 0.43857017159461975
# 		After adaption: PDE loss: 0.6593987345695496
# 		After adaption: Data loss: 1.211440920829773
#
# 	Testing: Initial condition loss: 0.08783172070980072
# 	Testing: Boundary condition loss: 0.034871697425842285
# 	Testing: PDE loss: 0.013353056274354458
# 	Testing: Data loss: 0.011444824747741222
#
# Epoch 39
# -------------------------------
# 	Before adaption: Initial condition loss: 0.06441422551870346
# 	Before adaption: Boundary condition loss: 0.033094413578510284
# 	Before adaption: PDE loss: 0.013292890042066574
# 	Before adaption: Data loss: 0.011192228645086288
# 		After adaption: Initial condition loss: 1.0925577878952026
# 		After adaption: Boundary condition loss: 0.3274745047092438
# 		After adaption: PDE loss: 0.5171382427215576
# 		After adaption: Data loss: 0.9348615407943726
#
# 	Testing: Initial condition loss: 0.07899317145347595
# 	Testing: Boundary condition loss: 0.033685192465782166
# 	Testing: PDE loss: 0.014332608319818974
# 	Testing: Data loss: 0.009965452365577221
#
# Epoch 40
# -------------------------------
# 	Before adaption: Initial condition loss: 0.05863312631845474
# 	Before adaption: Boundary condition loss: 0.031914133578538895
# 	Before adaption: PDE loss: 0.014264479279518127
# 	Before adaption: Data loss: 0.009769747965037823
# 		After adaption: Initial condition loss: 0.8307070732116699
# 		After adaption: Boundary condition loss: 0.24086704850196838
# 		After adaption: PDE loss: 0.4023091197013855
# 		After adaption: Data loss: 0.6895820498466492
#
# 	Testing: Initial condition loss: 0.0710783451795578
# 	Testing: Boundary condition loss: 0.031646259129047394
# 	Testing: PDE loss: 0.015311311930418015
# 	Testing: Data loss: 0.00717873964458704
#
# Epoch 60
# -------------------------------
# 	Before adaption: Initial condition loss: 0.01949235610663891
# 	Before adaption: Boundary condition loss: 0.00047662571887485683
# 	Before adaption: PDE loss: 0.014226952567696571
# 	Before adaption: Data loss: 0.0071741314604878426
# 		After adaption: Initial condition loss: 0.12546852231025696
# 		After adaption: Boundary condition loss: 0.1858236938714981
# 		After adaption: PDE loss: 0.40892788767814636
# 		After adaption: Data loss: 0.2569187879562378
#
# 	Testing: Initial condition loss: 0.030228527262806892
# 	Testing: Boundary condition loss: 0.0003750185715034604
# 	Testing: PDE loss: 0.013344203121960163
# 	Testing: Data loss: 0.00728120282292366
#
# Epoch 61
# -------------------------------
# 	Before adaption: Initial condition loss: 0.02343459241092205
# 	Before adaption: Boundary condition loss: 0.0003761400294024497
# 	Before adaption: PDE loss: 0.013230749405920506
# 	Before adaption: Data loss: 0.007277254480868578
# 		After adaption: Initial condition loss: 0.1162535697221756
# 		After adaption: Boundary condition loss: 0.13718995451927185
# 		After adaption: PDE loss: 0.3436770737171173
# 		After adaption: Data loss: 0.22620785236358643
#
# 	Testing: Initial condition loss: 0.03302356228232384
# 	Testing: Boundary condition loss: 0.00029444965184666216
# 	Testing: PDE loss: 0.01300015952438116
# 	Testing: Data loss: 0.006975830998271704
#
# Epoch 62
# -------------------------------
# 	Before adaption: Initial condition loss: 0.0256580151617527
# 	Before adaption: Boundary condition loss: 0.0002982362639158964
# 	Before adaption: PDE loss: 0.012880977243185043
# 	Before adaption: Data loss: 0.006967466790229082
# 		After adaption: Initial condition loss: 0.10257316380739212
# 		After adaption: Boundary condition loss: 0.05616052448749542
# 		After adaption: PDE loss: 0.2893909215927124
# 		After adaption: Data loss: 0.19187912344932556
#
# 	Testing: Initial condition loss: 0.03511368855834007
# 	Testing: Boundary condition loss: 0.00022028051898814738
# 	Testing: PDE loss: 0.013142427429556847
# 	Testing: Data loss: 0.00636105565354228
#
# Epoch 63
# -------------------------------
# 	Before adaption: Initial condition loss: 0.027339691296219826
# 	Before adaption: Boundary condition loss: 0.00022402805916499346
# 	Before adaption: PDE loss: 0.013062350451946259
# 	Before adaption: Data loss: 0.0063476585783064365
# 		After adaption: Initial condition loss: 0.07468913495540619
# 		After adaption: Boundary condition loss: 0.026019182056188583
# 		After adaption: PDE loss: 0.20370271801948547
# 		After adaption: Data loss: 0.134521484375
#
# 	Testing: Initial condition loss: 0.03652907907962799
# 	Testing: Boundary condition loss: 0.00016162735118996352
# 	Testing: PDE loss: 0.01359130535274744
# 	Testing: Data loss: 0.005674197804182768
#
# Epoch 64
# -------------------------------
# 	Before adaption: Initial condition loss: 0.028456905856728554
# 	Before adaption: Boundary condition loss: 0.00016378037980757654
# 	Before adaption: PDE loss: 0.013513521291315556
# 	Before adaption: Data loss: 0.005656642839312553
# 		After adaption: Initial condition loss: 0.07180150598287582
# 		After adaption: Boundary condition loss: 0.021417096257209778
# 		After adaption: PDE loss: 0.19460022449493408
# 		After adaption: Data loss: 0.12400847673416138
#
# 	Testing: Initial condition loss: 0.03714832291007042
# 	Testing: Boundary condition loss: 0.00012739769590552896
# 	Testing: PDE loss: 0.014272353611886501
# 	Testing: Data loss: 0.0050113932229578495
#
# Epoch 65
# -------------------------------
# 	Before adaption: Initial condition loss: 0.028849244117736816
# 	Before adaption: Boundary condition loss: 0.0001259931013919413
# 	Before adaption: PDE loss: 0.014182154089212418
# 	Before adaption: Data loss: 0.004989719949662685
# 		After adaption: Initial condition loss: 0.06745237857103348
# 		After adaption: Boundary condition loss: 0.01959095150232315
# 		After adaption: PDE loss: 0.18384242057800293
# 		After adaption: Data loss: 0.10893356055021286
#
# 	Testing: Initial condition loss: 0.03700321540236473
# 	Testing: Boundary condition loss: 0.00011591416841838509
# 	Testing: PDE loss: 0.015093649737536907
# 	Testing: Data loss: 0.004431458190083504
#
# Epoch 66
# -------------------------------
# 	Before adaption: Initial condition loss: 0.028514135628938675
# 	Before adaption: Boundary condition loss: 0.00011016489588655531
# 	Before adaption: PDE loss: 0.014997347258031368
# 	Before adaption: Data loss: 0.004404701758176088
# 		After adaption: Initial condition loss: 0.08940515667200089
# 		After adaption: Boundary condition loss: 0.022622453048825264
# 		After adaption: PDE loss: 0.24798865616321564
# 		After adaption: Data loss: 0.131097212433815
#
# 	Testing: Initial condition loss: 0.035780422389507294
# 	Testing: Boundary condition loss: 0.00013225252041593194
# 	Testing: PDE loss: 0.015944743528962135
# 	Testing: Data loss: 0.003907123114913702
#
# Epoch 67
# -------------------------------
# 	Before adaption: Initial condition loss: 0.027115020900964737
# 	Before adaption: Boundary condition loss: 0.00012137913290644065
# 	Before adaption: PDE loss: 0.015864813700318336
# 	Before adaption: Data loss: 0.0038743054028600454
# 		After adaption: Initial condition loss: 0.09955981373786926
# 		After adaption: Boundary condition loss: 0.02128097042441368
# 		After adaption: PDE loss: 0.2858913540840149
# 		After adaption: Data loss: 0.13637055456638336
#
# 	Testing: Initial condition loss: 0.03353893384337425
# 	Testing: Boundary condition loss: 0.00019460877228993922
# 	Testing: PDE loss: 0.0167681984603405
# 	Testing: Data loss: 0.0034156772308051586
#
# Epoch 68
# -------------------------------
# 	Before adaption: Initial condition loss: 0.024835441261529922
# 	Before adaption: Boundary condition loss: 0.00017692954861558974
# 	Before adaption: PDE loss: 0.016645822674036026
# 	Before adaption: Data loss: 0.0033771772868931293
# 		After adaption: Initial condition loss: 0.08805537223815918
# 		After adaption: Boundary condition loss: 0.017546961084008217
# 		After adaption: PDE loss: 0.2658557593822479
# 		After adaption: Data loss: 0.1211683601140976
#
# 	Testing: Initial condition loss: 0.030614608898758888
# 	Testing: Boundary condition loss: 0.0003285768907517195
# 	Testing: PDE loss: 0.0175729151815176
# 	Testing: Data loss: 0.0029635087121278048
#
# Epoch 69
# -------------------------------
# 	Before adaption: Initial condition loss: 0.02211788296699524
# 	Before adaption: Boundary condition loss: 0.00030197101295925677
# 	Before adaption: PDE loss: 0.01743241958320141
# 	Before adaption: Data loss: 0.002920674392953515
# 		After adaption: Initial condition loss: 0.06189408153295517
# 		After adaption: Boundary condition loss: 0.013817494735121727
# 		After adaption: PDE loss: 0.19779936969280243
# 		After adaption: Data loss: 0.0926525816321373
#
# 	Testing: Initial condition loss: 0.02752627432346344
# 	Testing: Boundary condition loss: 0.0005400713998824358
# 	Testing: PDE loss: 0.018388165161013603
# 	Testing: Data loss: 0.002585997572168708
#
# Epoch 70
# -------------------------------
# 	Before adaption: Initial condition loss: 0.019328182563185692
# 	Before adaption: Boundary condition loss: 0.0005045934813097119
# 	Before adaption: PDE loss: 0.018231341615319252
# 	Before adaption: Data loss: 0.002540121553465724
# 		After adaption: Initial condition loss: 0.0344700813293457
# 		After adaption: Boundary condition loss: 0.009384668432176113
# 		After adaption: PDE loss: 0.11686189472675323
# 		After adaption: Data loss: 0.0593121238052845
#
# 	Testing: Initial condition loss: 0.02473854459822178
# 	Testing: Boundary condition loss: 0.0008108131005428731
# 	Testing: PDE loss: 0.019205663353204727
# 	Testing: Data loss: 0.002304043620824814
#
# Epoch 71
# -------------------------------
# 	Before adaption: Initial condition loss: 0.016900863498449326
# 	Before adaption: Boundary condition loss: 0.0007662483840249479
# 	Before adaption: PDE loss: 0.019062889739871025
# 	Before adaption: Data loss: 0.0022558250930160284
# 		After adaption: Initial condition loss: 0.027993718162178993
# 		After adaption: Boundary condition loss: 0.008999891579151154
# 		After adaption: PDE loss: 0.0979280099272728
# ...
# 	Testing: PDE loss: 0.024563010782003403
# 	Testing: Data loss: 0.0015092488611117005
#
# Epoch 78
# -------------------------------
# 	Before adaption: Initial condition loss: 0.011930317617952824
# 	Before adaption: Boundary condition loss: 0.0013236717786639929
# 	Before adaption: PDE loss: 0.024396641179919243
# 	Before adaption: Data loss: 0.0014639365253970027
# 		After adaption: Initial condition loss: 0.025145232677459717
# 		After adaption: Boundary condition loss: 0.012815033085644245
# 		After adaption: PDE loss: 0.09130990505218506
# 		After adaption: Data loss: 0.057142071425914764
#
# 	Testing: Initial condition loss: 0.018193675205111504
# 	Testing: Boundary condition loss: 0.0014192515518516302
# 	Testing: PDE loss: 0.024997316300868988
# 	Testing: Data loss: 0.0014906527940183878
#
# Epoch 79
# -------------------------------
# 	Before adaption: Initial condition loss: 0.011638178490102291
# 	Before adaption: Boundary condition loss: 0.0013394950656220317
# 	Before adaption: PDE loss: 0.024836605414748192
# 	Before adaption: Data loss: 0.00144596875179559
# 		After adaption: Initial condition loss: 0.03272087126970291
# 		After adaption: Boundary condition loss: 0.017617153003811836
# 		After adaption: PDE loss: 0.11959139257669449
# 		After adaption: Data loss: 0.06174720078706741
#
# 	Testing: Initial condition loss: 0.017740942537784576
# 	Testing: Boundary condition loss: 0.001457936130464077
# 	Testing: PDE loss: 0.025192825123667717
# 	Testing: Data loss: 0.0014556163223460317
#
# Epoch 80
# -------------------------------
# 	Before adaption: Initial condition loss: 0.011228405870497227
# 	Before adaption: Boundary condition loss: 0.0013742548180744052
# 	Before adaption: PDE loss: 0.02501964010298252
# 	Before adaption: Data loss: 0.0014110454358160496
# 		After adaption: Initial condition loss: 0.02923271246254444
# 		After adaption: Boundary condition loss: 0.015683216974139214
# 		After adaption: PDE loss: 0.10626567900180817
# 		After adaption: Data loss: 0.05845379829406738
#
# 	Testing: Initial condition loss: 0.017210766673088074
# 	Testing: Boundary condition loss: 0.0015128051163628697
# 	Testing: PDE loss: 0.025177737697958946
# 	Testing: Data loss: 0.001409357413649559
#
# Epoch 81
# -------------------------------
# 	Before adaption: Initial condition loss: 0.010771295055747032
# 	Before adaption: Boundary condition loss: 0.0014218785800039768
# 	Before adaption: PDE loss: 0.02501683123409748
# 	Before adaption: Data loss: 0.0013647075975313783
# 		After adaption: Initial condition loss: 0.017597181722521782
# 		After adaption: Boundary condition loss: 0.00888284295797348
# 		After adaption: PDE loss: 0.06272771954536438
# 		After adaption: Data loss: 0.045753054320812225
#
# 	Testing: Initial condition loss: 0.016700683161616325
# 	Testing: Boundary condition loss: 0.0015759096713736653
# 	Testing: PDE loss: 0.025062859058380127
# 	Testing: Data loss: 0.0013704977463930845
#
# Epoch 82
# -------------------------------
# 	Before adaption: Initial condition loss: 0.01035243272781372
# 	Before adaption: Boundary condition loss: 0.0014786175452172756
# 	Before adaption: PDE loss: 0.024899378418922424
# 	Before adaption: Data loss: 0.0013258960098028183
# 		After adaption: Initial condition loss: 0.011101377196609974
# 		After adaption: Boundary condition loss: 0.0052734375931322575
# 		After adaption: PDE loss: 0.03903817757964134
# 		After adaption: Data loss: 0.03829006850719452
#
# 	Testing: Initial condition loss: 0.016275284811854362
# 	Testing: Boundary condition loss: 0.0016311167273670435
# 	Testing: PDE loss: 0.024899857118725777
# 	Testing: Data loss: 0.001344936667010188
#
# Epoch 83
# -------------------------------
# 	Before adaption: Initial condition loss: 0.010011887177824974
# 	Before adaption: Boundary condition loss: 0.0015295492485165596
# 	Before adaption: PDE loss: 0.02474057488143444
# 	Before adaption: Data loss: 0.0013005395885556936
# 		After adaption: Initial condition loss: 0.014772403053939342
# 		After adaption: Boundary condition loss: 0.00661370437592268
# 		After adaption: PDE loss: 0.05108951777219772
# 		After adaption: Data loss: 0.041377048939466476
#
# 	Testing: Initial condition loss: 0.01602073200047016
# 	Testing: Boundary condition loss: 0.0016415074933320284
# 	Testing: PDE loss: 0.02470780722796917
# 	Testing: Data loss: 0.001325760269537568
#
# Epoch 84
# -------------------------------
# 	Before adaption: Initial condition loss: 0.00979280099272728
# 	Before adaption: Boundary condition loss: 0.0015389774926006794
# 	Before adaption: PDE loss: 0.02457062155008316
# 	Before adaption: Data loss: 0.0012815316440537572
# 		After adaption: Initial condition loss: 0.025210458785295486
# 		After adaption: Boundary condition loss: 0.010875503532588482
# 		After adaption: PDE loss: 0.08688927441835403
# 		After adaption: Data loss: 0.052952297031879425
#
# 	Testing: Initial condition loss: 0.01603715680539608
# 	Testing: Boundary condition loss: 0.0015557765727862716
# 	Testing: PDE loss: 0.024462543427944183
# 	Testing: Data loss: 0.001300334231927991
#
# Epoch 85
# -------------------------------
# 	Before adaption: Initial condition loss: 0.009767530485987663
# 	Before adaption: Boundary condition loss: 0.0014572334475815296
# 	Before adaption: PDE loss: 0.024342095479369164
# 	Before adaption: Data loss: 0.0012559654423967004
# 		After adaption: Initial condition loss: 0.025681396946310997
# 		After adaption: Boundary condition loss: 0.010811885818839073
# 		After adaption: PDE loss: 0.0894659236073494
# 		After adaption: Data loss: 0.05112247169017792
#
# 	Testing: Initial condition loss: 0.01630997471511364
# 	Testing: Boundary condition loss: 0.001386257354170084
# 	Testing: PDE loss: 0.024192389100790024
# 	Testing: Data loss: 0.0012684528483077884
#
# Epoch 86
# -------------------------------
# 	Before adaption: Initial condition loss: 0.009931469336152077
# 	Before adaption: Boundary condition loss: 0.0012959724990651011
# 	Before adaption: PDE loss: 0.024086929857730865
# 	Before adaption: Data loss: 0.0012236841721460223
# 		After adaption: Initial condition loss: 0.016735611483454704
# 		After adaption: Boundary condition loss: 0.007007868494838476
# 		After adaption: PDE loss: 0.05989878997206688
# 		After adaption: Data loss: 0.03904668241739273
#
# 	Testing: Initial condition loss: 0.0167044997215271
# 	Testing: Boundary condition loss: 0.001195852062664926
# 	Testing: PDE loss: 0.023944517597556114
# 	Testing: Data loss: 0.0012411150382831693
#
# Epoch 87
# -------------------------------
# 	Before adaption: Initial condition loss: 0.010194415226578712
# 	Before adaption: Boundary condition loss: 0.0011155185056850314
# 	Before adaption: PDE loss: 0.023815227672457695
# 	Before adaption: Data loss: 0.0011959836119785905
# 		After adaption: Initial condition loss: 0.011848174035549164
# 		After adaption: Boundary condition loss: 0.004955528303980827
# 		After adaption: PDE loss: 0.043329641222953796
# 		After adaption: Data loss: 0.03408745676279068
#
# 	Testing: Initial condition loss: 0.01710418239235878
# 	Testing: Boundary condition loss: 0.001024231081828475
# 	Testing: PDE loss: 0.023732677102088928
# 	Testing: Data loss: 0.0012234392343088984
#
# Epoch 88
# -------------------------------
# 	Before adaption: Initial condition loss: 0.010478501208126545
# 	Before adaption: Boundary condition loss: 0.0009538815356791019
# 	Before adaption: PDE loss: 0.02359771355986595
# 	Before adaption: Data loss: 0.0011781433131545782
# 		After adaption: Initial condition loss: 0.01284084003418684
# 		After adaption: Boundary condition loss: 0.005413770209997892
# 		After adaption: PDE loss: 0.04794618859887123
# 		After adaption: Data loss: 0.03485861420631409
#
# 	Testing: Initial condition loss: 0.01742241531610489
# 	Testing: Boundary condition loss: 0.0008867712458595634
# 	Testing: PDE loss: 0.02355235256254673
# 	Testing: Data loss: 0.0012143256608396769
#
# Epoch 89
# -------------------------------
# 	Before adaption: Initial condition loss: 0.0107267452403903
# 	Before adaption: Boundary condition loss: 0.0008248034282587469
# 	Before adaption: PDE loss: 0.023422416299581528
# 	Before adaption: Data loss: 0.0011690612882375717
# 		After adaption: Initial condition loss: 0.02300434000790119
# 		After adaption: Boundary condition loss: 0.009808501228690147
# 		After adaption: PDE loss: 0.08701999485492706
# 		After adaption: Data loss: 0.05020514130592346
#
# 	Testing: Initial condition loss: 0.017544429749250412
# 	Before adaption: PDE loss: 0.02293885126709938
# 	Before adaption: Data loss: 0.0011214499827474356
# 		After adaption: Initial condition loss: 0.014220977202057838
# 		After adaption: Boundary condition loss: 0.006152654532343149
# 		After adaption: PDE loss: 0.06410085409879684
# 		After adaption: Data loss: 0.024827012792229652
#
# 	Testing: Initial condition loss: 0.015194892883300781
# 	Testing: Boundary condition loss: 0.00035676200059242547
# 	Testing: PDE loss: 0.023232555016875267
# 	Testing: Data loss: 0.0011493607889860868
#
# Epoch 100
# -------------------------------
# 	Before adaption: Initial condition loss: 0.009260484017431736
# 	Before adaption: Boundary condition loss: 0.0003297837101854384
# 	Before adaption: PDE loss: 0.023053433746099472
# 	Before adaption: Data loss: 0.0011118425754830241
# 		After adaption: Initial condition loss: 0.015294750221073627
# 		After adaption: Boundary condition loss: 0.0075846449472010136
# 		After adaption: PDE loss: 0.07012394070625305
# 		After adaption: Data loss: 0.02630406804382801
#
# 	Testing: Initial condition loss: 0.01506712194532156
# 	Testing: Boundary condition loss: 0.00033294904278591275
# 	Testing: PDE loss: 0.023326940834522247
# 	Testing: Data loss: 0.0011406923877075315
#
# Training complete!

# %%
def result_plot(simulation, prediction, savefig=False):
    """_summary_

    Args:
        simulation (_type_): _description_
        prediction (_type_): _description_
    """
    f, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, sharey=True)
    f.tight_layout()

    # Min and max of real data so plots share limits
    sim_min = np.min(simulation)
    sim_max = np.max(simulation)
    
    sim_im = ax1.imshow(simulation, aspect=0.125, vmin=sim_min, vmax=sim_max)
    pred_im = ax2.imshow(prediction, aspect=0.125, vmin=sim_min, vmax=sim_max)
    res_im_fixed = ax3.imshow(simulation-np.asarray(prediction), aspect=0.125, vmin=sim_min, vmax=sim_max)
    res_im = ax4.imshow(simulation-np.asarray(prediction), aspect=0.125)

    # Colorbars
    f.colorbar(sim_im, orientation='vertical', shrink=0.45)
    f.colorbar(pred_im, orientation='vertical', shrink=0.45)
    f.colorbar(res_im_fixed, orientation='vertical', shrink=0.45)  
    f.colorbar(res_im, orientation='vertical', shrink=0.45)  
    
    #Titles and labels
    ax1.set_title("Simulated Data")
    ax1.set_ylabel("Time-step index")
    ax1.set_xlabel("Spatial index")
    ax2.set_title("Predicted Data")
    ax2.set_xlabel("Spatial index")
    ax3.set_title("Residual (fixed)")
    ax3.set_xlabel("Spatial index")
    ax4.set_title("Residual")
    ax4.set_xlabel("Spatial index")
    
    # Make spacing suitable
    plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.6, hspace=None)
    if savefig:
        f.savefig("output_img.png")

# Model inferencing and QC
x = torch.from_numpy(scaled_features[:, 1]).to(device)
t = torch.from_numpy(scaled_features[:, 0]).to(device)


with torch.inference_mode():
    prediction = model(torch.Tensor(x).reshape((x.shape[0],1)),
                       torch.Tensor(t).reshape((t.shape[0],1)))

prediction = prediction.reshape_as(torch.Tensor(U_load))
prediction = prediction.cpu().detach().numpy()
simulation = U_load

result_plot(simulation,prediction)

# %%
#Save the model for future use
output_model_path = os.getcwd() + "/model.pt"
torch.save(model.cpu(), output_model_path)
